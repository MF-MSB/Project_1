# %%
import pandas as pd
import geopandas as gpd
# from geopy.geocoders import Nominatim
from shapely.geometry import Point
import matplotlib.pyplot as plt
# import numpy as np
import requests
import json

# %%
# API resource: U.S. Wind Turbine Database (USWTDB) API via https://eersc.usgs.gov/api/uswtdb/v1/. 
# The base path, when combined with additional query parameters,constitute the full endpoint request.
# More details can be found here: https://eerscmap.usgs.gov/uswtdb/api-doc/#keyValue
# With reference to the API resource we would like our call to return:
   
    #case_id (Unique stable identification number.)
    #t_manu (Turbine manufacturer - name of the original equipment manufacturer of the turbine.)
    #xlong (Longitude of the turbine point, in decimal degrees.) 
    #ylat (Latitude of the turbine point, in decimal degrees.)
    #t_cap (Turbine rated capacity - stated output power at rated wind speed from manufacturer, ACP, and/or internet resources in kilowatts (kW))
    #t_ttlh (Turbine total height from ground to tip of a blade at its apex in meters (m))
    #p_year (Year that the turbine became operational and began providing power. Note this may differ from the year that construction began.)

# With reference to the API resource and testing the API call would look like this:
  
# data_url = "https://eersc.usgs.gov/api/uswtdb/v1/turbines?&select=case_id,t_manu,xlong,ylat,t_cap,t_ttlh,p_year"

# With further reference to the API documentation we can eliminate downstream labor such as renaming and sorting 
# We can reorder our of results using "order" in our API Call.

# With reference to the API resource and testing the API call for the desired information filtered on p_year (descending in order) would look like this:

# data_url = "https://eersc.usgs.gov/api/uswtdb/v1/turbines?&order=p_year.asc&select=case_id,t_manu,xlong,ylat,t_cap,t_ttlh,p_year"

# We also want data for turbines that are online and generating power. We can do this by ensuring the t_cap is greater that 0.

data_url = "https://eersc.usgs.gov/api/uswtdb/v1/turbines?&order=p_year.asc&t_cap=gt.0&select=case_id,t_manu,xlong,ylat,t_cap,t_ttlh,p_year,t_state"

# Parse the JSON response from the API return and populate the dataframe
df = pd.read_json(data_url)

# Preview the first five records of our dataframe based on the custom URL paramters in the API request
df.head(5)
# Out:
#    case_id   t_manu      xlong      ylat  t_cap  t_ttlh  p_year t_state
# 0  3078137    Micon -118.37759  35.03793    108     NaN  1982.0      CA
# 1  3078139  Lolland -118.37814  35.03763     75     NaN  1982.0      CA
# 2  3078138  Lolland -118.37788  35.03780     75     NaN  1982.0      CA
# 3  3073305   Vestas -118.35442  35.03581     65     NaN  1982.0      CA
# 4  3005500   Vestas -116.67849  33.94339     65    30.4  1983.0      CA

# %%
# The types of data are available in the API resource and we can confirm those here:
data_types = df.dtypes
print(data_types)
# Out:
# case_id      int64
# t_manu      object
# xlong      float64
# ylat       float64
# t_cap        int64
# t_ttlh     float64
# p_year     float64
# t_state     object
# dtype: object

# %%
# check number of columns and number of rows
df.shape
# Out:
# (69817, 8)

# %%
# check for null values 
print(df.isna().sum())
# Out:
# case_id      0
# t_manu     177
# xlong        0
# ylat         0
# t_cap        0
# t_ttlh     810
# p_year       7
# t_state      0
# dtype: int64

# %%
# We have data from the API call the provides Longitude and Latitude data
# we want data that can be read as US State. GeoPandas enables that.

# the prompt for ChatGPT is: "I have a pandas dataframe has a latitude and longitude column can I use geopandas to 
# create a new column that includes US state"

# Here is the code it provided and our implementation of it.


## Yes, you can use GeoPandas to create a new column in your DataFrame that includes the US state corresponding 
## to each latitude and longitude pair. To do this, you'll need a GeoDataFrame that contains the geometry of US
## state boundaries (often available as a shapefile or GeoJSON file). Here's a step-by-step guide on how to accomplish this:

# import geopandas as gpd
# import pandas as pd
# from shapely.geometry import Point
# Replace 'us_states.shp' with the path to your US states shapefile or GeoJSON file
#us_states = gpd.read_file('us_states.shp')

# Replace 'us_states.shp' with the path to your US states shapefile or GeoJSON file
# us_states = gpd.read_file('us_states.shp')

# Replace 'your_data.csv' with the path to your data file
# data = pd.read_csv('your_data.csv')

# Assuming your data has 'latitude' and 'longitude' columns
# geometry = [Point(xy) for xy in zip(data['longitude'], data['latitude'])]
# gdf = gpd.GeoDataFrame(data, geometry=geometry)


# Perform a spatial join to get the US state for each point in your data
# merged = gpd.sjoin(gdf, us_states, op='within')

# The 'NAME' column in the 'merged' GeoDataFrame now contains the US state names
# data['US_State'] = merged['NAME']

# %%
# Replace 'us_states.shp' with the path to your US states shapefile or GeoJSON file
us_states = gpd.read_file("C:/Users/mford.MSBIOWORKS/Project_1/gz_2010_us_040_00_5m.json")
us_states.head(5)
# Out:
#         GEO_ID STATE        NAME LSAD  CENSUSAREA  \
# 0  0400000US01    01     Alabama        50645.326
# 1  0400000US02    02      Alaska       570640.950
# 2  0400000US04    04     Arizona       113594.084
# 3  0400000US05    05    Arkansas        52035.477
# 4  0400000US06    06  California       155779.220
#
#                                             geometry
# 0  MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...
# 1  MULTIPOLYGON (((-166.10574 53.98861, -166.0752...
# 2  POLYGON ((-112.53859 37.00067, -112.53454 37.0...
# 3  POLYGON ((-94.04296 33.01922, -94.04304 33.079...
# 4  MULTIPOLYGON (((-122.42144 37.86997, -122.4213...

# %%
# Replace 'your_data.csv' with the path to your data file
# data = pd.read_csv('your_data.csv')
# our data are in the dataframe df
# data = df

# %%
# # Assuming your data has 'latitude' and 'longitude' columns
# # geometry = [Point(xy) for xy in zip(data['longitude'], data['latitude'])]
# # gdf = gpd.GeoDataFrame(data, geometry=geometry)

# geometry = [Point(xy) for xy in zip(df['xlong'], df['ylat'])]
# gdf = gpd.GeoDataFrame(df, geometry=geometry)

# #Set the CRS to EPSG:4326
# gdf.crs = 'EPSG:4326'

# %%
# # # Now you can perform a spatial join using gdfClusterMap as the GeoDataFrame
# # df3 = gpd.sjoin(gdfClusterMap, gdf, how="left", predicate="within")
# df_states = gpd.sjoin(gdf, us_states, how="left", predicate="within")

# %%
# # The 'NAME' column in the 'merged' GeoDataFrame now contains the US state names
# # data['US_State'] = merged['NAME']
# df_states.head()

# %%
# count the entries for each state 
turbines_per_state = df['t_state'].value_counts().reset_index()
turbines_per_state .columns = ['t_state', 'Count']
turbines_per_state .head()
# Out:
#   t_state  Count
# 0      TX  18325
# 1      IA   6284
# 2      OK   5344
# 3      KS   3927
# 4      CA   3857

# %%
# we dont have data for all 48 states!!!
turbines_per_state.shape
# Out:
# (45, 2)

# %%
data_types = turbines_per_state.dtypes
print(data_types)
# Out:
# t_state    object
# Count       int64
# dtype: object

# %%
# We can plot of box plot to visulize the spread of the data
# There are three stand out points
turbines_per_state.boxplot(column=['Count'])
plt.figure(figsize=(12, 8))
plt.show()

# %%
# We can create a new figure that plots boxplots excluding points

# Create a list of data to exclude
exclude_indices = [0, 1, 2, 3, 4, 5]

# Create a list of labels for the boxplots
labels = ['All States', 'Excluding TX', 'Excluding TX, IA, OK']

# Create a list of dataframes for each boxplot
boxplot_data = [turbines_per_state, turbines_per_state[turbines_per_state.index != exclude_indices[0]], turbines_per_state[turbines_per_state.index.isin(exclude_indices) == False]]

# Create the boxplots
plt.figure(figsize=(10, 6))
plt.boxplot([df['Count'] for df in boxplot_data], vert=False, labels=labels)

# Add labels and title
plt.xlabel('Number of turbines')
plt.ylabel('Group')
plt.title('Boxplots of Counts')

plt.show()

# %%
# min and mas values
min_value = turbines_per_state['Count'].min()
max_value = turbines_per_state['Count'].max()
print("Minimum value:", min_value)
print("Maximum value:", max_value)
# Out:
# Minimum value: 1
# Maximum value: 18325

# %%
# Count of turbines per state
turbines_per_state.sort_values(by='Count', ascending=False, inplace=True)
turbines_per_state.head(10)
# Out:
#   t_state  Count
# 0      TX  18325
# 1      IA   6284
# 2      OK   5344
# 3      KS   3927
# 4      CA   3857
# 5      IL   3557
# 6      CO   2825
# 7      MN   2700
# 8      OR   2113
# 9      ND   2086

# %%
# Get State Crosswalk From Generic Website
crosswalk = 'http://app02.clerk.org/menu/ccis/Help/CCIS%20Codes/state_codes.html'
states = pd.read_html(crosswalk)[0]

# Demo Crosswalking State Name to State Abbreviation
turbines_per_state['NAME'] = turbines_per_state['t_state'].map(dict(zip(states['Code'], states['Description'])))

turbines_per_state
# Out:
#    t_state  Count            NAME
# 0       TX  18325           Texas
# 1       IA   6284            Iowa
# 2       OK   5344        Oklahoma
# 3       KS   3927          Kansas
# 4       CA   3857      California
# 5       IL   3557        Illinois
# 6       CO   2825        Colorado
# 7       MN   2700       Minnesota
# 8       OR   2113          Oregon
# 9       ND   2086    North Dakota
# 10      NM   1923      New Mexico
# 11      WA   1822      Washington
# 12      MI   1637        Michigan
# 13      IN   1602         Indiana
# 14      NE   1480        Nebraska
# 15      WY   1358         Wyoming
# 16      SD   1327    South Dakota
# 17      NY   1270        New York
# 18      MO   1081        Missouri
# 19      MT    795         Montana
# 20      PA    751    Pennsylvania
# 21      ID    541           Idaho
# 22      OH    493            Ohio
# 23      WI    478       Wisconsin
# 24      WV    419   West Virginia
# 25      ME    416           Maine
# 26      AZ    324         Arizona
# 27      UT    205            Utah
# 28      HI    127          Hawaii
# 29      AK    122          Alaska
# 30      NC    104  North Carolina
# 31      MA     92   Massachusetts
# 32      NH     84   New Hampshire
# 33      MD     80        Maryland
# 34      VT     73         Vermont
# 35      NV     66          Nevada
# 36      PR     62     Puerto Rico
# 37      RI     35    Rhode Island
# 38      TN     18       Tennessee
# 39      NJ      6      New Jersey
# 40      CT      3     Connecticut
# 41      VA      2        Virginia
# 42      AR      1        Arkansas
# 43      DE      1        Delaware
# 44      GU      1            Guam

# %%
# # another GeoPandas use.
merged_data = us_states.merge(turbines_per_state, left_on='NAME', right_on='NAME', how='left')
merged_data
# Out:
#          GEO_ID STATE                  NAME LSAD  CENSUSAREA  \
# 0   0400000US01    01               Alabama        50645.326
# 1   0400000US02    02                Alaska       570640.950
# 2   0400000US04    04               Arizona       113594.084
# 3   0400000US05    05              Arkansas        52035.477
# 4   0400000US06    06            California       155779.220
# 5   0400000US08    08              Colorado       103641.888
# 6   0400000US09    09           Connecticut         4842.355
# 7   0400000US10    10              Delaware         1948.543
# 8   0400000US11    11  District of Columbia           61.048
# 9   0400000US12    12               Florida        53624.759
# 10  0400000US13    13               Georgia        57513.485
# 11  0400000US15    15                Hawaii         6422.628
# 12  0400000US16    16                 Idaho        82643.117
# 13  0400000US17    17              Illinois        55518.930
# 14  0400000US18    18               Indiana        35826.109
# 15  0400000US19    19                  Iowa        55857.130
# 16  0400000US20    20                Kansas        81758.717
# 17  0400000US21    21              Kentucky        39486.338
# 18  0400000US22    22             Louisiana        43203.905
# 19  0400000US23    23                 Maine        30842.923
# 20  0400000US24    24              Maryland         9707.241
# 21  0400000US25    25         Massachusetts         7800.058
# 22  0400000US26    26              Michigan        56538.901
# 23  0400000US27    27             Minnesota        79626.743
# 24  0400000US28    28           Mississippi        46923.274
# 25  0400000US29    29              Missouri        68741.522
# 26  0400000US30    30               Montana       145545.801
# 27  0400000US31    31              Nebraska        76824.171
# 28  0400000US32    32                Nevada       109781.180
# 29  0400000US33    33         New Hampshire         8952.651
# 30  0400000US34    34            New Jersey         7354.220
# 31  0400000US35    35            New Mexico       121298.148
# 32  0400000US36    36              New York        47126.399
# 33  0400000US37    37        North Carolina        48617.905
# 34  0400000US38    38          North Dakota        69000.798
# 35  0400000US39    39                  Ohio        40860.694
# 36  0400000US40    40              Oklahoma        68594.921
# 37  0400000US41    41                Oregon        95988.013
# 38  0400000US42    42          Pennsylvania        44742.703
# 39  0400000US44    44          Rhode Island         1033.814
# 40  0400000US45    45        South Carolina        30060.696
# 41  0400000US46    46          South Dakota        75811.000
# 42  0400000US47    47             Tennessee        41234.896
# 43  0400000US48    48                 Texas       261231.711
# 44  0400000US49    49                  Utah        82169.620
# 45  0400000US50    50               Vermont         9216.657
# 46  0400000US51    51              Virginia        39490.086
# 47  0400000US53    53            Washington        66455.521
# 48  0400000US54    54         West Virginia        24038.210
# 49  0400000US55    55             Wisconsin        54157.805
# 50  0400000US56    56               Wyoming        97093.141
# 51  0400000US72    72           Puerto Rico         3423.775
#
#                                              geometry t_state    Count
# 0   MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...     NaN      NaN
# 1   MULTIPOLYGON (((-166.10574 53.98861, -166.0752...      AK    122.0
# 2   POLYGON ((-112.53859 37.00067, -112.53454 37.0...      AZ    324.0
# 3   POLYGON ((-94.04296 33.01922, -94.04304 33.079...      AR      1.0
# 4   MULTIPOLYGON (((-122.42144 37.86997, -122.4213...      CA   3857.0
# 5   POLYGON ((-106.19055 40.99761, -106.06118 40.9...      CO   2825.0
# 6   POLYGON ((-71.79924 42.00807, -71.79792 41.935...      CT      3.0
# 7   MULTIPOLYGON (((-75.56493 39.58325, -75.57627 ...      DE      1.0
# 8   POLYGON ((-77.03860 38.79151, -77.03890 38.800...     NaN      NaN
# 9   MULTIPOLYGON (((-82.82158 27.96444, -82.82980 ...     NaN      NaN
# 10  POLYGON ((-84.81048 34.98761, -84.80918 34.987...     NaN      NaN
# 11  MULTIPOLYGON (((-155.77823 20.24574, -155.7727...      HI    127.0
# 12  POLYGON ((-111.04416 43.02005, -111.04413 43.0...      ID    541.0
# 13  POLYGON ((-89.36603 42.50027, -89.36156 42.500...      IL   3557.0
# 14  POLYGON ((-84.80248 40.52805, -84.80255 40.501...      IN   1602.0
# 15  POLYGON ((-91.21771 43.50055, -91.21827 43.497...      IA   6284.0
# 16  POLYGON ((-99.54112 36.99957, -99.55807 36.999...      KS   3927.0
# 17  MULTIPOLYGON (((-89.48511 36.49769, -89.49254 ...     NaN      NaN
# 18  MULTIPOLYGON (((-88.86507 29.75271, -88.88975 ...     NaN      NaN
# 19  MULTIPOLYGON (((-70.15259 43.74679, -70.15196 ...      ME    416.0
# 20  MULTIPOLYGON (((-76.04837 38.12055, -76.05681 ...      MD     80.0
# 21  MULTIPOLYGON (((-70.82740 41.60207, -70.82373 ...      MA     92.0
# 22  MULTIPOLYGON (((-85.82595 45.40430, -85.83352 ...      MI   1637.0
# 23  POLYGON ((-92.20469 46.70404, -92.20569 46.702...      MN   2700.0
# 24  MULTIPOLYGON (((-89.09562 30.23177, -89.07726 ...     NaN      NaN
# 25  POLYGON ((-89.54501 36.33681, -89.56044 36.337...      MO   1081.0
# 26  POLYGON ((-105.03840 45.00035, -105.07661 45.0...      MT    795.0
# 27  POLYGON ((-104.05325 41.00141, -104.05316 41.0...      NE   1480.0
# 28  POLYGON ((-114.04215 40.99993, -114.04318 40.7...      NV     66.0
# 29  POLYGON ((-72.45210 43.16141, -72.45187 43.170...      NH     84.0
# 30  POLYGON ((-75.21088 39.86571, -75.21043 39.865...      NJ      6.0
# 31  POLYGON ((-105.99800 32.00233, -106.09976 32.0...      NM   1923.0
# 32  MULTIPOLYGON (((-74.04086 40.70012, -74.04002 ...      NY   1270.0
# 33  MULTIPOLYGON (((-75.75377 35.19961, -75.74522 ...      NC    104.0
# 34  POLYGON ((-98.72437 45.93869, -98.90443 45.939...      ND   2086.0
# 35  MULTIPOLYGON (((-82.83512 41.70897, -82.82572 ...      OH    493.0
# 36  POLYGON ((-96.94461 33.94922, -96.95231 33.944...      OK   5344.0
# 37  POLYGON ((-121.92224 45.64908, -121.90827 45.6...      OR   2113.0
# 38  POLYGON ((-79.91617 39.72089, -80.07595 39.721...      PA    751.0
# 39  MULTIPOLYGON (((-71.38359 41.46478, -71.38928 ...      RI     35.0
# 40  POLYGON ((-79.29075 33.11005, -79.29159 33.109...     NaN      NaN
# 41  POLYGON ((-104.05449 44.18038, -104.05539 44.2...      SD   1327.0
# 42  POLYGON ((-83.47211 36.59728, -83.37490 36.597...      TN     18.0
# 43  MULTIPOLYGON (((-97.13436 27.89633, -97.13360 ...      TX  18325.0
# 44  POLYGON ((-111.04655 41.25172, -111.04672 40.9...      UT    205.0
# 45  POLYGON ((-72.43380 43.23300, -72.43447 43.230...      VT     73.0
# 46  MULTIPOLYGON (((-75.97361 37.83582, -75.97171 ...      VA      2.0
# 47  MULTIPOLYGON (((-122.51954 48.28831, -122.5227...      WA   1822.0
# 48  POLYGON ((-80.07595 39.72135, -79.91617 39.720...      WV    419.0
# 49  MULTIPOLYGON (((-90.40331 47.02669, -90.40332 ...      WI    478.0
# 50  POLYGON ((-110.04848 40.99755, -110.12164 40.9...      WY   1358.0
# 51  MULTIPOLYGON (((-65.32770 18.29584, -65.33745 ...      PR     62.0

# %%
# We need to remove some data to make a nice figure

merged_data = merged_data.drop([1,8,11,51])

# %%
# We need to add some data to make a nice figure

merged_data = merged_data.fillna(0)

# %%
# This code allows you to see if you have a GeoPandas dataframe

if isinstance(merged_data, gpd.GeoDataFrame):
    print("It's a GeoPandas DataFrame.")
else:
    print("It's a regular pandas DataFrame.")
# Out:
# It's a GeoPandas DataFrame.

# %%
fig, ax = plt.subplots(1, 1, figsize=(14, 8))

merged_data.plot(column='Count', cmap='viridis_r', linewidth=0.1, ax=ax, edgecolor='black', legend=True)

ax.set_axis_off()
 
plt.title('Wind Turbine Distribution for the United States of America')

plt.show()

# %%
# Let's replot but remove data for Texas
merged_data.at[43, 'Count'] = 0  # Replace the value at row 0, column 'A' with 10
merged_data.head(5)
# Out:
#         GEO_ID STATE        NAME LSAD  CENSUSAREA  \
# 0  0400000US01    01     Alabama        50645.326
# 2  0400000US04    04     Arizona       113594.084
# 3  0400000US05    05    Arkansas        52035.477
# 4  0400000US06    06  California       155779.220
# 5  0400000US08    08    Colorado       103641.888
#
#                                             geometry t_state   Count
# 0  MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...       0     0.0
# 2  POLYGON ((-112.53859 37.00067, -112.53454 37.0...      AZ   324.0
# 3  POLYGON ((-94.04296 33.01922, -94.04304 33.079...      AR     1.0
# 4  MULTIPOLYGON (((-122.42144 37.86997, -122.4213...      CA  3857.0
# 5  POLYGON ((-106.19055 40.99761, -106.06118 40.9...      CO  2825.0

# %%
fig, ax = plt.subplots(1, 1, figsize=(14, 8))

merged_data.plot(column='Count', cmap='viridis_r', linewidth=0.1, ax=ax, edgecolor='black', legend=True)

ax.set_axis_off()
 
plt.title('Wind Turbine Distribution for the United States of America' '\n' 'Excluding Texas')

plt.show()

# %%
# Let's replot but remove data for Texas, Iowa and Oklahoma (the top three window produces)

merged_data.at[15, 'Count'] = 0  # Replace the value at row 0, column 'A' with 10
merged_data.at[36, 'Count'] = 0  # Replace the value at row 0, column 'A' with 10
merged_data.head(5)
# Out:
#         GEO_ID STATE        NAME LSAD  CENSUSAREA  \
# 0  0400000US01    01     Alabama        50645.326
# 2  0400000US04    04     Arizona       113594.084
# 3  0400000US05    05    Arkansas        52035.477
# 4  0400000US06    06  California       155779.220
# 5  0400000US08    08    Colorado       103641.888
#
#                                             geometry t_state   Count
# 0  MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...       0     0.0
# 2  POLYGON ((-112.53859 37.00067, -112.53454 37.0...      AZ   324.0
# 3  POLYGON ((-94.04296 33.01922, -94.04304 33.079...      AR     1.0
# 4  MULTIPOLYGON (((-122.42144 37.86997, -122.4213...      CA  3857.0
# 5  POLYGON ((-106.19055 40.99761, -106.06118 40.9...      CO  2825.0

# %%
fig, ax = plt.subplots(1, 1, figsize=(14, 8))

merged_data.plot(column='Count', cmap='viridis_r', linewidth=0.1, ax=ax, edgecolor='black', legend=True)

ax.set_axis_off()
 
plt.title('Wind Turbine Distribution for the United States of America' '\n' 'Excluding Texas, Iowa and Oklahoma')

plt.show()

# %%
# Who is making all the wind turbines 
manufacturer_counts = df['t_manu'].value_counts().reset_index()
manufacturer_counts.columns = ['t_manu', 'Count']
manufacturer_counts.head(50)
# Out:
#                              t_manu  Count
# 0                           GE Wind  32693
# 1                            Vestas  17043
# 2                           Siemens   5164
# 3                            Gamesa   3037
# 4                        Mitsubishi   2371
# 5   Siemens Gamesa Renewable Energy   2247
# 6                            Nordex   1822
# 7                            Suzlon   1316
# 8                           Acciona    758
# 9                           REpower    574
# 10                        NEG Micon    444
# 11                            Enron    396
# 12                            Bonus    305
# 13                          Clipper    279
# 14                         Nordtank    232
# 15                            Micon    211
# 16                         Goldwind    195
# 17           Northern Power Systems     97
# 18                             Zond     85
# 19                Goldwind Americas     48
# 20                           DeWind     34
# 21                           Vensys     32
# 22                           Alstom     24
# 23                             Sany     21
# 24                       Fuhrlander     19
# 25                        Entegrity     17
# 26       China Creative Wind Energy     17
# 27                     HZ Windpower     16
# 28                          NedWind     13
# 29                              EWT     13
# 30                              AOC     12
# 31                         Seaforth     12
# 32                          Vergnet      9
# 33                              RRB      8
# 34                        PowerWind      8
# 35                        Windmatic      6
# 36                          Guodian      6
# 37                      Aeronautica      5
# 38                             AAER      4
# 39                          Sinovel      4
# 40                          Hyundai      4
# 41                           Nordic      4
# 42                        Endurance      4
# 43                          Samsung      3
# 44                       Turbowinds      3
# 45                     Westinghouse      2
# 46                           Elecon      2
# 47                             Siva      2
# 48                              AWE      2
# 49                          Lolland      2

# %%
# Filter the DataFrame to keep only the rows that you want to plot
manufacturer_counts_filtered = manufacturer_counts.loc[0:16]
print(manufacturer_counts_filtered['t_manu'].to_string(index=False))
# Out:
#                         GE Wind
#                          Vestas
#                         Siemens
#                          Gamesa
#                      Mitsubishi
# Siemens Gamesa Renewable Energy
#                          Nordex
#                          Suzlon
#                         Acciona
#                         REpower
#                       NEG Micon
#                           Enron
#                           Bonus
#                         Clipper
#                        Nordtank
#                           Micon
#                        Goldwind

# %%
# Get the top 10 manufacturers and their counts
top_5 = manufacturer_counts.head(5)

# Sum the counts of the remaining manufacturers
other_count = manufacturer_counts['Count'][5:].sum()

# Create a new DataFrame for the top 10 manufacturers and 'OTHER'
top_manufacturers = top_5._append({'t_manu': 'OTHER', 'Count': other_count}, ignore_index=True)

# Create a pie chart for the top 5 manufacturers
plt.figure(figsize=(8, 8))
plt.pie(top_manufacturers['Count'], labels=top_manufacturers['t_manu'], autopct='%1.1f%%', pctdistance=0.85, startangle=140)
plt.axis('equal')
plt.title('Top 10 Manufacturers (and OTHER)')

# Show the pie chart
plt.show()

# %%
# How much power could the turbines generate
result_df = df.groupby('t_state')['t_cap'].sum().reset_index()
result_df = result_df.sort_values(by='t_cap', ascending=False)
result_df
# Out:
#    t_state     t_cap
# 37      TX  40383434
# 9       IA  12774302
# 30      OK  12174370
# 13      KS   8238120
# 11      IL   7442408
# 3       CA   5853946
# 4       CO   5183980
# 18      MN   4731885
# 26      NM   4311635
# 22      ND   4260480
# 31      OR   4024410
# 17      MI   3540170
# 23      NE   3452060
# 12      IN   3432580
# 41      WA   3395850
# 35      SD   3160674
# 44      WY   3088870
# 28      NY   2530960
# 19      MO   2390350
# 20      MT   1481520
# 32      PA   1459000
# 29      OH   1104180
# 16      ME   1027400
# 10      ID    972500
# 43      WV    857000
# 2       AZ    852000
# 42      WI    827770
# 38      UT    390675
# 8       HI    236460
# 24      NH    214150
# 21      NC    208000
# 15      MD    191050
# 27      NV    151800
# 40      VT    149600
# 33      PR    125925
# 14      MA    125180
# 34      RI     79385
# 0       AK     67950
# 36      TN     28980
# 39      VA     12000
# 25      NJ      9000
# 5       CT      5800
# 6       DE      2000
# 7       GU       275
# 1       AR       100

# %%
windiest_states = pd.read_csv("C:/Users/mford.MSBIOWORKS/Project_1/windiest-states-2024.csv")
# print(monthly_energy_production_df)
windiest_states.head(5)
# Out:
#    fips       state  densityMi   pop2024   pop2023   pop2020     pop2019  \
# 0     1     Alabama  101.15897   5123196   5098746   5031362   5006199.4
# 1     2      Alaska    1.28344    732385    732984    732923    730653.8
# 2     4     Arizona   66.44574   7547837   7453517   7179943   7101150.4
# 3     5    Arkansas   59.20375   3080667   3063152   3014195   3004367.3
# 4     6  California  249.08392  38802044  38915693  39501653  39276883.3
#
#     pop2010  growthRate  growth  growthSince2010  \
# 0   4779736     0.00480   24450          0.07186
# 1    710231    -0.00082    -599          0.03119
# 2   6392017     0.01265   94320          0.18082
# 3   2915918     0.00572   17515          0.05650
# 4  37253956    -0.00292 -113649          0.04155
#
#    WindiestStatesAverageWindSpeedMPH  MeanWindSpeed328ft  MeanWindPower328ft  \
# 0                              14.70                15.5                 341
# 1                              16.35                21.9                1611
# 2                              15.92                14.5                 355
# 3                              16.44                16.7                 421
# 4                              13.54                16.6                 649
#
#    MeanWindSpeed33ft
# 0                9.1
# 1               16.3
# 2                8.7
# 3                9.7
# 4               10.7

# %%
windiest_states = windiest_states.rename(columns={'state': 'NAME'})

# %%
wind_turbine_count = turbines_per_state.merge(windiest_states, on = 'NAME')
wind_turbine_count
# Out:
#    t_state  Count            NAME  fips   densityMi   pop2024   pop2023  \
# 0       TX  18325           Texas    48   118.55740  30970988  30500280
# 1       IA   6284            Iowa    19    57.39966   3206173   3203345
# 2       OK   5344        Oklahoma    40    59.43509   4076950   4048375
# 3       KS   3927          Kansas    20    35.90560   2935606   2936378
# 4       CA   3857      California     6   249.08392  38802044  38915693
# 5       IL   3557        Illinois    17   222.86349  12373158  12477595
# 6       CO   2825        Colorado     8    56.89956   5897184   5868555
# 7       MN   2700       Minnesota    27    71.94306   5728610   5722897
# 8       OR   2113          Oregon    41    43.83682   4207809   4223973
# 9       ND   2086    North Dakota    38    11.33194    781915    780588
# 10      NM   1923      New Mexico    35    17.36779   2106678   2110011
# 11      WA   1822      Washington    53   118.51252   7875868   7830827
# 12      MI   1637        Michigan    26   177.35246  10027331  10030722
# 13      IN   1602         Indiana    18   191.81731   6872047   6852542
# 14      NE   1480        Nebraska    31    25.72973   1976661   1972292
# 15      WY   1358         Wyoming    56     6.02697    585177    583279
# 16      SD   1327    South Dakota    46    12.36158    937144    923484
# 17      NY   1270        New York    36   409.88985  19316469  19496810
# 18      MO   1081        Missouri    29    90.10830   6194225   6186091
# 19      MT    795         Montana    30     7.94352   1156147   1139507
# 20      PA    751    Pennsylvania    42   288.13236  12891906  12931957
# 21      ID    541           Idaho    16    24.30298   2008471   1973752
# 22      OH    493            Ohio    39   287.30305  11739490  11747774
# 23      WI    478       Wisconsin    55   109.26207   5917415   5904977
# 24      WV    419   West Virginia    54    72.98511   1754416   1764786
# 25      ME    416           Maine    23    45.44123   1401544   1393442
# 26      AZ    324         Arizona     4    66.44574   7547837   7453517
# 27      UT    205            Utah    49    42.15862   3464174   3422487
# 28      HI    127          Hawaii    15   222.05823   1426280   1433238
# 29      AK    122          Alaska     2     1.28344    732385    732984
# 30      NC    104  North Carolina    37   225.53682  10965149  10832061
# 31      MA     92   Massachusetts    25   893.14641   6966542   6974258
# 32      NH     84   New Hampshire    33   157.56540   1410683   1402957
# 33      MD     80        Maryland    24   633.02359   6144760   6154710
# 34      VT     73         Vermont    50    70.22328    647248    647156
# 35      NV     66          Nevada    32    29.51797   3240512   3209142
# 36      RI     35    Rhode Island    44  1051.48162   1087232   1090483
# 37      TN     18       Tennessee    47   175.02886   7217315   7134327
# 38      NJ      6      New Jersey    34  1257.70669   9249175   9255437
# 39      CT      3     Connecticut     9   750.08364   3631905   3629055
# 40      VA      2        Virginia    51   221.22378   8736127   8709873
# 41      AR      1        Arkansas     5    59.20375   3080667   3063152
# 42      DE      1        Delaware    10   536.46691   1045574   1031985
#
#      pop2020     pop2019   pop2010  growthRate  growth  growthSince2010  \
# 0   29232474  28823782.7  25145561     0.01543  470708          0.23167
# 1    3190571   3176149.4   3046355     0.00088    2828          0.05246
# 2    3964912   3943555.9   3751351     0.00706   28575          0.08680
# 3    2937919   2929438.9   2853118    -0.00026    -772          0.02891
# 4   39501653  39276883.3  37253956    -0.00292 -113649          0.04155
# 5   12786580  12790985.2  12830632    -0.00837 -104437         -0.03565
# 6    5784865   5709298.1   5029196     0.00488   28629          0.17259
# 7    5709852   5669259.3   5303925     0.00100    5713          0.08007
# 8    4244795   4203422.9   3831074    -0.00383  -16164          0.09834
# 9     779518    768825.3    672591     0.00170    1327          0.16254
# 10   2118390   2112468.9   2059179    -0.00158   -3333          0.02307
# 11   7724031   7624081.9   6724540     0.00575   45041          0.17121
# 12  10069577  10050983.3   9883640    -0.00034   -3391          0.01454
# 13   6788799   6758299.3   6483802     0.00285   19505          0.05988
# 14   1962642   1949011.9   1826341     0.00222    4369          0.08231
# 15    577605    576207.1    563626     0.00325    1898          0.03824
# 16    887799    880437.1    814180     0.01479   13660          0.15103
# 17  20108296  20035276.6  19378102    -0.00925 -180341         -0.00318
# 18   6153998   6137490.9   5988927     0.00131    8134          0.03428
# 19   1087075   1077309.0    989415     0.01460   16640          0.16852
# 20  12994440  12965233.9  12702379    -0.00310  -40051          0.01492
# 21   1849202   1821040.0   1567582     0.01759   34719          0.28125
# 22  11797517  11771415.7  11536504    -0.00071   -8284          0.01760
# 23   5896271   5875342.5   5686986     0.00211   12438          0.04052
# 24   1791420   1797577.4   1852994    -0.00588  -10370         -0.05320
# 25   1363557   1360037.4   1328361     0.00581    8102          0.05509
# 26   7179943   7101150.4   6392017     0.01265   94320          0.18082
# 27   3283785   3231795.0   2763885     0.01218   41687          0.25337
# 28   1451043   1441968.8   1360301    -0.00485   -6958          0.04850
# 29    732923    730653.8    710231    -0.00082    -599          0.03119
# 30  10449445  10358048.8   9535483     0.01229  133088          0.14993
# 31   6995729   6950919.0   6547629    -0.00111   -7716          0.06398
# 32   1378587   1372375.3   1316470     0.00551    7726          0.07156
# 33   6173205   6133239.7   5773552    -0.00162   -9950          0.06429
# 34    642893    641177.8    625741     0.00014      92          0.03437
# 35   3115648   3074138.3   2700551     0.00978   31370          0.19994
# 36   1096345   1091967.2   1052567    -0.00298   -3251          0.03293
# 37   6925619   6867667.6   6346105     0.01163   82988          0.13728
# 38   9271689   9223709.5   8791894    -0.00068   -6262          0.05201
# 39   3597362   3595035.5   3574097     0.00079    2850          0.01617
# 40   8636471   8572926.3   8001024     0.00301   26254          0.09188
# 41   3014195   3004367.3   2915918     0.00572   17515          0.05650
# 42    992114    982696.0    897934     0.01317   13589          0.16442
#
#     WindiestStatesAverageWindSpeedMPH  MeanWindSpeed328ft  MeanWindPower328ft  \
# 0                               15.55                19.2                 553
# 1                               18.09                18.6                 542
# 2                               16.46                20.2                 683
# 3                               19.30                19.9                 657
# 4                               13.54                16.6                 649
# 5                               18.28                18.1                 538
# 6                               20.16                20.0                 751
# 7                               18.51                18.9                 592
# 8                               16.39                16.2                 523
# 9                               18.80                19.6                 660
# 10                              17.82                19.2                 560
# 11                              15.03                17.0                 686
# 12                              17.50                20.9                 880
# 13                              17.84                17.5                 490
# 14                              18.51                20.5                 692
# 15                              20.88                21.5                 964
# 16                              21.32                20.3                 722
# 17                              15.57                19.1                 705
# 18                              19.31                18.8                 541
# 19                              21.03                20.5                 985
# 20                              17.42                17.1                 489
# 21                              20.59                16.5                 472
# 22                              16.16                19.4                 740
# 23                              18.40                20.2                 807
# 24                              18.72                17.0                 583
# 25                              16.95                17.3                 545
# 26                              15.92                14.5                 355
# 27                              18.26                15.6                 431
# 28                              14.03                19.9                 717
# 29                              16.35                21.9                1611
# 30                              17.99                16.7                 501
# 31                              15.76                18.4                 631
# 32                              17.13                17.7                 690
# 33                              19.74                17.7                 556
# 34                              18.07                17.7                 610
# 35                              17.43                15.6                 445
# 36                              14.91                18.1                 572
# 37                              17.43                16.2                 447
# 38                              14.33                17.2                 474
# 39                              13.97                15.9                 394
# 40                              19.32                17.2                 567
# 41                              16.44                16.7                 421
# 42                              12.91                17.5                 482
#
#     MeanWindSpeed33ft
# 0                11.7
# 1                11.1
# 2                12.5
# 3                12.3
# 4                10.7
# 5                11.6
# 6                12.8
# 7                12.4
# 8                 9.9
# 9                12.3
# 10               11.8
# 11               11.3
# 12               16.3
# 13               10.4
# 14               12.9
# 15               14.1
# 16               12.8
# 17               13.8
# 18               11.3
# 19               13.5
# 20                9.4
# 21               10.6
# 22               15.0
# 23               15.7
# 24                9.6
# 25               10.2
# 26                8.7
# 27                9.7
# 28               13.3
# 29               16.3
# 30               10.1
# 31               11.7
# 32                9.1
# 33               11.4
# 34               10.7
# 35                9.8
# 36               12.0
# 37                9.6
# 38               10.8
# 39                8.9
# 40               10.3
# 41                9.7
# 42               11.5

# %%
print(wind_turbine_count.columns)
# Out:
# Index(['t_state', 'Count', 'NAME', 'fips', 'densityMi', 'pop2024', 'pop2023',
#        'pop2020', 'pop2019', 'pop2010', 'growthRate', 'growth',
#        'growthSince2010', 'WindiestStatesAverageWindSpeedMPH',
#        'MeanWindSpeed328ft', 'MeanWindPower328ft', 'MeanWindSpeed33ft'],
#       dtype='object')

# %%
# Assuming 'wind_turbine_count' is your DataFrame
columns_to_delete = ['t_state', 'fips', 'densityMi', 'pop2024', 'pop2023', 'pop2020', 'pop2019', 'pop2010', 'growthRate', 'growth', 'growthSince2010', 'MeanWindSpeed328ft', 'MeanWindPower328ft', 'MeanWindSpeed33ft']
wind_turbine_count = wind_turbine_count.drop(columns=columns_to_delete)
wind_turbine_count
# Out:
#     Count            NAME  WindiestStatesAverageWindSpeedMPH
# 0   18325           Texas                              15.55
# 1    6284            Iowa                              18.09
# 2    5344        Oklahoma                              16.46
# 3    3927          Kansas                              19.30
# 4    3857      California                              13.54
# 5    3557        Illinois                              18.28
# 6    2825        Colorado                              20.16
# 7    2700       Minnesota                              18.51
# 8    2113          Oregon                              16.39
# 9    2086    North Dakota                              18.80
# 10   1923      New Mexico                              17.82
# 11   1822      Washington                              15.03
# 12   1637        Michigan                              17.50
# 13   1602         Indiana                              17.84
# 14   1480        Nebraska                              18.51
# 15   1358         Wyoming                              20.88
# 16   1327    South Dakota                              21.32
# 17   1270        New York                              15.57
# 18   1081        Missouri                              19.31
# 19    795         Montana                              21.03
# 20    751    Pennsylvania                              17.42
# 21    541           Idaho                              20.59
# 22    493            Ohio                              16.16
# 23    478       Wisconsin                              18.40
# 24    419   West Virginia                              18.72
# 25    416           Maine                              16.95
# 26    324         Arizona                              15.92
# 27    205            Utah                              18.26
# 28    127          Hawaii                              14.03
# 29    122          Alaska                              16.35
# 30    104  North Carolina                              17.99
# 31     92   Massachusetts                              15.76
# 32     84   New Hampshire                              17.13
# 33     80        Maryland                              19.74
# 34     73         Vermont                              18.07
# 35     66          Nevada                              17.43
# 36     35    Rhode Island                              14.91
# 37     18       Tennessee                              17.43
# 38      6      New Jersey                              14.33
# 39      3     Connecticut                              13.97
# 40      2        Virginia                              19.32
# 41      1        Arkansas                              16.44
# 42      1        Delaware                              12.91

# %%
correlation = wind_turbine_count['Count'].corr(wind_turbine_count['WindiestStatesAverageWindSpeedMPH'])

print(f'Correlation between Column1 and Column2: {correlation}')
# Out:
# Correlation between Column1 and Column2: -0.05504268151880325

# %%
wind_turbine_count.plot(x='Count', y='WindiestStatesAverageWindSpeedMPH', kind='scatter', title='Average Wind Speed (mph) vs Number of Turbines')
plt.show()
