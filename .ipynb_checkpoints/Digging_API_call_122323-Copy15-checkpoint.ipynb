# %%
import requests
import json
import pandas as pd

# %%
#Detailed view of electricity/electric-power-operational-data entry for EIA API. 
eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/data?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&data[]=generation&facets[fueltypeid][]=WND&facets[location][]=TX&frequency=monthly&sort[0][column]=period&sort[0][direction]=desc&facets[sectorid][]=99"

# %%
# Execute "GET" request with url
response_data = requests.get(eia_url)

# %%
# Print "response_data" variable
print(response_data)
# Out:
# <Response [200]>

# %%
# Store response using "content" attribute
response_content = response_data.content
print(response_content)
# Out:
# b'{"response":{"total":274,"dateFormat":"YYYY-MM","frequency":"monthly","data":[{"period":"2023-10","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":9773.33385,"generation-units":"thousand megawatthours"},{"period":"2023-09","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":8125.7154,"generation-units":"thousand megawatthours"},{"period":"2023-08","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":8783.25504,"generation-units":"thousand megawatthours"},{"period":"2023-07","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":9897.40967,"generation-units":"thousand megawatthours"},{"period":"2023-06","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":8979.36081,"generation-units":"thousand megawatthours"},{"period":"2023-05","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":8445.01374,"generation-units":"thousand megawatthours"},{"period":"2023-04","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":11385.38769,"generation-units":"thousand megawatthours"},{"period":"2023-03","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":12388.14098,"generation-units":"thousand megawatthours"},{"period":"2023-02","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":11130.62195,"generation-units":"thousand megawatthours"},{"period":"2023-01","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":11859.63363,"generation-units":"thousand megawatthours"},{"period":"2022-12","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":9646.75355,"generation-units":"thousand megawatthours"},{"period":"2022-11","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":9997.79827,"generation-units":"thousand megawatthours"},{"period":"2022-10","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":8218.15006,"generation-units":"thousand megawatthours"},{"period":"2022-09","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":6217.03186,"generation-units":"thousand megawatthours"},{"period":"2022-08","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":6668.02996,"generation-units":"thousand megawatthours"},{"period":"2022-07","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":9275.75002,"generation-units":"thousand megawatthours"},{"period":"2022-06","location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":10257.16316,"generation-units":"thousand megawatthours"},{"period":"2022-05","location":"TX","sta ...

# %%
# Format data as JSON
data = response_data.json()

# %%
# Use json.dumps with argument indent=4 to format data
print(json.dumps(data, indent=4))
# Out:
# {
#     "response": {
#         "total": 274,
#         "dateFormat": "YYYY-MM",
#         "frequency": "monthly",
#         "data": [
#             {
#                 "period": "2023-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9773.33385,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2023-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8125.7154,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2023-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8783.25504,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2023-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9897.40967,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2023-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8979.36081,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2023-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8445.01374,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2023-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 11385.38769,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2023-03",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12388.14098,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2023-02",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 11130.62195,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2023-01",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 11859.63363,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2022-12",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9646.75355,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2022-11",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9997.79827,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2022-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8218.15006,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2022-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6217.03186,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2022-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6668.02996,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2022-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9275.75002,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2022-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 10257.16316,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2022-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 13017.31015,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2022-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12494.23161,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2022-03",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 11319.14232,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2022-02",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8809.27047,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2022-01",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8866.27113,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2021-12",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 10121.13796,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2021-11",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8849.29424,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2021-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8850.32749,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2021-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6984.9333,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2021-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7374.59279,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2021-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5599.00704,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2021-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7228.13719,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2021-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9557.49122,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2021-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9517.51468,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2021-03",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 10969.98957,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2021-02",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6385.83811,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2021-01",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8035.95195,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2020-12",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8620.79109,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2020-11",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7981.28208,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2020-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7838.42748,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2020-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5522.44675,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2020-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6688.84143,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2020-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7276.25003,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2020-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8858.99278,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2020-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8314.06806,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2020-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7950.31501,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2020-03",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7699.45349,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2020-02",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7713.78517,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2020-01",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7976.34405,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2019-12",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7289.96162,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2019-11",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6989.79485,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2019-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7455.26004,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2019-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6516.64147,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2019-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6488.55596,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2019-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6730.66637,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2019-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6289.76109,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2019-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7762.19026,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2019-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7838.53038,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2019-03",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6694.24327,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2019-02",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6639.39823,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2019-01",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6925.36705,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2018-12",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6556.40936,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2018-11",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6073.54707,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2018-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5599.33735,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2018-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4164.62387,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2018-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5968.27419,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2018-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4647.1136,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2018-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7688.99776,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2018-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7671.80055,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2018-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7476.86188,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2018-03",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7209.9128,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2018-02",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6041.10297,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2018-01",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6602.45229,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2017-12",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5329.61529,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2017-11",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5894.79945,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2017-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6002.9634,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2017-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4754.44227,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2017-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3694.0053,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2017-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4511.09548,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2017-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4839.07385,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2017-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6310.01793,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2017-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6928.58128,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2017-03",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7095.2499,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2017-02",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5828.27402,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2017-01",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5872.87835,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2016-12",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5372.95198,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2016-11",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4516.30116,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2016-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5451.20877,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2016-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3915.41865,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2016-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3702.05462,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2016-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5674.9113,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2016-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3781.5647,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2016-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5172.88725,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2016-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4736.84338,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2016-03",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5635.2791,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2016-02",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 5120.44464,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2016-01",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4450.91844,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2015-12",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4984.23801,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2015-11",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4722.37236,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2015-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3660.71241,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2015-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3464.84232,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2015-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3217.83857,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2015-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4059.35964,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2015-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3410.8346,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2015-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4371.47879,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2015-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4098.79862,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2015-03",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2543.79907,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2015-02",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3267.79165,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2015-01",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3031.29897,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2014-12",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3321.82386,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2014-11",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3994.16741,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2014-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2981.19815,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2014-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2319.77147,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2014-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2550.91353,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2014-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2770.08988,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2014-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4209.45101,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2014-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3518.38624,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2014-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3996.69153,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
# ...
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 253.12394,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2003-12",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 286.351,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2003-11",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 227.643,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2003-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 168.134,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2003-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 196.229,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2003-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 192.641,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2003-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 239.586,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2003-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 213.226,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2003-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 209.163,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2003-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 260.324,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2003-03",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 215.447,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2003-02",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 190.098,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2003-01",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 171.01,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2002-12",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 203.936,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2002-11",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 170.311,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2002-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 173.421,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2002-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 163.651,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2002-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 247.536,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2002-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 218.034,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2002-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 257.712,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2002-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 264.416,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2002-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 236.924,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2002-03",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 238.396,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2002-02",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 194.607,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2002-01",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 287.16,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2001-12",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 142.904,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2001-11",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 89.264,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2001-10",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 123.255,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2001-09",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 75.75,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2001-08",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 55.825,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2001-07",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 76.348,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2001-06",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 92.156,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2001-05",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 103.312,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2001-04",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 115.487,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2001-03",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 87.631,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2001-02",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 141.647,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2001-01",
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 83.931,
#                 "generation-units": "thousand megawatthours"
#             }
#         ],
#         "description": "Monthly and annual electric power operations by state, sector, and energy source.\n    Source: Form EIA-923"
#     },
#     "request": {
#         "command": "/v2/electricity/electric-power-operational-data/data/",
#         "params": {
#             "api_key": "VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9",
#             "data": [
#                 "generation"
#             ],
#             "facets": {
#                 "fueltypeid": [
#                     "WND"
#                 ],
#                 "location": [
#                     "TX"
#                 ],
#                 "sectorid": [
#                     99
#                 ]
#             },
#             "frequency": "monthly",
#             "sort": [
#                 {
#                     "column": "period",
#                     "direction": "desc"
#                 }
#             ]
#         }
#     },
#     "apiVersion": "2.1.4"
# }

# %%
data = data['response']['data']
df = pd.json_normalize(data)

# Display the DataFrame
df
# Out:
#       period location stateDescription  sectorid sectorDescription fueltypeid  \
# 0    2023-10       TX            Texas        99       All Sectors        WND
# 1    2023-09       TX            Texas        99       All Sectors        WND
# 2    2023-08       TX            Texas        99       All Sectors        WND
# 3    2023-07       TX            Texas        99       All Sectors        WND
# 4    2023-06       TX            Texas        99       All Sectors        WND
# ..       ...      ...              ...       ...               ...        ...
# 269  2001-05       TX            Texas        99       All Sectors        WND
# 270  2001-04       TX            Texas        99       All Sectors        WND
# 271  2001-03       TX            Texas        99       All Sectors        WND
# 272  2001-02       TX            Texas        99       All Sectors        WND
# 273  2001-01       TX            Texas        99       All Sectors        WND
#
#     fuelTypeDescription  generation        generation-units
# 0                  wind  9773.33385  thousand megawatthours
# 1                  wind  8125.71540  thousand megawatthours
# 2                  wind  8783.25504  thousand megawatthours
# 3                  wind  9897.40967  thousand megawatthours
# 4                  wind  8979.36081  thousand megawatthours
# ..                  ...         ...                     ...
# 269                wind   103.31200  thousand megawatthours
# 270                wind   115.48700  thousand megawatthours
# 271                wind    87.63100  thousand megawatthours
# 272                wind   141.64700  thousand megawatthours
# 273                wind    83.93100  thousand megawatthours
#
# [274 rows x 9 columns]
