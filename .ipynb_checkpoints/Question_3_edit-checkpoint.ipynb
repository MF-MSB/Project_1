# %%
import pandas as pd
import geopandas as gpd
from geopy.geocoders import Nominatim
from shapely.geometry import Point
import matplotlib.pyplot as plt
import numpy as np
import requests
import json

# %%
#This call returns the monthly wind power generation data at a state and year level. 
eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/data?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&data[]=generation&facets[fueltypeid][]=WND&frequency=annual&sort[0][column]=period&sort[0][direction]=desc&facets[sectorid][]=99"

# %%
# Execute "GET" request with url
response_data = requests.get(eia_url)

# %%
# Print "response_data" variable
print(response_data)
# Out:
# <Response [200]>

# %%
response_content = response_data.content
print(response_content)
# Out:
# b'{"response":{"total":74,"dateFormat":"YYYY","frequency":"annual","data":[{"period":2022,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":831511.612,"unit":"Million Kilowatthours"},{"period":2021,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":897998.76,"unit":"Million Kilowatthours"},{"period":2020,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":773392.897,"unit":"Million Kilowatthours"},{"period":2019,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":964956.812,"unit":"Million Kilowatthours"},{"period":2018,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1149487.339,"unit":"Million Kilowatthours"},{"period":2017,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1205835.276,"unit":"Million Kilowatthours"},{"period":2016,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1239148.654,"unit":"Million Kilowatthours"},{"period":2015,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1352398.197,"unit":"Million Kilowatthours"},{"period":2014,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1581710.35,"unit":"Million Kilowatthours"},{"period":2013,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1581114.716,"unit":"Million Kilowatthours"},{"period":2012,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1514042.945,"unit":"Million Kilowatthours"},{"period":2011,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1733430.005,"unit":"Million Kilowatthours"},{"period":2010,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1847290.279,"unit":"Million Kilowatthours"},{"period":2009,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1755904.253,"unit":"Million Kilowatthours"},{"period":2008,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1985801.247,"unit":"Million Kilowatthours"},{"period":2007,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":2016455.584,"unit":"Million Kilowatthours"},{"period":2006,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1990511.135,"unit":"Million Kilowatthours"},{"period":2005,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":2012873.046,"unit":"Million Kilowatthours"},{"period":2004,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1978300.549,"unit":"Million Kilowatthours"},{"period":2003,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1973736.752,"unit":"Million Kilowatthours"},{"period":2002,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1933130.354,"unit":"Million Kilowatthours"},{"period":2001,"msn":"CLETPUS","seriesDescription":"Electricity Net Generation From Coal, All Sectors in Million Kilowatthours","value":1903955.942,"un ...

# %%
# Format data as JSON
data = response_data.json()

# %%
# Use json.dumps with argument indent=4 to format data
print(json.dumps(data, indent=4))
# Out:
# {
#     "response": {
#         "total": 74,
#         "dateFormat": "YYYY",
#         "frequency": "annual",
#         "data": [
#             {
#                 "period": 2022,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 831511.612,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2021,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 897998.76,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2020,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 773392.897,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2019,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 964956.812,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2018,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1149487.339,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2017,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1205835.276,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2016,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1239148.654,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2015,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1352398.197,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2014,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1581710.35,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2013,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1581114.716,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2012,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1514042.945,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2011,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1733430.005,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2010,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1847290.279,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2009,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1755904.253,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2008,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1985801.247,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2007,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 2016455.584,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2006,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1990511.135,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2005,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 2012873.046,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2004,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1978300.549,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2003,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1973736.752,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2002,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1933130.354,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2001,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1903955.942,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 2000,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1966264.596,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1999,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1881087.224,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1998,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1873515.69,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1997,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1845015.736,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1996,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1795195.593,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1995,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1709426.468,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1994,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1690693.864,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1993,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1690070.232,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1992,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1621206.039,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1991,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1590622.748,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1990,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1594011.479,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1989,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1583779.139,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1988,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1540652.774,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1987,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1463781.289,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1986,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1385831.452,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1985,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1402128.125,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1984,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1341680.752,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1983,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1259424.279,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1982,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1192004.204,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1981,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1203203.232,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1980,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1161562.368,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1979,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 1075037.091,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1978,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 975742.083,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1977,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 985218.596,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1976,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 944390.993,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1975,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 852786.222,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1974,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 828432.921,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1973,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 847651.47,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1972,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 771131.265,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1971,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 713102.454,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1970,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 704394.479,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1969,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 706001.24,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1968,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 684904.58,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1967,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 630483.363,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1966,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 613474.8,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1965,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 570925.951,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1964,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 526230.019,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1963,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 493926.719,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1962,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 450249.238,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1961,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 421870.669,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1960,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 403067.357,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1959,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 378424.21,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1958,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 344365.781,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1957,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 346386.207,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1956,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 338503.484,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1955,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 301362.698,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1954,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 239145.966,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1953,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 218846.325,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1952,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 195436.666,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1951,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 185203.657,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1950,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 154519.994,
#                 "unit": "Million Kilowatthours"
#             },
#             {
#                 "period": 1949,
#                 "msn": "CLETPUS",
#                 "seriesDescription": "Electricity Net Generation From Coal, All Sectors in Million Kilowatthours",
#                 "value": 135451.32,
#                 "unit": "Million Kilowatthours"
#             }
#         ],
#         "description": "These data represent the most recent comprehensive energy statistics integrated across all energy sources.  The data includes total energy production, consumption, stocks, and trade; energy prices; overviews of petroleum, natural gas, coal, electricity, nuclear energy, renewable energy, and carbon dioxide emissions; and data unit conversions values.  Source: https://www.eia.gov/totalenergy/data/monthly/pdf/mer_a_doc.pdf  Report:  MER (https://www.eia.gov/totalenergy/data/monthly/)"
#     },
#     "request": {
#         "command": "/v2/total-energy/data/",
#         "params": {
#             "api_key": "VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9",
#             "frequency": "annual",
#             "data": [
#                 "value"
#             ],
#             "facets": {
#                 "msn": [
#                     "CLETPUS"
#                 ]
#             },
#             "sort": [
#                 {
#                     "column": "period",
#                     "direction": "desc"
#                 }
#             ],
#             "offset": 0,
#             "length": 5000
#         }
#     },
#     "apiVersion": "2.1.5",
#     "ExcelAddInVersion": "2.1.0"
# }

# %%
data = data['response']['data']
df = pd.json_normalize(data)
# Display the DataFrame
df.tail(5)
# Out:
#     period      msn                                  seriesDescription  \
# 69    1953  CLETPUS  Electricity Net Generation From Coal, All Sect...
# 70    1952  CLETPUS  Electricity Net Generation From Coal, All Sect...
# 71    1951  CLETPUS  Electricity Net Generation From Coal, All Sect...
# 72    1950  CLETPUS  Electricity Net Generation From Coal, All Sect...
# 73    1949  CLETPUS  Electricity Net Generation From Coal, All Sect...
#
#          value                   unit
# 69  218846.325  Million Kilowatthours
# 70  195436.666  Million Kilowatthours
# 71  185203.657  Million Kilowatthours
# 72  154519.994  Million Kilowatthours
# 73  135451.320  Million Kilowatthours

# %%
data_types = df.dtypes
print(data_types)
# Out:
# period                   int64
# location                object
# stateDescription        object
# sectorid                 int64
# sectorDescription       object
# fueltypeid              object
# fuelTypeDescription     object
# generation             float64
# generation-units        object
# dtype: object

# %%
nan_count = df.isna().sum().sum()
print("Total NaN values in the DataFrame:", nan_count)
# Out:
# Total NaN values in the DataFrame: 6

# %%
df['generation'] = df['generation'].fillna(0)
df.head()
# Out:
#    period location       stateDescription  sectorid sectorDescription  \
# 0    2022       HI                 Hawaii        99       All Sectors
# 1    2022       CO               Colorado        99       All Sectors
# 2    2022       NV                 Nevada        99       All Sectors
# 3    2022      PCN  Pacific Noncontiguous        99       All Sectors
# 4    2022       AK                 Alaska        99       All Sectors
#
#   fueltypeid fuelTypeDescription   generation        generation-units
# 0        WND                wind    625.42187  thousand megawatthours
# 1        WND                wind  16911.12600  thousand megawatthours
# 2        WND                wind    315.55100  thousand megawatthours
# 3        WND                wind    764.69787  thousand megawatthours
# 4        WND                wind    139.27600  thousand megawatthours

# %%
unique_states = df['location'].unique()
print(unique_states)
# Out:
# ['HI' 'CO' 'NV' 'PCN' 'AK' 'NH' 'CT' 'IL' 'UT' 'AZ' 'MAT' 'NC' 'IA' 'VA'
#  'RI' 'PA' 'WY' 'PCC' 'OH' 'MN' 'SAT' 'PR' 'TN' 'ENC' 'CA' 'ME' 'MD' 'NJ'
#  'DE' 'ID' 'WV' 'TX' 'MT' 'MI' 'OR' 'MO' 90 'WNC' 'SD' 'WI' 'NEW' 'WSC'
#  'IN' 'NE' 'MA' 'MTN' 'NY' 'KS' 'WA' 'VT' 'NM' 'OK' 'US' 'ESC' 'ND']

# %%
unique_states = df['stateDescription'].unique()
print(unique_states)
# Out:
# ['Hawaii' 'Colorado' 'Nevada' 'Pacific Noncontiguous' 'Alaska'
#  'New Hampshire' 'Connecticut' 'Illinois' 'Utah' 'Arizona'
#  'Middle Atlantic' 'North Carolina' 'Iowa' 'Virginia' 'Rhode Island'
#  'Pennsylvania' 'Wyoming' 'Pacific Contiguous' 'Ohio' 'Minnesota'
#  'South Atlantic' 'Puerto Rico' 'Tennessee' 'East North Central'
#  'California' 'Maine' 'Maryland' 'New Jersey' 'Delaware' 'Idaho'
#  'West Virginia' 'Texas' 'Montana' 'Michigan' 'Oregon' 'Missouri'
#  'Pacific' 'West North Central' 'South Dakota' 'Wisconsin' 'New England'
#  'West South Central' 'Indiana' 'Nebraska' 'Massachusetts' 'Mountain'
#  'New York' 'Kansas' 'Washington' 'Vermont' 'New Mexico' 'Oklahoma'
#  'U.S. Total' 'East South Central' 'North Dakota']

# %%
new_df = df[['period', 'stateDescription', 'generation']]
new_df.tail(50)
# Out:
#      period       stateDescription  generation
# 901    2002               New York      81.626
# 902    2002     West North Central    2305.474
# 903    2002              Minnesota     905.839
# 904    2002                 Hawaii       1.614
# 905    2002     West South Central    2656.104
# 906    2002          Massachusetts       0.000
# 907    2002          West Virginia       9.023
# 908    2002             California    3802.645
# 909    2002               Michigan       0.329
# 910    2002  Pacific Noncontiguous       1.614
# 911    2002             Washington     416.581
# 912    2002             U.S. Total   10354.279
# 913    2002                Wyoming     447.330
# 914    2002                   Iowa     918.835
# 915    2002        Middle Atlantic     139.394
# 916    2002     Pacific Contiguous    4595.385
# 917    2002           Pennsylvania      57.768
# 918    2002              Tennessee       4.068
# 919    2002           South Dakota       6.043
# 920    2002                  Texas    2656.104
# 921    2001                  Texas    1187.510
# 922    2001              Minnesota     897.018
# 923    2001            New England      12.133
# 924    2001           South Dakota       0.871
# 925    2001                 Alaska       0.950
# 926    2001             Washington       0.000
# 927    2001        Middle Atlantic      31.714
# 928    2001     West South Central    1187.510
# 929    2001     East North Central      72.564
# 930    2001                   Iowa     487.864
# 931    2001     West North Central    1428.215
# 932    2001                 Kansas      39.832
# 933    2001               New York      20.539
# 934    2001              Tennessee       0.000
# 935    2001               Mountain     413.799
# 936    2001                 Hawaii       2.122
# 937    2001                Vermont      12.133
# 938    2001             California    3499.738
# 939    2001              Wisconsin      72.284
# 940    2001          Massachusetts       0.000
# 941    2001           Pennsylvania      11.175
# 942    2001                Wyoming     365.159
# 943    2001               Michigan       0.280
# 944    2001                 Oregon      88.587
# 945    2001     Pacific Contiguous    3588.325
# 946    2001               Colorado      48.640
# 947    2001     East South Central       0.000
# 948    2001  Pacific Noncontiguous       3.072
# 949    2001               Nebraska       2.630
# 950    2001             U.S. Total    6737.332

# %%
stateDescription_to_remove = ['Alaska', 'U.S. Total', 'New England','West South Central', 'Pacific Noncontiguous', 'Pacific Contiguous', 'Middle Atlantic', 'East North Central',  'East South Central', 'South Atlantic', 'Hawaii' ,'Mountain','Pacific' ,'West North Central','Puerto Rico']

new_df = new_df[~new_df['stateDescription'].isin(stateDescription_to_remove)]

new_df.head(50)
# Out:
#     period stateDescription    generation
# 1     2022         Colorado   16911.12600
# 2     2022           Nevada     315.55100
# 5     2022    New Hampshire     482.32200
# 6     2022      Connecticut      12.83308
# 7     2022         Illinois   23493.80554
# 8     2022             Utah     723.43900
# 9     2022          Arizona    1564.34800
# 11    2022   North Carolina     546.75500
# 12    2022             Iowa   45761.36955
# 13    2022         Virginia      50.85200
# 14    2022     Rhode Island     209.33800
# 15    2022     Pennsylvania    3572.24500
# 16    2022          Wyoming    9780.14100
# 18    2022             Ohio    3154.00700
# 19    2022        Minnesota   15091.22700
# 22    2022        Tennessee      14.86500
# 24    2022       California   14638.06100
# 25    2022            Maine    2716.38400
# 26    2022         Maryland     497.60800
# 27    2022       New Jersey      21.62900
# 28    2022         Delaware       4.37700
# 29    2022            Idaho    2441.68800
# 30    2022    West Virginia    2006.89500
# 31    2022            Texas  114786.90255
# 32    2022          Montana    4021.86000
# 33    2022         Michigan    9151.17900
# 34    2022           Oregon    8149.18841
# 35    2022         Missouri    7524.60500
# 38    2022     South Dakota   10295.11300
# 39    2022        Wisconsin    1815.72200
# 42    2022          Indiana    9985.20500
# 43    2022         Nebraska   12614.06100
# 44    2022    Massachusetts     215.68049
# 46    2022         New York    4567.50800
# 47    2022           Kansas   29687.47900
# 48    2022       Washington    8060.91200
# 49    2022          Vermont     409.18500
# 50    2022       New Mexico   14434.55068
# 51    2022         Oklahoma   37552.75500
# 54    2022     North Dakota   16249.88800
# 55    2021    West Virginia    1624.13600
# 57    2021          Arizona    1600.31900
# 58    2021    Massachusetts     208.62625
# 59    2021          Vermont     338.18800
# 60    2021        Minnesota   12271.31400
# 61    2021            Idaho    2680.20600
# 63    2021         Oklahoma   32540.31215
# 64    2021            Maine    2544.19700
# 66    2021           Nevada     339.94400
# 67    2021         New York    4156.36900

# %%
transposed_df = new_df.pivot(index='stateDescription', columns='period', values='generation')
transposed_df = transposed_df.reset_index()
transposed_df.columns.name = None
transposed_df.rename(columns={'stateDescription': 'State'}, inplace = True)
transposed_df = transposed_df.round(3)

# %%
transposed_df.head(50)
# Out:
#              State      2001      2002      2003      2004      2005  \
# 0          Arizona       NaN       NaN       NaN       NaN       NaN
# 1       California  3499.738  3802.645  3895.431  4305.875  4262.229
# 2         Colorado    48.640   139.006   147.109   220.141   776.234
# 3      Connecticut       NaN       NaN       NaN       NaN       NaN
# 4         Delaware       NaN       NaN       NaN       NaN       NaN
# 5            Idaho       NaN       NaN       NaN       NaN       NaN
# 6         Illinois       NaN       NaN    18.024    78.073   141.146
# 7          Indiana       NaN       NaN       NaN       NaN       NaN
# 8             Iowa   487.864   918.835   981.970  1049.952  1647.134
# 9           Kansas    39.832   466.679   365.939   358.632   425.823
# 10           Maine       NaN       NaN       NaN       NaN       NaN
# 11        Maryland       NaN       NaN       NaN       NaN       NaN
# 12   Massachusetts     0.000     0.000       NaN       NaN       NaN
# 13        Michigan     0.280     0.329     2.660     1.875     1.848
# 14       Minnesota   897.018   905.839   977.760   812.371  1582.477
# 15        Missouri       NaN       NaN       NaN       NaN       NaN
# 16         Montana       NaN       NaN       NaN       NaN       NaN
# 17        Nebraska     2.630     8.078    38.221    38.431    96.608
# 18          Nevada       NaN       NaN       NaN       NaN       NaN
# 19   New Hampshire       NaN       NaN       NaN       NaN       NaN
# 20      New Jersey       NaN       NaN       NaN       NaN       NaN
# 21      New Mexico       NaN       NaN   182.735   513.465   794.630
# 22        New York    20.539    81.626    41.201   116.450   102.990
# 23  North Carolina       NaN       NaN       NaN       NaN       NaN
# 24    North Dakota       NaN       NaN    58.878   214.523   220.345
# 25            Ohio       NaN       NaN     0.000       NaN    13.268
# 26        Oklahoma       NaN       NaN    54.470   572.744   847.773
# 27          Oregon    88.587   376.159   443.617   619.012   734.274
# 28    Pennsylvania    11.175    57.768   111.521   306.312   284.241
# 29    Rhode Island       NaN       NaN       NaN       NaN       NaN
# 30    South Dakota     0.871     6.043    44.249   157.678   158.104
# 31       Tennessee     0.000     4.068     3.933     3.813     3.339
# 32           Texas  1187.510  2656.104  2569.853  3137.690  4237.209
# 33            Utah       NaN       NaN       NaN       NaN       NaN
# 34         Vermont    12.133    10.372    10.829    11.364    11.486
# 35        Virginia       NaN       NaN       NaN       NaN       NaN
# 36      Washington     0.000   416.581   603.674   736.576   498.470
# 37   West Virginia       NaN     9.023   169.762   161.191   153.892
# 38       Wisconsin    72.284    46.180    97.580   103.563    92.544
# 39         Wyoming   365.159   447.330   366.478   616.515   717.264
#
#         2006      2007       2008       2009  ...       2013       2014  \
# 0        NaN       NaN        NaN     29.545  ...    449.764    468.115
# 1   4882.801  5584.933   5384.955   5839.813  ...  12822.060  12992.498
# 30   9326.617   10295.113
# 31     28.186      14.865
# 32  99474.216  114786.903
# 33    825.229     723.439
# 34    338.188     409.185
# 35     49.583      50.852
# 36   9297.756    8060.912
# 37   1624.136    2006.895
# 38   1593.479    1815.722
# 39   8447.860    9780.141
#
# [40 rows x 23 columns]

# %%
print(transposed_df.columns)
# Out:
# Index(['State',    2001,    2002,    2003,    2004,    2005,    2006,    2007,
#           2008,    2009,    2010,    2011,    2012,    2013,    2014,    2015,
#           2016,    2017,    2018,    2019,    2020,    2021,    2022],
#       dtype='object')

# %%
# Select the row with index 0 and Description "Coal Production"
# Filter the DataFrame for each type of production
California_row = transposed_df[(transposed_df.index == 1) & (transposed_df['State'] == 'California')]
Arizona_row = transposed_df[(transposed_df.index == 0) & (transposed_df['State'] == 'Arizona')]

# Extract the years and values for each production type
years = Arizona_row.columns[2:].astype(int)
California_values = California_row.values[:, 2:].flatten().astype(float)

# Create a line plot for each production type
plt.figure(figsize=(12, 6))
plt.plot(years, California_values, linestyle='-', color='r', label='California')
plt.title("Primary Energy Production by Wind Source")
plt.xlabel("Year")
plt.ylabel("Production Value (Quadrillion Btu)")
plt.grid(True)
plt.legend()

# Extend the x-axis by adding extra space on both ends
plt.xlim(years[0] - 5, years[-1] + 5)  # Adjust the numbers to control the extension

plt.show()

# %%
# Reset the index to make 'State' a column
transposed_df.reset_index(inplace=True)

# Create a new DataFrame with 'State' and '2022' columns
state_2022_df = transposed_df[['State', 2022]]

# Print the new DataFrame
state_2022_df.head()
# Out:
#          State       2022
# 0      Arizona   1564.348
# 1   California  14638.061
# 2     Colorado  16911.126
# 3  Connecticut     12.833
# 4     Delaware      4.377

# %%
print(state_2022_df.columns)
# Out:
# Index(['State', 2022], dtype='object')

# %%
# Iterate over column names and count characters
column_name_lengths = {str(col): len(str(col)) for col in state_2022_df.columns}

# Print the column name lengths
print(column_name_lengths)
# Out:
# {'State': 5, '2022': 4}

# %%
# state_2022_df.rename(columns={2022: '2022'}, inplace = True)

state_2022_df = state_2022_df.copy()
state_2022_df.rename(columns={2022: '2022'}, inplace=True)

# %%
new_rows = [
  {'State': 'South Carolina', '2022': 0},
  {'State': 'Florida', '2022': 0},
  {'State': 'Mississippi', '2022': 0},
  {'State': 'Louisiana', '2022': 0},
  {'State': 'District ofColumbia', '2022': 0},
  {'State': 'Kentucky', '2022': 0},
  {'State': 'Alabama', '2022': 0},
  {'State': 'Georgia', '2022': 0},
]

# Convert the list of dictionaries to a DataFrame
new_rows_df = pd.DataFrame(new_rows)

# Concatenate the original DataFrame and the new rows DataFrame
state_2022_df = pd.concat([state_2022_df, new_rows_df], ignore_index=True)

state_2022_df.head(50)
# Out:
#                   State        2022
# 0               Arizona    1564.348
# 1            California   14638.061
# 2              Colorado   16911.126
# 3           Connecticut      12.833
# 4              Delaware       4.377
# 5                 Idaho    2441.688
# 6              Illinois   23493.806
# 7               Indiana    9985.205
# 8                  Iowa   45761.370
# 9                Kansas   29687.479
# 10                Maine    2716.384
# 11             Maryland     497.608
# 12        Massachusetts     215.680
# 13             Michigan    9151.179
# 14            Minnesota   15091.227
# 15             Missouri    7524.605
# 16              Montana    4021.860
# 17             Nebraska   12614.061
# 18               Nevada     315.551
# 19        New Hampshire     482.322
# 20           New Jersey      21.629
# 21           New Mexico   14434.551
# 22             New York    4567.508
# 23       North Carolina     546.755
# 24         North Dakota   16249.888
# 25                 Ohio    3154.007
# 26             Oklahoma   37552.755
# 27               Oregon    8149.188
# 28         Pennsylvania    3572.245
# 29         Rhode Island     209.338
# 30         South Dakota   10295.113
# 31            Tennessee      14.865
# 32                Texas  114786.903
# 33                 Utah     723.439
# 34              Vermont     409.185
# 35             Virginia      50.852
# 36           Washington    8060.912
# 37        West Virginia    2006.895
# 38            Wisconsin    1815.722
# 39              Wyoming    9780.141
# 40       South Carolina       0.000
# 41              Florida       0.000
# 42          Mississippi       0.000
# 43            Louisiana       0.000
# 44  District ofColumbia       0.000
# 45             Kentucky       0.000
# 46              Alabama       0.000
# 47              Georgia       0.000

# %%
state_2022_df = state_2022_df.sort_values(by='State')

# Display the sorted DataFrame
state_2022_df.head(50)
# Out:
#                   State        2022
# 46              Alabama       0.000
# 0               Arizona    1564.348
# 1            California   14638.061
# 2              Colorado   16911.126
# 3           Connecticut      12.833
# 4              Delaware       4.377
# 44  District ofColumbia       0.000
# 41              Florida       0.000
# 47              Georgia       0.000
# 5                 Idaho    2441.688
# 6              Illinois   23493.806
# 7               Indiana    9985.205
# 8                  Iowa   45761.370
# 9                Kansas   29687.479
# 45             Kentucky       0.000
# 43            Louisiana       0.000
# 10                Maine    2716.384
# 11             Maryland     497.608
# 12        Massachusetts     215.680
# 13             Michigan    9151.179
# 14            Minnesota   15091.227
# 42          Mississippi       0.000
# 15             Missouri    7524.605
# 16              Montana    4021.860
# 17             Nebraska   12614.061
# 18               Nevada     315.551
# 19        New Hampshire     482.322
# 20           New Jersey      21.629
# 21           New Mexico   14434.551
# 22             New York    4567.508
# 23       North Carolina     546.755
# 24         North Dakota   16249.888
# 25                 Ohio    3154.007
# 26             Oklahoma   37552.755
# 27               Oregon    8149.188
# 28         Pennsylvania    3572.245
# 29         Rhode Island     209.338
# 40       South Carolina       0.000
# 30         South Dakota   10295.113
# 31            Tennessee      14.865
# 32                Texas  114786.903
# 33                 Utah     723.439
# 34              Vermont     409.185
# 35             Virginia      50.852
# 36           Washington    8060.912
# 37        West Virginia    2006.895
# 38            Wisconsin    1815.722
# 39              Wyoming    9780.141

# %%
state_2022_df = state_2022_df.reset_index(drop=True)

# %%
# Display the sorted DataFrame
state_2022_df.head(50)
# Out:
#                   State        2022
# 0               Alabama       0.000
# 1               Arizona    1564.348
# 2            California   14638.061
# 3              Colorado   16911.126
# 4           Connecticut      12.833
# 5              Delaware       4.377
# 6   District ofColumbia       0.000
# 7               Florida       0.000
# 8               Georgia       0.000
# 9                 Idaho    2441.688
# 10             Illinois   23493.806
# 11              Indiana    9985.205
# 12                 Iowa   45761.370
# 13               Kansas   29687.479
# 14             Kentucky       0.000
# 15            Louisiana       0.000
# 16                Maine    2716.384
# 17             Maryland     497.608
# 18        Massachusetts     215.680
# 19             Michigan    9151.179
# 20            Minnesota   15091.227
# 21          Mississippi       0.000
# 22             Missouri    7524.605
# 23              Montana    4021.860
# 24             Nebraska   12614.061
# 25               Nevada     315.551
# 26        New Hampshire     482.322
# 27           New Jersey      21.629
# 28           New Mexico   14434.551
# 29             New York    4567.508
# 30       North Carolina     546.755
# 31         North Dakota   16249.888
# 32                 Ohio    3154.007
# 33             Oklahoma   37552.755
# 34               Oregon    8149.188
# 35         Pennsylvania    3572.245
# 36         Rhode Island     209.338
# 37       South Carolina       0.000
# 38         South Dakota   10295.113
# 39            Tennessee      14.865
# 40                Texas  114786.903
# 41                 Utah     723.439
# 42              Vermont     409.185
# 43             Virginia      50.852
# 44           Washington    8060.912
# 45        West Virginia    2006.895
# 46            Wisconsin    1815.722
# 47              Wyoming    9780.141

# %%
# Load in json
gdf = gpd.read_file("C:/Users/mford.MSBIOWORKS/Project_1/gz_2010_us_040_00_5m.json")
# print(monthly_energy_production_df)
gdf.head(5)
# Out:
#         GEO_ID STATE        NAME LSAD  CENSUSAREA  \
# 0  0400000US01    01     Alabama        50645.326
# 1  0400000US02    02      Alaska       570640.950
# 2  0400000US04    04     Arizona       113594.084
# 3  0400000US05    05    Arkansas        52035.477
# 4  0400000US06    06  California       155779.220
#
#                                             geometry
# 0  MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...
# 1  MULTIPOLYGON (((-166.10574 53.98861, -166.0752...
# 2  POLYGON ((-112.53859 37.00067, -112.53454 37.0...
# 3  POLYGON ((-94.04296 33.01922, -94.04304 33.079...
# 4  MULTIPOLYGON (((-122.42144 37.86997, -122.4213...

# %%
value_to_delete = ['Alaska','Hawaii', 'Puerto Rico' ]
gdf = gdf[~gdf['NAME'].isin(value_to_delete)]

# %%
gdf.sort_values(by='NAME', ascending=True, inplace = True)
gdf.reset_index(drop=True, inplace=True)
gdf.head(5)
# Out:
#         GEO_ID STATE        NAME LSAD  CENSUSAREA  \
# 0  0400000US01    01     Alabama        50645.326
# 1  0400000US04    04     Arizona       113594.084
# 2  0400000US05    05    Arkansas        52035.477
# 3  0400000US06    06  California       155779.220
# 4  0400000US08    08    Colorado       103641.888
#
#                                             geometry
# 0  MULTIPOLYGON (((-88.12466 30.28364, -88.08681 ...
# 1  POLYGON ((-112.53859 37.00067, -112.53454 37.0...
# 2  POLYGON ((-94.04296 33.01922, -94.04304 33.079...
# 3  MULTIPOLYGON (((-122.42144 37.86997, -122.4213...
# 4  POLYGON ((-106.19055 40.99761, -106.06118 40.9...

# %%
# Merge the GeoDataFrame with your data based on a common column (e.g., 'State' column)
merged_data = gdf.merge(state_2022_df, left_on='NAME', right_on='State', how='left')

# %%
merged_data = merged_data.to_crs(epsg=3395)

fig, ax = plt.subplots(1, 1, figsize=(14, 8))

merged_data.plot(column='2022', cmap='viridis_r', linewidth=0.1, ax=ax, edgecolor='black', legend=True)

ax.set_axis_off()
 
plt.title('2022 Wind Turbine Electricity for the United States of America')

plt.show()
