# %%
import pandas as pd
import geopandas as gpd
from geopy.geocoders import Nominatim
from shapely.geometry import Point
import matplotlib.pyplot as plt
import numpy as np
import requests
import json

# %%
#This call returns the monthly wind power generation data at a state and year level. 
eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/data?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&data[]=generation&facets[fueltypeid][]=WND&frequency=annual&sort[0][column]=period&sort[0][direction]=desc&facets[sectorid][]=99"

# %%
# Execute "GET" request with url
response_data = requests.get(eia_url)

# %%
# Print "response_data" variable
print(response_data)
# Out:
# <Response [200]>

# %%
response_content = response_data.content
print(response_content)
# Out:
# b'{"response":{"total":951,"dateFormat":"YYYY","frequency":"annual","data":[{"period":2022,"location":"ND","stateDescription":"North Dakota","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":16249.888,"generation-units":"thousand megawatthours"},{"period":2022,"location":"TN","stateDescription":"Tennessee","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":14.865,"generation-units":"thousand megawatthours"},{"period":2022,"location":"ENC","stateDescription":"East North Central","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":47599.91854,"generation-units":"thousand megawatthours"},{"period":2022,"location":"NE","stateDescription":"Nebraska","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":12614.061,"generation-units":"thousand megawatthours"},{"period":2022,"location":"MTN","stateDescription":"Mountain","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":50192.70368,"generation-units":"thousand megawatthours"},{"period":2022,"location":"HI","stateDescription":"Hawaii","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":625.42187,"generation-units":"thousand megawatthours"},{"period":2022,"location":"VA","stateDescription":"Virginia","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":50.852,"generation-units":"thousand megawatthours"},{"period":2022,"location":"ID","stateDescription":"Idaho","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":2441.688,"generation-units":"thousand megawatthours"},{"period":2022,"location":"WV","stateDescription":"West Virginia","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":2006.895,"generation-units":"thousand megawatthours"},{"period":2022,"location":"OH","stateDescription":"Ohio","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":3154.007,"generation-units":"thousand megawatthours"},{"period":2022,"location":"RI","stateDescription":"Rhode Island","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":209.338,"generation-units":"thousand megawatthours"},{"period":2022,"location":"PA","stateDescription":"Pennsylvania","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":3572.245,"generation-units":"thousand megawatthours"},{"period":2022,"location":"AZ","stateDescription":"Arizona","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":1564.348,"generation-units":"thousand megawatthours"},{"period":2022,"location":"WA","stateDescription":"Washington","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":8060.912,"generation-units":"thousand megawatthours"},{"period":2022,"location":"VT","stateDescription":"Vermont","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":409.185,"generation-units":"thousand megawatthours"},{"period":2022,"location":"NY","stateDescription":"New York","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":4567.508,"generation-units":"thousand megawatthours"},{"period":2022,"location":"TX","stateDescription":"Texas","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":114786.90255,"generation-units":"thousand megawatthours"},{"period":2022,"location":"ESC","stateDescription":"East South Central","sectorid":99,"sect ...

# %%
# Format data as JSON
data = response_data.json()

# %%
# Use json.dumps with argument indent=4 to format data
print(json.dumps(data, indent=4))
# Out:
# {
#     "response": {
#         "total": 951,
#         "dateFormat": "YYYY",
#         "frequency": "annual",
#         "data": [
#             {
#                 "period": 2022,
#                 "location": "ND",
#                 "stateDescription": "North Dakota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 16249.888,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "TN",
#                 "stateDescription": "Tennessee",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 14.865,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "ENC",
#                 "stateDescription": "East North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 47599.91854,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NE",
#                 "stateDescription": "Nebraska",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12614.061,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MTN",
#                 "stateDescription": "Mountain",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 50192.70368,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "HI",
#                 "stateDescription": "Hawaii",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 625.42187,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "VA",
#                 "stateDescription": "Virginia",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 50.852,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "ID",
#                 "stateDescription": "Idaho",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2441.688,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "WV",
#                 "stateDescription": "West Virginia",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2006.895,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "OH",
#                 "stateDescription": "Ohio",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3154.007,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "RI",
#                 "stateDescription": "Rhode Island",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 209.338,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "PA",
#                 "stateDescription": "Pennsylvania",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3572.245,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "AZ",
#                 "stateDescription": "Arizona",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1564.348,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "WA",
#                 "stateDescription": "Washington",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8060.912,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "VT",
#                 "stateDescription": "Vermont",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 409.185,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NY",
#                 "stateDescription": "New York",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4567.508,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 114786.90255,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "ESC",
#                 "stateDescription": "East South Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 14.865,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NM",
#                 "stateDescription": "New Mexico",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 14434.55068,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "KS",
#                 "stateDescription": "Kansas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 29687.479,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "US",
#                 "stateDescription": "U.S. Total",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 434297.35817,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "SAT",
#                 "stateDescription": "South Atlantic",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3106.487,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "OK",
#                 "stateDescription": "Oklahoma",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 37552.755,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NEW",
#                 "stateDescription": "New England",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4045.74257,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "CO",
#                 "stateDescription": "Colorado",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 16911.126,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "IA",
#                 "stateDescription": "Iowa",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 45761.36955,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "PCN",
#                 "stateDescription": "Pacific Noncontiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 764.69787,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "AK",
#                 "stateDescription": "Alaska",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 139.276,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NV",
#                 "stateDescription": "Nevada",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 315.551,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "PR",
#                 "stateDescription": "Puerto Rico",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 155.009,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "WSC",
#                 "stateDescription": "West South Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 152339.65755,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "OR",
#                 "stateDescription": "Oregon",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8149.18841,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NC",
#                 "stateDescription": "North Carolina",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 546.755,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NH",
#                 "stateDescription": "New Hampshire",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 482.322,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "WY",
#                 "stateDescription": "Wyoming",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9780.141,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "CA",
#                 "stateDescription": "California",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 14638.061,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "CT",
#                 "stateDescription": "Connecticut",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12.83308,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "IL",
#                 "stateDescription": "Illinois",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 23493.80554,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "UT",
#                 "stateDescription": "Utah",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 723.439,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7524.605,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MD",
#                 "stateDescription": "Maryland",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 497.608,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "ME",
#                 "stateDescription": "Maine",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2716.384,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MAT",
#                 "stateDescription": "Middle Atlantic",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8161.382,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MT",
#                 "stateDescription": "Montana",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4021.86,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MN",
#                 "stateDescription": "Minnesota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 15091.227,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": 90,
#                 "stateDescription": "Pacific",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 31612.85928,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "WNC",
#                 "stateDescription": "West North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 137223.74255,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "SD",
#                 "stateDescription": "South Dakota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 10295.113,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NJ",
#                 "stateDescription": "New Jersey",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 21.629,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "DE",
#                 "stateDescription": "Delaware",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4.377,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "PCC",
#                 "stateDescription": "Pacific Contiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 30848.16141,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "WI",
#                 "stateDescription": "Wisconsin",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1815.722,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MI",
#                 "stateDescription": "Michigan",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9151.179,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MA",
#                 "stateDescription": "Massachusetts",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 215.68049,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "IN",
#                 "stateDescription": "Indiana",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9985.205,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "WNC",
#                 "stateDescription": "West North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 115451.48663,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NJ",
#                 "stateDescription": "New Jersey",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 19.729,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "PR",
#                 "stateDescription": "Puerto Rico",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 165.727,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MD",
#                 "stateDescription": "Maryland",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 517.431,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "IN",
#                 "stateDescription": "Indiana",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7856.98503,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NV",
#                 "stateDescription": "Nevada",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 339.944,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "OH",
#                 "stateDescription": "Ohio",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2586.756,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "WV",
#                 "stateDescription": "West Virginia",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1624.136,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "WI",
#                 "stateDescription": "Wisconsin",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1593.479,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "IA",
#                 "stateDescription": "Iowa",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 37098.274,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "VA",
#                 "stateDescription": "Virginia",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 49.583,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "WSC",
#                 "stateDescription": "West South Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 132014.52768,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "PCN",
#                 "stateDescription": "Pacific Noncontiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 790.103,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "IL",
#                 "stateDescription": "Illinois",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 19133.08783,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 99474.21553,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "WA",
#                 "stateDescription": "Washington",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9297.756,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "ESC",
#                 "stateDescription": "East South Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 28.186,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NE",
#                 "stateDescription": "Nebraska",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9592.039,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "AK",
#                 "stateDescription": "Alaska",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 132.212,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NH",
#                 "stateDescription": "New Hampshire",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 504.23,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MI",
#                 "stateDescription": "Michigan",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7696.887,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "SAT",
#                 "stateDescription": "South Atlantic",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2710.702,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "OK",
#                 "stateDescription": "Oklahoma",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 32540.31215,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "ND",
#                 "stateDescription": "North Dakota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 14935.203,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": 90,
#                 "stateDescription": "Pacific",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 34640.61541,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MTN",
#                 "stateDescription": "Mountain",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 43072.636,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "CO",
#                 "stateDescription": "Colorado",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 15125.697,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "HI",
#                 "stateDescription": "Hawaii",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 657.891,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "RI",
#                 "stateDescription": "Rhode Island",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 172.16,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "CA",
#                 "stateDescription": "California",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 15177.00641,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "PCC",
#                 "stateDescription": "Pacific Contiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 33850.51241,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "SD",
#                 "stateDescription": "South Dakota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9326.617,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MT",
#                 "stateDescription": "Montana",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3472.646,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "KS",
#                 "stateDescription": "Kansas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 25693.69463,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6534.345,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MAT",
#                 "stateDescription": "Middle Atlantic",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7631.267,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NEW",
#                 "stateDescription": "New England",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3780.15925,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "WY",
#                 "stateDescription": "Wyoming",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8447.86,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "US",
#                 "stateDescription": "U.S. Total",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 378196.77482,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "ID",
#                 "stateDescription": "Idaho",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2680.206,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NY",
#                 "stateDescription": "New York",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4156.369,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MA",
#                 "stateDescription": "Massachusetts",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 208.62625,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "TN",
#                 "stateDescription": "Tennessee",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 28.186,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NC",
#                 "stateDescription": "North Carolina",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 514.703,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "DE",
#                 "stateDescription": "Delaware",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4.849,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "PA",
#                 "stateDescription": "Pennsylvania",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3455.169,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "UT",
#                 "stateDescription": "Utah",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 825.229,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "ME",
#                 "stateDescription": "Maine",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2544.197,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "OR",
#                 "stateDescription": "Oregon",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9375.75,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "CT",
#                 "stateDescription": "Connecticut",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12.758,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NM",
#                 "stateDescription": "New Mexico",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 10580.735,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "VT",
#                 "stateDescription": "Vermont",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 338.188,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MN",
#                 "stateDescription": "Minnesota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12271.314,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "AZ",
#                 "stateDescription": "Arizona",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1600.319,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "ENC",
#                 "stateDescription": "East North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 38867.19486,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2020,
#                 "location": "OR",
#                 "stateDescription": "Oregon",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8777.254,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2020,
#                 "location": "IA",
#                 "stateDescription": "Iowa",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 34182.302,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2020,
#                 "location": 90,
#                 "stateDescription": "Pacific",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 32346.71068,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2020,
#                 "location": "PCC",
#                 "stateDescription": "Pacific Contiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 31625.93994,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2020,
#                 "location": "NH",
#                 "stateDescription": "New Hampshire",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 524.87224,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2020,
#                 "location": "CT",
#                 "stateDescription": "Connecticut",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
# ...
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4.068,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2002,
#                 "location": "SD",
#                 "stateDescription": "South Dakota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6.043,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2002,
#                 "location": "WA",
#                 "stateDescription": "Washington",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 416.581,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2002,
#                 "location": "US",
#                 "stateDescription": "U.S. Total",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 10354.279,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2002,
#                 "location": "NY",
#                 "stateDescription": "New York",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 81.626,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2002,
#                 "location": "KS",
#                 "stateDescription": "Kansas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 466.679,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2002,
#                 "location": "MTN",
#                 "stateDescription": "Mountain",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 586.336,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "TN",
#                 "stateDescription": "Tennessee",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": null,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "SD",
#                 "stateDescription": "South Dakota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 0.871,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "US",
#                 "stateDescription": "U.S. Total",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6737.332,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "ESC",
#                 "stateDescription": "East South Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": null,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "PCN",
#                 "stateDescription": "Pacific Noncontiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3.072,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "NE",
#                 "stateDescription": "Nebraska",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2.63,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "PCC",
#                 "stateDescription": "Pacific Contiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3588.325,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "MTN",
#                 "stateDescription": "Mountain",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 413.799,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "WSC",
#                 "stateDescription": "West South Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1187.51,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "PA",
#                 "stateDescription": "Pennsylvania",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 11.175,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "WY",
#                 "stateDescription": "Wyoming",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 365.159,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "CO",
#                 "stateDescription": "Colorado",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 48.64,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "HI",
#                 "stateDescription": "Hawaii",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2.122,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "AK",
#                 "stateDescription": "Alaska",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 0.95,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "WNC",
#                 "stateDescription": "West North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1428.215,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1187.51,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "MN",
#                 "stateDescription": "Minnesota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 897.018,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "ENC",
#                 "stateDescription": "East North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 72.564,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "MI",
#                 "stateDescription": "Michigan",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 0.28,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "IA",
#                 "stateDescription": "Iowa",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 487.864,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "KS",
#                 "stateDescription": "Kansas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 39.832,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "NEW",
#                 "stateDescription": "New England",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12.133,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "VT",
#                 "stateDescription": "Vermont",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12.133,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "CA",
#                 "stateDescription": "California",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3499.738,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "MA",
#                 "stateDescription": "Massachusetts",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": null,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "WA",
#                 "stateDescription": "Washington",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": null,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "NY",
#                 "stateDescription": "New York",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 20.539,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "WI",
#                 "stateDescription": "Wisconsin",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 72.284,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "MAT",
#                 "stateDescription": "Middle Atlantic",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 31.714,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "OR",
#                 "stateDescription": "Oregon",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 88.587,
#                 "generation-units": "thousand megawatthours"
#             }
#         ],
#         "description": "Monthly and annual electric power operations by state, sector, and energy source.\n    Source: Form EIA-923"
#     },
#     "request": {
#         "command": "/v2/electricity/electric-power-operational-data/data/",
#         "params": {
#             "api_key": "VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9",
#             "data": [
#                 "generation"
#             ],
#             "facets": {
#                 "fueltypeid": [
#                     "WND"
#                 ],
#                 "sectorid": [
#                     99
#                 ]
#             },
#             "frequency": "annual",
#             "sort": [
#                 {
#                     "column": "period",
#                     "direction": "desc"
#                 }
#             ]
#         }
#     },
#     "apiVersion": "2.1.5",
#     "ExcelAddInVersion": "2.1.0"
# }

# %%
data = data['response']['data']
df = pd.json_normalize(data)
# Display the DataFrame
df.tail(5)
# Out:
#      period location stateDescription  sectorid sectorDescription fueltypeid  \
# 946    2001       WA       Washington        99       All Sectors        WND
# 947    2001       NY         New York        99       All Sectors        WND
# 948    2001       WI        Wisconsin        99       All Sectors        WND
# 949    2001      MAT  Middle Atlantic        99       All Sectors        WND
# 950    2001       OR           Oregon        99       All Sectors        WND
#
#     fuelTypeDescription  generation        generation-units
# 946                wind         NaN  thousand megawatthours
# 947                wind      20.539  thousand megawatthours
# 948                wind      72.284  thousand megawatthours
# 949                wind      31.714  thousand megawatthours
# 950                wind      88.587  thousand megawatthours

# %%
data_types = df.dtypes
print(data_types)
# Out:
# period                   int64
# location                object
# stateDescription        object
# sectorid                 int64
# sectorDescription       object
# fueltypeid              object
# fuelTypeDescription     object
# generation             float64
# generation-units        object
# dtype: object

# %%
nan_count = df.isna().sum().sum()
print("Total NaN values in the DataFrame:", nan_count)
# Out:
# Total NaN values in the DataFrame: 6

# %%
df['generation'] = df['generation'].fillna(0)
df.head()
# Out:
#    period location    stateDescription  sectorid sectorDescription fueltypeid  \
# 0    2022       ND        North Dakota        99       All Sectors        WND
# 1    2022       TN           Tennessee        99       All Sectors        WND
# 2    2022      ENC  East North Central        99       All Sectors        WND
# 3    2022       NE            Nebraska        99       All Sectors        WND
# 4    2022      MTN            Mountain        99       All Sectors        WND
#
#   fuelTypeDescription   generation        generation-units
# 0                wind  16249.88800  thousand megawatthours
# 1                wind     14.86500  thousand megawatthours
# 2                wind  47599.91854  thousand megawatthours
# 3                wind  12614.06100  thousand megawatthours
# 4                wind  50192.70368  thousand megawatthours

# %%
unique_states = df['location'].unique()
print(unique_states)
# Out:
# ['ND' 'TN' 'ENC' 'NE' 'MTN' 'HI' 'VA' 'ID' 'WV' 'OH' 'RI' 'PA' 'AZ' 'WA'
#  'VT' 'NY' 'TX' 'ESC' 'NM' 'KS' 'US' 'SAT' 'OK' 'NEW' 'CO' 'IA' 'PCN' 'AK'
#  'NV' 'PR' 'WSC' 'OR' 'NC' 'NH' 'WY' 'CA' 'CT' 'IL' 'UT' 'MO' 'MD' 'ME'
#  'MAT' 'MT' 'MN' 90 'WNC' 'SD' 'NJ' 'DE' 'PCC' 'WI' 'MI' 'MA' 'IN']

# %%
unique_states = df['stateDescription'].unique()
print(unique_states)
# Out:
# ['North Dakota' 'Tennessee' 'East North Central' 'Nebraska' 'Mountain'
#  'Hawaii' 'Virginia' 'Idaho' 'West Virginia' 'Ohio' 'Rhode Island'
#  'Pennsylvania' 'Arizona' 'Washington' 'Vermont' 'New York' 'Texas'
#  'East South Central' 'New Mexico' 'Kansas' 'U.S. Total' 'South Atlantic'
#  'Oklahoma' 'New England' 'Colorado' 'Iowa' 'Pacific Noncontiguous'
#  'Alaska' 'Nevada' 'Puerto Rico' 'West South Central' 'Oregon'
#  'North Carolina' 'New Hampshire' 'Wyoming' 'California' 'Connecticut'
#  'Illinois' 'Utah' 'Missouri' 'Maryland' 'Maine' 'Middle Atlantic'
#  'Montana' 'Minnesota' 'Pacific' 'West North Central' 'South Dakota'
#  'New Jersey' 'Delaware' 'Pacific Contiguous' 'Wisconsin' 'Michigan'
#  'Massachusetts' 'Indiana']

# %%
new_df = df[['period', 'stateDescription', 'generation']]
new_df.tail(50)
# Out:
#      period       stateDescription  generation
# 901    2002  Pacific Noncontiguous       1.614
# 902    2002                Wyoming     447.330
# 903    2002              Wisconsin      46.180
# 904    2002     East North Central      46.509
# 905    2002                   Iowa     918.835
# 906    2002        Middle Atlantic     139.394
# 907    2002     Pacific Contiguous    4595.385
# 908    2002          Massachusetts       0.000
# 909    2002          West Virginia       9.023
# 910    2002             California    3802.645
# 911    2002     West North Central    2305.474
# 912    2002                Vermont      10.372
# 913    2002           Pennsylvania      57.768
# 914    2002              Tennessee       4.068
# 915    2002           South Dakota       6.043
# 916    2002             Washington     416.581
# 917    2002             U.S. Total   10354.279
# 918    2002               New York      81.626
# 919    2002                 Kansas     466.679
# 920    2002               Mountain     586.336
# 921    2001              Tennessee       0.000
# 922    2001           South Dakota       0.871
# 923    2001             U.S. Total    6737.332
# 924    2001     East South Central       0.000
# 925    2001  Pacific Noncontiguous       3.072
# 926    2001               Nebraska       2.630
# 927    2001     Pacific Contiguous    3588.325
# 928    2001               Mountain     413.799
# 929    2001     West South Central    1187.510
# 930    2001           Pennsylvania      11.175
# 931    2001                Wyoming     365.159
# 932    2001               Colorado      48.640
# 933    2001                 Hawaii       2.122
# 934    2001                 Alaska       0.950
# 935    2001     West North Central    1428.215
# 936    2001                  Texas    1187.510
# 937    2001              Minnesota     897.018
# 938    2001     East North Central      72.564
# 939    2001               Michigan       0.280
# 940    2001                   Iowa     487.864
# 941    2001                 Kansas      39.832
# 942    2001            New England      12.133
# 943    2001                Vermont      12.133
# 944    2001             California    3499.738
# 945    2001          Massachusetts       0.000
# 946    2001             Washington       0.000
# 947    2001               New York      20.539
# 948    2001              Wisconsin      72.284
# 949    2001        Middle Atlantic      31.714
# 950    2001                 Oregon      88.587

# %%
stateDescription_to_remove = ['Alaska', 'U.S. Total', 'New England','West South Central', 'Pacific Noncontiguous', 'Pacific Contiguous', 'Middle Atlantic', 'East North Central',  'East South Central', 'South Atlantic', 'Hawaii' ,'Mountain','Pacific' ,'West North Central','Puerto Rico']

new_df = new_df[~new_df['stateDescription'].isin(stateDescription_to_remove)]

new_df.head(50)
# Out:
#     period stateDescription    generation
# 0     2022     North Dakota   16249.88800
# 1     2022        Tennessee      14.86500
# 3     2022         Nebraska   12614.06100
# 6     2022         Virginia      50.85200
# 7     2022            Idaho    2441.68800
# 8     2022    West Virginia    2006.89500
# 9     2022             Ohio    3154.00700
# 10    2022     Rhode Island     209.33800
# 11    2022     Pennsylvania    3572.24500
# 12    2022          Arizona    1564.34800
# 13    2022       Washington    8060.91200
# 14    2022          Vermont     409.18500
# 15    2022         New York    4567.50800
# 16    2022            Texas  114786.90255
# 18    2022       New Mexico   14434.55068
# 19    2022           Kansas   29687.47900
# 22    2022         Oklahoma   37552.75500
# 24    2022         Colorado   16911.12600
# 25    2022             Iowa   45761.36955
# 28    2022           Nevada     315.55100
# 31    2022           Oregon    8149.18841
# 32    2022   North Carolina     546.75500
# 33    2022    New Hampshire     482.32200
# 34    2022          Wyoming    9780.14100
# 35    2022       California   14638.06100
# 36    2022      Connecticut      12.83308
# 37    2022         Illinois   23493.80554
# 38    2022             Utah     723.43900
# 39    2022         Missouri    7524.60500
# 40    2022         Maryland     497.60800
# 41    2022            Maine    2716.38400
# 43    2022          Montana    4021.86000
# 44    2022        Minnesota   15091.22700
# 47    2022     South Dakota   10295.11300
# 48    2022       New Jersey      21.62900
# 49    2022         Delaware       4.37700
# 51    2022        Wisconsin    1815.72200
# 52    2022         Michigan    9151.17900
# 53    2022    Massachusetts     215.68049
# 54    2022          Indiana    9985.20500
# 56    2021       New Jersey      19.72900
# 58    2021         Maryland     517.43100
# 59    2021          Indiana    7856.98503
# 60    2021           Nevada     339.94400
# 61    2021             Ohio    2586.75600
# 62    2021    West Virginia    1624.13600
# 63    2021        Wisconsin    1593.47900
# 64    2021             Iowa   37098.27400
# 65    2021         Virginia      49.58300
# 68    2021         Illinois   19133.08783

# %%
transposed_df = new_df.pivot(index='stateDescription', columns='period', values='generation')
transposed_df = transposed_df.reset_index()
transposed_df.columns.name = None
transposed_df.rename(columns={'stateDescription': 'State'}, inplace = True)
transposed_df = transposed_df.round(3)

# %%
transposed_df.head(5)
# Out:
#    index        State      2001      2002      2003      2004      2005  \
# 0      0      Arizona       NaN       NaN       NaN       NaN       NaN
# 1      1   California  3499.738  3802.645  3895.431  4305.875  4262.229
# 2      2     Colorado    48.640   139.006   147.109   220.141   776.234
# 3      3  Connecticut       NaN       NaN       NaN       NaN       NaN
# 4      4     Delaware       NaN       NaN       NaN       NaN       NaN
#
#        2006      2007      2008  ...       2013       2014       2015  \
# 0       NaN       NaN       NaN  ...    449.764    468.115    452.035
# 1  4882.801  5584.933  5384.955  ...  12822.060  12992.498  12229.559
# 2   865.536  1291.516  3220.843  ...   7203.720   7368.614   7475.279
# 3       NaN       NaN       NaN  ...        NaN        NaN        NaN
# 4       NaN       NaN       NaN  ...      4.458      5.051      5.126
#
#         2016       2017       2018       2019       2020       2021       2022
# 0    541.582    569.934    530.190    554.374    644.160   1600.319   1564.348
# 1  13509.039  12822.948  14023.951  13735.069  13583.089  15177.006  14638.061
# 2   9421.204   9314.663   9745.150  10852.376  13386.228  15125.697  16911.126
# 3     12.742     12.706     12.295     12.215     12.184     12.758     12.833
# 4      5.321      4.965      5.207      5.270      5.179      4.849      4.377
#
# [5 rows x 24 columns]

# %%
print(transposed_df.columns)
# Out:
# Index(['State',    2001,    2002,    2003,    2004,    2005,    2006,    2007,
#           2008,    2009,    2010,    2011,    2012,    2013,    2014,    2015,
#           2016,    2017,    2018,    2019,    2020,    2021,    2022],
#       dtype='object')

# %%
# Select the row with index 0 and Description "Coal Production"
# Filter the DataFrame for each type of production
California_row = transposed_df[(transposed_df.index == 1) & (transposed_df['State'] == 'California')]
Arizona_row = transposed_df[(transposed_df.index == 0) & (transposed_df['State'] == 'Arizona')]

# Extract the years and values for each production type
years = Arizona_row.columns[2:].astype(int)
California_values = California_row.values[:, 2:].flatten().astype(float)

# Create a line plot for each production type
plt.figure(figsize=(12, 6))
plt.plot(years, California_values, linestyle='-', color='r', label='California')
plt.title("Primary Energy Production by Wind Source")
plt.xlabel("Year")
plt.ylabel("Production Value (Quadrillion Btu)")
plt.grid(True)
plt.legend()

# Extend the x-axis by adding extra space on both ends
plt.xlim(years[0] - 5, years[-1] + 5)  # Adjust the numbers to control the extension

plt.show()

# %%
# Reset the index to make 'State' a column
transposed_df.reset_index(inplace=True)

# Create a new DataFrame with 'State' and '2022' columns
state_2022_df = transposed_df[['State', 2022]]

# Print the new DataFrame
state_2022_df.head()
# Out:
#          State       2022
# 0      Arizona   1564.348
# 1   California  14638.061
# 2     Colorado  16911.126
# 3  Connecticut     12.833
# 4     Delaware      4.377

# %%
print(state_2022_df.columns)
# Out:
# Index(['State', 2022], dtype='object')

# %%
# Iterate over column names and count characters
column_name_lengths = {str(col): len(str(col)) for col in state_2022_df.columns}

# Print the column name lengths
print(column_name_lengths)
# Out:
# {'State': 5, '2022': 4}

# %%
# state_2022_df.rename(columns={2022: '2022'}, inplace = True)

state_2022_df = state_2022_df.copy()




state_2022_df.rename(columns={2022: '2022'}, inplace=True)

# %%
new_rows = [
  {'State': 'South Carolina', '2022': 0},
  {'State': 'Florida', '2022': 0},
  {'State': 'Mississippi', '2022': 0},
  {'State': 'Louisiana', '2022': 0},
  {'State': 'District ofColumbia', '2022': 0},
  {'State': 'Kentucky', '2022': 0},
  {'State': 'Alabama', '2022': 0},
  {'State': 'Georgia', '2022': 0},
]

# Convert the list of dictionaries to a DataFrame
new_rows_df = pd.DataFrame(new_rows)

# Concatenate the original DataFrame and the new rows DataFrame
state_2022_df = pd.concat([state_2022_df, new_rows_df], ignore_index=True)

state_2022_df.head(50)
# Out:
#                   State        2022
# 0               Arizona    1564.348
# 1            California   14638.061
# 2              Colorado   16911.126
# 3           Connecticut      12.833
# 4              Delaware       4.377
# 5                 Idaho    2441.688
# 6              Illinois   23493.806
# 7               Indiana    9985.205
# 8                  Iowa   45761.370
# 9                Kansas   29687.479
# 10                Maine    2716.384
# 11             Maryland     497.608
# 12        Massachusetts     215.680
# 13             Michigan    9151.179
# 14            Minnesota   15091.227
# 15             Missouri    7524.605
# 16              Montana    4021.860
# 17             Nebraska   12614.061
# 18               Nevada     315.551
# 19        New Hampshire     482.322
# 20           New Jersey      21.629
# 21           New Mexico   14434.551
# 22             New York    4567.508
# 23       North Carolina     546.755
# 24         North Dakota   16249.888
# 25                 Ohio    3154.007
# 26             Oklahoma   37552.755
# 27               Oregon    8149.188
# 28         Pennsylvania    3572.245
# 29         Rhode Island     209.338
# 30         South Dakota   10295.113
# 31            Tennessee      14.865
# 32                Texas  114786.903
# 33                 Utah     723.439
# 34              Vermont     409.185
# 35             Virginia      50.852
# 36           Washington    8060.912
# 37        West Virginia    2006.895
# 38            Wisconsin    1815.722
# 39              Wyoming    9780.141
# 40       South Carolina       0.000
# 41              Florida       0.000
# 42          Mississippi       0.000
# 43            Louisiana       0.000
# 44  District ofColumbia       0.000
# 45             Kentucky       0.000
# 46              Alabama       0.000
# 47              Georgia       0.000

# %%
state_2022_df = state_2022_df.sort_values(by='2022', ascending = [False])

# Display the sorted DataFrame
state_2022_df.head(10)
# Out:
#            State        2022
# 32         Texas  114786.903
# 8           Iowa   45761.370
# 26      Oklahoma   37552.755
# 9         Kansas   29687.479
# 6       Illinois   23493.806
# 2       Colorado   16911.126
# 24  North Dakota   16249.888
# 14     Minnesota   15091.227
# 1     California   14638.061
# 21    New Mexico   14434.551

# %%
print(transposed_df.columns)
# Out:
# Index(['index', 'State',    2001,    2002,    2003,    2004,    2005,    2006,
#           2007,    2008,    2009,    2010,    2011,    2012,    2013,    2014,
#           2015,    2016,    2017,    2018,    2019,    2020,    2021,    2022],
#       dtype='object')

# %%
transposed_df.head()
# Out:
#    index        State      2001      2002      2003      2004      2005  \
# 0      0      Arizona       NaN       NaN       NaN       NaN       NaN
# 1      1   California  3499.738  3802.645  3895.431  4305.875  4262.229
# 2      2     Colorado    48.640   139.006   147.109   220.141   776.234
# 3      3  Connecticut       NaN       NaN       NaN       NaN       NaN
# 4      4     Delaware       NaN       NaN       NaN       NaN       NaN
#
#        2006      2007      2008  ...       2013       2014       2015  \
# 0       NaN       NaN       NaN  ...    449.764    468.115    452.035
# 1  4882.801  5584.933  5384.955  ...  12822.060  12992.498  12229.559
# 2   865.536  1291.516  3220.843  ...   7203.720   7368.614   7475.279
# 3       NaN       NaN       NaN  ...        NaN        NaN        NaN
# 4       NaN       NaN       NaN  ...      4.458      5.051      5.126
#
#         2016       2017       2018       2019       2020       2021       2022
# 0    541.582    569.934    530.190    554.374    644.160   1600.319   1564.348
# 1  13509.039  12822.948  14023.951  13735.069  13583.089  15177.006  14638.061
# 2   9421.204   9314.663   9745.150  10852.376  13386.228  15125.697  16911.126
# 3     12.742     12.706     12.295     12.215     12.184     12.758     12.833
# 4      5.321      4.965      5.207      5.270      5.179      4.849      4.377
#
# [5 rows x 24 columns]

# %%
for column in transposed_df.columns:
    print(column)
    transposed_df.rename(columns={column: str(column)}, inplace=True)

transposed_df.head()
# Out:
# index
# State
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
#    index        State      2001      2002      2003      2004      2005  \
# 0      0      Arizona       NaN       NaN       NaN       NaN       NaN
# 1      1   California  3499.738  3802.645  3895.431  4305.875  4262.229
# 2      2     Colorado    48.640   139.006   147.109   220.141   776.234
# 3      3  Connecticut       NaN       NaN       NaN       NaN       NaN
# 4      4     Delaware       NaN       NaN       NaN       NaN       NaN
#
#        2006      2007      2008  ...       2013       2014       2015  \
# 0       NaN       NaN       NaN  ...    449.764    468.115    452.035
# 1  4882.801  5584.933  5384.955  ...  12822.060  12992.498  12229.559
# 2   865.536  1291.516  3220.843  ...   7203.720   7368.614   7475.279
# 3       NaN       NaN       NaN  ...        NaN        NaN        NaN
# 4       NaN       NaN       NaN  ...      4.458      5.051      5.126
#
#         2016       2017       2018       2019       2020       2021       2022
# 0    541.582    569.934    530.190    554.374    644.160   1600.319   1564.348
# 1  13509.039  12822.948  14023.951  13735.069  13583.089  15177.006  14638.061
# 2   9421.204   9314.663   9745.150  10852.376  13386.228  15125.697  16911.126
# 3     12.742     12.706     12.295     12.215     12.184     12.758     12.833
# 4      5.321      4.965      5.207      5.270      5.179      4.849      4.377
#
# [5 rows x 24 columns]

# %%
transposed_df['2001']
# Out:
# 0          NaN
# 1     3499.738
# 2       48.640
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8      487.864
# 9       39.832
# 10         NaN
# 11         NaN
# 12       0.000
# 13       0.280
# 14     897.018
# 15         NaN
# 16         NaN
# 17       2.630
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22      20.539
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27      88.587
# 28      11.175
# 29         NaN
# 30       0.871
# 31       0.000
# 32    1187.510
# 33         NaN
# 34      12.133
# 35         NaN
# 36       0.000
# 37         NaN
# 38      72.284
# 39     365.159
# Name: 2001, dtype: float64
