# %%
import requests
import json
import pandas as pd

# %%
#Detailed view of electricity/electric-power-operational-data entry for EIA API. This one enables us to detemrine the fueltypeid for wind is WND
eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/facet/fueltypeid?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"

# %%
# Execute "GET" request with url
response_data = requests.get(eia_url)

# %%
# Print "response_data" variable
print(response_data)
# Out:
# <Response [200]>

# %%
# Store response using "content" attribute
response_content = response_data.content
print(response_content)
# Out:
# b'{"response":{"totalFacets":45,"facets":[{"id":"ALL","name":"all fuels"},{"id":"SPV","name":"solar photovoltaic"},{"id":"RC","name":"refined coal"},{"id":"LIG","name":"lignite coal"},{"id":"WAS","name":"renewable waste products"},{"id":"BIT","name":"bituminous coal"},{"id":"STH","name":"solar thermal"},{"id":"REN","name":"renewable"},{"id":"TPV","name":"estimated total solar photovoltaic"},{"id":"TSN","name":"estimated total solar"},{"id":"COW","name":"all coal products"},{"id":"OTH","name":"other"},{"id":"PET","name":"petroleum"},{"id":"OB2","name":"biomass"},{"id":"HPS","name":"hydro-electric pumped storage"},{"id":"WND","name":"wind"},{"id":"WNT","name":"onshore wind turbine"},{"id":"MLG","name":"municiapl landfill gas"},{"id":"LFG","name":"landfill gas"},{"id":"ORW","name":"other renewables"},{"id":"NUC","name":"nuclear"},{"id":"DPV","name":"estimated small scale solar photovoltaic"},{"id":"WNS","name":"offshore wind turbine"},{"id":"ANT","name":"anthracite coal"},{"id":"BIO","name":"biomass"},{"id":"WOC","name":"waste coal"},{"id":"PC","name":"petroleum coke"},{"id":"SUB","name":"subbituminous coal"},{"id":"RFO","name":"residual fuel oil"},{"id":"NGO","name":"natural gas & other gases"},{"id":"PEL","name":"petroleum liquids"},{"id":"SUN","name":"solar"},{"id":"OOG","name":"other gases"},{"id":"GEO","name":"geothermal"},{"id":"WOO","name":"waste oil and other oils"},{"id":"AOR","name":"all renewables"},{"id":"MSB","name":"biogenic municipal solid waste"},{"id":"HYC","name":"conventional hydroelectric"},{"id":"BIS","name":"bituminous coal and synthetic coal"},{"id":"WWW","name":"wood and wood wastes"},{"id":"DFO","name":"distillate fuel oil"},{"id":"FOS","name":"fossil fuels"},{"id":"NG","name":"natural gas"},{"id":"OBW","name":"biomass"},{"id":"COL","name":"coal, excluding waste coal"}]},"request":{"command":"\\/v2\\/electricity\\/electric-power-operational-data\\/facet\\/fueltypeid\\/","params":{"api_key":"VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"}},"apiVersion":"2.1.5","ExcelAddInVersion":"2.1.0"}'

# %%
# Format data as JSON
data = response_data.json()

# %%
# Use json.dumps with argument indent=4 to format data
print(json.dumps(data, indent=4))
# Out:
# {
#     "response": {
#         "totalFacets": 45,
#         "facets": [
#             {
#                 "id": "ALL",
#                 "name": "all fuels"
#             },
#             {
#                 "id": "SPV",
#                 "name": "solar photovoltaic"
#             },
#             {
#                 "id": "RC",
#                 "name": "refined coal"
#             },
#             {
#                 "id": "LIG",
#                 "name": "lignite coal"
#             },
#             {
#                 "id": "WAS",
#                 "name": "renewable waste products"
#             },
#             {
#                 "id": "BIT",
#                 "name": "bituminous coal"
#             },
#             {
#                 "id": "STH",
#                 "name": "solar thermal"
#             },
#             {
#                 "id": "REN",
#                 "name": "renewable"
#             },
#             {
#                 "id": "TPV",
#                 "name": "estimated total solar photovoltaic"
#             },
#             {
#                 "id": "TSN",
#                 "name": "estimated total solar"
#             },
#             {
#                 "id": "COW",
#                 "name": "all coal products"
#             },
#             {
#                 "id": "OTH",
#                 "name": "other"
#             },
#             {
#                 "id": "PET",
#                 "name": "petroleum"
#             },
#             {
#                 "id": "OB2",
#                 "name": "biomass"
#             },
#             {
#                 "id": "HPS",
#                 "name": "hydro-electric pumped storage"
#             },
#             {
#                 "id": "WND",
#                 "name": "wind"
#             },
#             {
#                 "id": "WNT",
#                 "name": "onshore wind turbine"
#             },
#             {
#                 "id": "MLG",
#                 "name": "municiapl landfill gas"
#             },
#             {
#                 "id": "LFG",
#                 "name": "landfill gas"
#             },
#             {
#                 "id": "ORW",
#                 "name": "other renewables"
#             },
#             {
#                 "id": "NUC",
#                 "name": "nuclear"
#             },
#             {
#                 "id": "DPV",
#                 "name": "estimated small scale solar photovoltaic"
#             },
#             {
#                 "id": "WNS",
#                 "name": "offshore wind turbine"
#             },
#             {
#                 "id": "ANT",
#                 "name": "anthracite coal"
#             },
#             {
#                 "id": "BIO",
#                 "name": "biomass"
#             },
#             {
#                 "id": "WOC",
#                 "name": "waste coal"
#             },
#             {
#                 "id": "PC",
#                 "name": "petroleum coke"
#             },
#             {
#                 "id": "SUB",
#                 "name": "subbituminous coal"
#             },
#             {
#                 "id": "RFO",
#                 "name": "residual fuel oil"
#             },
#             {
#                 "id": "NGO",
#                 "name": "natural gas & other gases"
#             },
#             {
#                 "id": "PEL",
#                 "name": "petroleum liquids"
#             },
#             {
#                 "id": "SUN",
#                 "name": "solar"
#             },
#             {
#                 "id": "OOG",
#                 "name": "other gases"
#             },
#             {
#                 "id": "GEO",
#                 "name": "geothermal"
#             },
#             {
#                 "id": "WOO",
#                 "name": "waste oil and other oils"
#             },
#             {
#                 "id": "AOR",
#                 "name": "all renewables"
#             },
#             {
#                 "id": "MSB",
#                 "name": "biogenic municipal solid waste"
#             },
#             {
#                 "id": "HYC",
#                 "name": "conventional hydroelectric"
#             },
#             {
#                 "id": "BIS",
#                 "name": "bituminous coal and synthetic coal"
#             },
#             {
#                 "id": "WWW",
#                 "name": "wood and wood wastes"
#             },
#             {
#                 "id": "DFO",
#                 "name": "distillate fuel oil"
#             },
#             {
#                 "id": "FOS",
#                 "name": "fossil fuels"
#             },
#             {
#                 "id": "NG",
#                 "name": "natural gas"
#             },
#             {
#                 "id": "OBW",
#                 "name": "biomass"
#             },
#             {
#                 "id": "COL",
#                 "name": "coal, excluding waste coal"
#             }
#         ]
#     },
#     "request": {
#         "command": "/v2/electricity/electric-power-operational-data/facet/fueltypeid/",
#         "params": {
#             "api_key": "VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"
#         }
#     },
#     "apiVersion": "2.1.5",
#     "ExcelAddInVersion": "2.1.0"
# }

# %%
# Extract the 'facets' list from the JSON data
facets_data = data['response']['facets']

# Convert the 'facets' list into a DataFrame
df = pd.DataFrame(facets_data)

# Display the DataFrame
df.head(50)
# Out:
#      id                                      name
# 0   ALL                                 all fuels
# 1   SPV                        solar photovoltaic
# 2    RC                              refined coal
# 3   LIG                              lignite coal
# 4   WAS                  renewable waste products
# 5   BIT                           bituminous coal
# 6   STH                             solar thermal
# 7   REN                                 renewable
# 8   TPV        estimated total solar photovoltaic
# 9   TSN                     estimated total solar
# 10  COW                         all coal products
# 11  OTH                                     other
# 12  PET                                 petroleum
# 13  OB2                                   biomass
# 14  HPS             hydro-electric pumped storage
# 15  WND                                      wind
# 16  WNT                      onshore wind turbine
# 17  MLG                    municiapl landfill gas
# 18  LFG                              landfill gas
# 19  ORW                          other renewables
# 20  NUC                                   nuclear
# 21  DPV  estimated small scale solar photovoltaic
# 22  WNS                     offshore wind turbine
# 23  ANT                           anthracite coal
# 24  BIO                                   biomass
# 25  WOC                                waste coal
# 26   PC                            petroleum coke
# 27  SUB                        subbituminous coal
# 28  RFO                         residual fuel oil
# 29  NGO                 natural gas & other gases
# 30  PEL                         petroleum liquids
# 31  SUN                                     solar
# 32  OOG                               other gases
# 33  GEO                                geothermal
# 34  WOO                  waste oil and other oils
# 35  AOR                            all renewables
# 36  MSB            biogenic municipal solid waste
# 37  HYC                conventional hydroelectric
# 38  BIS        bituminous coal and synthetic coal
# 39  WWW                      wood and wood wastes
# 40  DFO                       distillate fuel oil
# 41  FOS                              fossil fuels
# 42   NG                               natural gas
# 43  OBW                                   biomass
# 44  COL                coal, excluding waste coal
