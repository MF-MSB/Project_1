# %%
import requests
import json
import pandas as pd

# %%
#Detailed view of electricity/electric-power-operational-data entry for EIA API. This one enables us to detemrine the fueltypeid for wind is WND
eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/facet/location?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"

# %%
# Execute "GET" request with url
response_data = requests.get(eia_url)

# %%
# Print "response_data" variable
print(response_data)
# Out:
# <Response [200]>

# %%
# Store response using "content" attribute
response_content = response_data.content
print(response_content)
# Out:
# b'{"response":{"totalFacets":64,"facets":[{"id":"VA","name":"Virginia","alias":"(VA) Virginia"},{"id":"PCC","name":"Pacific Contiguous","alias":"Region: (PCC) Pacific Contiguous"},{"id":"PCN","name":"Pacific Noncontiguous","alias":"Region: (PCN) Pacific Noncontiguous"},{"id":"MAT","name":"Middle Atlantic","alias":"Region: (MAT) Middle Atlantic"},{"id":"KS","name":"Kansas","alias":"(KS) Kansas"},{"id":"UT","name":"Utah","alias":"(UT) Utah"},{"id":"MN","name":"Minnesota","alias":"(MN) Minnesota"},{"id":"IN","name":"Indiana","alias":"(IN) Indiana"},{"id":"CT","name":"Connecticut","alias":"(CT) Connecticut"},{"id":"DE","name":"Delaware","alias":"(DE) Delaware"},{"id":"SC","name":"South Carolina","alias":"(SC) South Carolina"},{"id":"OH","name":"Ohio","alias":"(OH) Ohio"},{"id":"MO","name":"Missouri","alias":"(MO) Missouri"},{"id":"NEW","name":"New England","alias":"Region: (NEW) New England"},{"id":"ND","name":"North Dakota","alias":"(ND) North Dakota"},{"id":"PA","name":"Pennsylvania","alias":"(PA) Pennsylvania"},{"id":"GA","name":"Georgia","alias":"(GA) Georgia"},{"id":"OR","name":"Oregon","alias":"(OR) Oregon"},{"id":"ENC","name":"East North Central","alias":"Region: (ENC) East North Central"},{"id":"NE","name":"Nebraska","alias":"(NE) Nebraska"},{"id":"CO","name":"Colorado","alias":"(CO) Colorado"},{"id":"WV","name":"West Virginia","alias":"(WV) West Virginia"},{"id":"WY","name":"Wyoming","alias":"(WY) Wyoming"},{"id":"NY","name":"New York","alias":"(NY) New York"},{"id":"LA","name":"Louisiana","alias":"(LA) Louisiana"},{"id":"MA","name":"Massachusetts","alias":"(MA) Massachusetts"},{"id":"ME","name":"Maine","alias":"(ME) Maine"},{"id":"MT","name":"Montana","alias":"(MT) Montana"},{"id":"HI","name":"Hawaii","alias":"(HI) Hawaii"},{"id":"CA","name":"California","alias":"(CA) California"},{"id":"MD","name":"Maryland","alias":"(MD) Maryland"},{"id":"ID","name":"Idaho","alias":"(ID) Idaho"},{"id":"MS","name":"Mississippi","alias":"(MS) Mississippi"},{"id":"SAT","name":"South Atlantic","alias":"Region: (SAT) South Atlantic"},{"id":"NC","name":"North Carolina","alias":"(NC) North Carolina"},{"id":"MI","name":"Michigan","alias":"(MI) Michigan"},{"id":"WA","name":"Washington","alias":"(WA) Washington"},{"id":90,"name":"Pacific","alias":"(90) Pacific"},{"id":"AL","name":"Alabama","alias":"(AL) Alabama"},{"id":"PR","name":"Puerto Rico","alias":"(PR) Puerto Rico"},{"id":"KY","name":"Kentucky","alias":"(KY) Kentucky"},{"id":"WI","name":"Wisconsin","alias":"(WI) Wisconsin"},{"id":"MTN","name":"Mountain","alias":"Region: (MTN) Mountain"},{"id":"ESC","name":"East South Central","alias":"Region: (ESC) East South Central"},{"id":"NH","name":"New Hampshire","alias":"(NH) New Hampshire"},{"id":"AZ","name":"Arizona","alias":"(AZ) Arizona"},{"id":"TN","name":"Tennessee","alias":"(TN) Tennessee"},{"id":"WNC","name":"West North Central","alias":"Region: (WNC) West North Central"},{"id":"WSC","name":"West South Central","alias":"Region: (WSC) West South Central"},{"id":"OK","name":"Oklahoma","alias":"(OK) Oklahoma"},{"id":"AK","name":"Alaska","alias":"(AK) Alaska"},{"id":"FL","name":"Florida","alias":"(FL) Florida"},{"id":"US","name":"U.S. Total","alias":"Total: (US) U.S. Total"},{"id":"AR","name":"Arkansas","alias":"(AR) Arkansas"},{"id":"TX","name":"Texas","alias":"(TX) Texas"},{"id":"NJ","name":"New Jersey","alias":"(NJ) New Jersey"},{"id":"SD","name":"South Dakota","alias":"(SD) South Dakota"},{"id":"IL","name":"Illinois","alias":"(IL) Illinois"},{"id":"VT","name":"Vermont","alias":"(VT) Vermont"},{"id":"NV","name":"Nevada","alias":"(NV) Nevada"},{"id":"IA","name":"Iowa","alias":"(IA) Iowa"},{"id":"NM","name":"New Mexico","alias":"(NM) New Mexico"},{"id":"DC","name":"District of Columbia","alias":"(DC) District of Columbia"},{"id":"RI","name":"Rhode Island","alias":"(RI) Rhode Island"}]},"request":{"command":"\\/v2\\/electricity\\/electric-power-operational-data\\/facet\\/location\\/","params":{"api_key":"VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9" ...

# %%
# Format data as JSON
data = response_data.json()

# %%
# Use json.dumps with argument indent=4 to format data
print(json.dumps(data, indent=4))
# Out:
# {
#     "response": {
#         "totalFacets": 64,
#         "facets": [
#             {
#                 "id": "MN",
#                 "name": "Minnesota",
#                 "alias": "(MN) Minnesota"
#             },
#             {
#                 "id": "MAT",
#                 "name": "Middle Atlantic",
#                 "alias": "Region: (MAT) Middle Atlantic"
#             },
#             {
#                 "id": "IN",
#                 "name": "Indiana",
#                 "alias": "(IN) Indiana"
#             },
#             {
#                 "id": "UT",
#                 "name": "Utah",
#                 "alias": "(UT) Utah"
#             },
#             {
#                 "id": "CT",
#                 "name": "Connecticut",
#                 "alias": "(CT) Connecticut"
#             },
#             {
#                 "id": "VA",
#                 "name": "Virginia",
#                 "alias": "(VA) Virginia"
#             },
#             {
#                 "id": "KS",
#                 "name": "Kansas",
#                 "alias": "(KS) Kansas"
#             },
#             {
#                 "id": "PCC",
#                 "name": "Pacific Contiguous",
#                 "alias": "Region: (PCC) Pacific Contiguous"
#             },
#             {
#                 "id": "PCN",
#                 "name": "Pacific Noncontiguous",
#                 "alias": "Region: (PCN) Pacific Noncontiguous"
#             },
#             {
#                 "id": "DE",
#                 "name": "Delaware",
#                 "alias": "(DE) Delaware"
#             },
#             {
#                 "id": "OH",
#                 "name": "Ohio",
#                 "alias": "(OH) Ohio"
#             },
#             {
#                 "id": "PA",
#                 "name": "Pennsylvania",
#                 "alias": "(PA) Pennsylvania"
#             },
#             {
#                 "id": "NEW",
#                 "name": "New England",
#                 "alias": "Region: (NEW) New England"
#             },
#             {
#                 "id": "MO",
#                 "name": "Missouri",
#                 "alias": "(MO) Missouri"
#             },
#             {
#                 "id": "SC",
#                 "name": "South Carolina",
#                 "alias": "(SC) South Carolina"
#             },
#             {
#                 "id": "ND",
#                 "name": "North Dakota",
#                 "alias": "(ND) North Dakota"
#             },
#             {
#                 "id": "WV",
#                 "name": "West Virginia",
#                 "alias": "(WV) West Virginia"
#             },
#             {
#                 "id": "OR",
#                 "name": "Oregon",
#                 "alias": "(OR) Oregon"
#             },
#             {
#                 "id": "MA",
#                 "name": "Massachusetts",
#                 "alias": "(MA) Massachusetts"
#             },
#             {
#                 "id": "ME",
#                 "name": "Maine",
#                 "alias": "(ME) Maine"
#             },
#             {
#                 "id": "GA",
#                 "name": "Georgia",
#                 "alias": "(GA) Georgia"
#             },
#             {
#                 "id": "CA",
#                 "name": "California",
#                 "alias": "(CA) California"
#             },
#             {
#                 "id": "CO",
#                 "name": "Colorado",
#                 "alias": "(CO) Colorado"
#             },
#             {
#                 "id": "LA",
#                 "name": "Louisiana",
#                 "alias": "(LA) Louisiana"
#             },
#             {
#                 "id": "NE",
#                 "name": "Nebraska",
#                 "alias": "(NE) Nebraska"
#             },
#             {
#                 "id": "MT",
#                 "name": "Montana",
#                 "alias": "(MT) Montana"
#             },
#             {
#                 "id": "WY",
#                 "name": "Wyoming",
#                 "alias": "(WY) Wyoming"
#             },
#             {
#                 "id": "HI",
#                 "name": "Hawaii",
#                 "alias": "(HI) Hawaii"
#             },
#             {
#                 "id": "ENC",
#                 "name": "East North Central",
#                 "alias": "Region: (ENC) East North Central"
#             },
#             {
#                 "id": "NY",
#                 "name": "New York",
#                 "alias": "(NY) New York"
#             },
#             {
#                 "id": "MI",
#                 "name": "Michigan",
#                 "alias": "(MI) Michigan"
#             },
#             {
#                 "id": "MS",
#                 "name": "Mississippi",
#                 "alias": "(MS) Mississippi"
#             },
#             {
#                 "id": "ID",
#                 "name": "Idaho",
#                 "alias": "(ID) Idaho"
#             },
#             {
#                 "id": "MD",
#                 "name": "Maryland",
#                 "alias": "(MD) Maryland"
#             },
#             {
#                 "id": "SAT",
#                 "name": "South Atlantic",
#                 "alias": "Region: (SAT) South Atlantic"
#             },
#             {
#                 "id": "NC",
#                 "name": "North Carolina",
#                 "alias": "(NC) North Carolina"
#             },
#             {
#                 "id": "AL",
#                 "name": "Alabama",
#                 "alias": "(AL) Alabama"
#             },
#             {
#                 "id": "WA",
#                 "name": "Washington",
#                 "alias": "(WA) Washington"
#             },
#             {
#                 "id": 90,
#                 "name": "Pacific",
#                 "alias": "(90) Pacific"
#             },
#             {
#                 "id": "PR",
#                 "name": "Puerto Rico",
#                 "alias": "(PR) Puerto Rico"
#             },
#             {
#                 "id": "NH",
#                 "name": "New Hampshire",
#                 "alias": "(NH) New Hampshire"
#             },
#             {
#                 "id": "WI",
#                 "name": "Wisconsin",
#                 "alias": "(WI) Wisconsin"
#             },
#             {
#                 "id": "AZ",
#                 "name": "Arizona",
#                 "alias": "(AZ) Arizona"
#             },
#             {
#                 "id": "KY",
#                 "name": "Kentucky",
#                 "alias": "(KY) Kentucky"
#             },
#             {
#                 "id": "WSC",
#                 "name": "West South Central",
#                 "alias": "Region: (WSC) West South Central"
#             },
#             {
#                 "id": "MTN",
#                 "name": "Mountain",
#                 "alias": "Region: (MTN) Mountain"
#             },
#             {
#                 "id": "TN",
#                 "name": "Tennessee",
#                 "alias": "(TN) Tennessee"
#             },
#             {
#                 "id": "ESC",
#                 "name": "East South Central",
#                 "alias": "Region: (ESC) East South Central"
#             },
#             {
#                 "id": "WNC",
#                 "name": "West North Central",
#                 "alias": "Region: (WNC) West North Central"
#             },
#             {
#                 "id": "OK",
#                 "name": "Oklahoma",
#                 "alias": "(OK) Oklahoma"
#             },
#             {
#                 "id": "FL",
#                 "name": "Florida",
#                 "alias": "(FL) Florida"
#             },
#             {
#                 "id": "US",
#                 "name": "U.S. Total",
#                 "alias": "Total: (US) U.S. Total"
#             },
#             {
#                 "id": "AK",
#                 "name": "Alaska",
#                 "alias": "(AK) Alaska"
#             },
#             {
#                 "id": "TX",
#                 "name": "Texas",
#                 "alias": "(TX) Texas"
#             },
#             {
#                 "id": "AR",
#                 "name": "Arkansas",
#                 "alias": "(AR) Arkansas"
#             },
#             {
#                 "id": "NJ",
#                 "name": "New Jersey",
#                 "alias": "(NJ) New Jersey"
#             },
#             {
#                 "id": "NM",
#                 "name": "New Mexico",
#                 "alias": "(NM) New Mexico"
#             },
#             {
#                 "id": "IL",
#                 "name": "Illinois",
#                 "alias": "(IL) Illinois"
#             },
#             {
#                 "id": "IA",
#                 "name": "Iowa",
#                 "alias": "(IA) Iowa"
#             },
#             {
#                 "id": "DC",
#                 "name": "District of Columbia",
#                 "alias": "(DC) District of Columbia"
#             },
#             {
#                 "id": "VT",
#                 "name": "Vermont",
#                 "alias": "(VT) Vermont"
#             },
#             {
#                 "id": "RI",
#                 "name": "Rhode Island",
#                 "alias": "(RI) Rhode Island"
#             },
#             {
#                 "id": "SD",
#                 "name": "South Dakota",
#                 "alias": "(SD) South Dakota"
#             },
#             {
#                 "id": "NV",
#                 "name": "Nevada",
#                 "alias": "(NV) Nevada"
#             }
#         ]
#     },
#     "request": {
#         "command": "/v2/electricity/electric-power-operational-data/facet/location/",
#         "params": {
#             "api_key": "VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"
#         }
#     },
#     "apiVersion": "2.1.4"
# }

# %%
# Extract the 'facets' list from the JSON data
facets_data = data['response']['facets']

# Convert the 'facets' list into a DataFrame
df = pd.DataFrame(facets_data)

# Display the DataFrame
df.head(50)
# Out:
#      id                   name                                alias
# 0    MN              Minnesota                       (MN) Minnesota
# 1   MAT        Middle Atlantic        Region: (MAT) Middle Atlantic
# 2    IN                Indiana                         (IN) Indiana
# 3    UT                   Utah                            (UT) Utah
# 4    CT            Connecticut                     (CT) Connecticut
# 5    VA               Virginia                        (VA) Virginia
# 6    KS                 Kansas                          (KS) Kansas
# 7   PCC     Pacific Contiguous     Region: (PCC) Pacific Contiguous
# 8   PCN  Pacific Noncontiguous  Region: (PCN) Pacific Noncontiguous
# 9    DE               Delaware                        (DE) Delaware
# 10   OH                   Ohio                            (OH) Ohio
# 11   PA           Pennsylvania                    (PA) Pennsylvania
# 12  NEW            New England            Region: (NEW) New England
# 13   MO               Missouri                        (MO) Missouri
# 14   SC         South Carolina                  (SC) South Carolina
# 15   ND           North Dakota                    (ND) North Dakota
# 16   WV          West Virginia                   (WV) West Virginia
# 17   OR                 Oregon                          (OR) Oregon
# 18   MA          Massachusetts                   (MA) Massachusetts
# 19   ME                  Maine                           (ME) Maine
# 20   GA                Georgia                         (GA) Georgia
# 21   CA             California                      (CA) California
# 22   CO               Colorado                        (CO) Colorado
# 23   LA              Louisiana                       (LA) Louisiana
# 24   NE               Nebraska                        (NE) Nebraska
# 25   MT                Montana                         (MT) Montana
# 26   WY                Wyoming                         (WY) Wyoming
# 27   HI                 Hawaii                          (HI) Hawaii
# 28  ENC     East North Central     Region: (ENC) East North Central
# 29   NY               New York                        (NY) New York
# 30   MI               Michigan                        (MI) Michigan
# 31   MS            Mississippi                     (MS) Mississippi
# 32   ID                  Idaho                           (ID) Idaho
# 33   MD               Maryland                        (MD) Maryland
# 34  SAT         South Atlantic         Region: (SAT) South Atlantic
# 35   NC         North Carolina                  (NC) North Carolina
# 36   AL                Alabama                         (AL) Alabama
# 37   WA             Washington                      (WA) Washington
# 38   90                Pacific                         (90) Pacific
# 39   PR            Puerto Rico                     (PR) Puerto Rico
# 40   NH          New Hampshire                   (NH) New Hampshire
# 41   WI              Wisconsin                       (WI) Wisconsin
# 42   AZ                Arizona                         (AZ) Arizona
# 43   KY               Kentucky                        (KY) Kentucky
# 44  WSC     West South Central     Region: (WSC) West South Central
# 45  MTN               Mountain               Region: (MTN) Mountain
# 46   TN              Tennessee                       (TN) Tennessee
# 47  ESC     East South Central     Region: (ESC) East South Central
# 48  WNC     West North Central     Region: (WNC) West North Central
# 49   OK               Oklahoma                        (OK) Oklahoma
