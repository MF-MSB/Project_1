# %%
# Dependencies
import pandas as pd
import requests
import json

# %%
# This document describes how to use the EIA API: https://www.eia.gov/opendata/documentation/APIv2.0.1.pdf
# Execute "GET" request with url
# response_data = requests.get(eia_url)

# %%
#Overview of API calls

# %%
#Detailed view of available information  
# eia_url = "https://api.eia.gov/v2?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&"

# %%
#Detailed view of information available for electricity. 
# eia_url = "https://api.eia.gov/v2/electricity?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&"

# %%
#Detailed view of electricity/electric-power-operational-data entry for EIA API. 
# eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"

# "facets": [
#             {
#                 "id": "location",
#                 "description": "State / Census Region"
#             },
#             {
#                 "id": "sectorid",
#                 "description": "Sector"
#             },
#             {
#                 "id": "fueltypeid",
#                 "description": "Energy Source"
#             }

# %%
#This call enables us to detemrine the fueltypeid for wind is WND
# eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/facet/fueltypeid?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"

# %%
#This call enables us to detemrine the location information is for state. Note there are 64 entries
# eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/facet/location?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"

# %%
#This call enables us to detemrine the sector id is 99.
# eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/facet/sectorid?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"

# %%
# This call returns the monthly wind power generation data at a state and year level. 
eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/data?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&data[]=generation&facets[fueltypeid][]=WND&frequency=annual&sort[0][column]=period&sort[0][direction]=desc&facets[sectorid][]=99"

# %%
#This call returns the monthly wind power generation data for Texas and year level. 
#eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/data?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&data[]=generation&facets[fueltypeid][]=WND&facets[location][]=TX&frequency=monthly&sort[0][column]=period&sort[0][direction]=desc&facets[sectorid][]=99"

# %%
response_data = requests.get(eia_url)

# %%
# Print "response_data" variable
print(response_data)
# Out:
# <Response [200]>

# %%
response_content = response_data.content
print(response_content)
# Out:
# b'{"response":{"total":951,"dateFormat":"YYYY","frequency":"annual","data":[{"period":2022,"location":"ND","stateDescription":"North Dakota","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":16249.888,"generation-units":"thousand megawatthours"},{"period":2022,"location":"CO","stateDescription":"Colorado","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":16911.126,"generation-units":"thousand megawatthours"},{"period":2022,"location":"WSC","stateDescription":"West South Central","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":152339.65755,"generation-units":"thousand megawatthours"},{"period":2022,"location":"MT","stateDescription":"Montana","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":4021.86,"generation-units":"thousand megawatthours"},{"period":2022,"location":"SAT","stateDescription":"South Atlantic","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":3106.487,"generation-units":"thousand megawatthours"},{"period":2022,"location":"CT","stateDescription":"Connecticut","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":12.83308,"generation-units":"thousand megawatthours"},{"period":2022,"location":"IL","stateDescription":"Illinois","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":23493.80554,"generation-units":"thousand megawatthours"},{"period":2022,"location":"UT","stateDescription":"Utah","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":723.439,"generation-units":"thousand megawatthours"},{"period":2022,"location":"PCN","stateDescription":"Pacific Noncontiguous","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":764.69787,"generation-units":"thousand megawatthours"},{"period":2022,"location":"NV","stateDescription":"Nevada","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":315.551,"generation-units":"thousand megawatthours"},{"period":2022,"location":"ID","stateDescription":"Idaho","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":2441.688,"generation-units":"thousand megawatthours"},{"period":2022,"location":"WV","stateDescription":"West Virginia","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":2006.895,"generation-units":"thousand megawatthours"},{"period":2022,"location":"OH","stateDescription":"Ohio","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":3154.007,"generation-units":"thousand megawatthours"},{"period":2022,"location":"MAT","stateDescription":"Middle Atlantic","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":8161.382,"generation-units":"thousand megawatthours"},{"period":2022,"location":"AK","stateDescription":"Alaska","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":139.276,"generation-units":"thousand megawatthours"},{"period":2022,"location":"TN","stateDescription":"Tennessee","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":14.865,"generation-units":"thousand megawatthours"},{"period":2022,"location":"ENC","stateDescription":"East North Central","sectorid":99,"sectorDescription":"All Sectors","fueltypeid":"WND","fuelTypeDescription":"wind","generation":47599.91854,"generation-units":"thousand megawatthours"},{"period":2022,"location":"RI","stateDescription":"Rhode Isla ...

# %%
# Format data as JSON
data = response_data.json()

# %%
# Use json.dumps with argument indent=4 to format data
print(json.dumps(data, indent=4))
# Out:
# {
#     "response": {
#         "total": 951,
#         "dateFormat": "YYYY",
#         "frequency": "annual",
#         "data": [
#             {
#                 "period": 2022,
#                 "location": "ND",
#                 "stateDescription": "North Dakota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 16249.888,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "CO",
#                 "stateDescription": "Colorado",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 16911.126,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "WSC",
#                 "stateDescription": "West South Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 152339.65755,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MT",
#                 "stateDescription": "Montana",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4021.86,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "SAT",
#                 "stateDescription": "South Atlantic",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3106.487,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "CT",
#                 "stateDescription": "Connecticut",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12.83308,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "IL",
#                 "stateDescription": "Illinois",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 23493.80554,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "UT",
#                 "stateDescription": "Utah",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 723.439,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "PCN",
#                 "stateDescription": "Pacific Noncontiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 764.69787,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NV",
#                 "stateDescription": "Nevada",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 315.551,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "ID",
#                 "stateDescription": "Idaho",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2441.688,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "WV",
#                 "stateDescription": "West Virginia",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2006.895,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "OH",
#                 "stateDescription": "Ohio",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3154.007,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MAT",
#                 "stateDescription": "Middle Atlantic",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8161.382,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "AK",
#                 "stateDescription": "Alaska",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 139.276,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "TN",
#                 "stateDescription": "Tennessee",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 14.865,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "ENC",
#                 "stateDescription": "East North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 47599.91854,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "RI",
#                 "stateDescription": "Rhode Island",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 209.338,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "PA",
#                 "stateDescription": "Pennsylvania",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3572.245,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NM",
#                 "stateDescription": "New Mexico",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 14434.55068,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "AZ",
#                 "stateDescription": "Arizona",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1564.348,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "OR",
#                 "stateDescription": "Oregon",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8149.18841,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "KS",
#                 "stateDescription": "Kansas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 29687.479,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "WY",
#                 "stateDescription": "Wyoming",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9780.141,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "PR",
#                 "stateDescription": "Puerto Rico",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 155.009,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "WA",
#                 "stateDescription": "Washington",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8060.912,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "VT",
#                 "stateDescription": "Vermont",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 409.185,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "ESC",
#                 "stateDescription": "East South Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 14.865,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NH",
#                 "stateDescription": "New Hampshire",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 482.322,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "WI",
#                 "stateDescription": "Wisconsin",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1815.722,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7524.605,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "VA",
#                 "stateDescription": "Virginia",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 50.852,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "CA",
#                 "stateDescription": "California",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 14638.061,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NC",
#                 "stateDescription": "North Carolina",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 546.755,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NEW",
#                 "stateDescription": "New England",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4045.74257,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NJ",
#                 "stateDescription": "New Jersey",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 21.629,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "DE",
#                 "stateDescription": "Delaware",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4.377,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NE",
#                 "stateDescription": "Nebraska",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12614.061,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MTN",
#                 "stateDescription": "Mountain",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 50192.70368,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "IA",
#                 "stateDescription": "Iowa",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 45761.36955,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MI",
#                 "stateDescription": "Michigan",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9151.179,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "NY",
#                 "stateDescription": "New York",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4567.508,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "US",
#                 "stateDescription": "U.S. Total",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 434297.35817,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "HI",
#                 "stateDescription": "Hawaii",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 625.42187,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MN",
#                 "stateDescription": "Minnesota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 15091.227,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "ME",
#                 "stateDescription": "Maine",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2716.384,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MD",
#                 "stateDescription": "Maryland",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 497.608,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "OK",
#                 "stateDescription": "Oklahoma",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 37552.755,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "PCC",
#                 "stateDescription": "Pacific Contiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 30848.16141,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "MA",
#                 "stateDescription": "Massachusetts",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 215.68049,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "IN",
#                 "stateDescription": "Indiana",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9985.205,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": 90,
#                 "stateDescription": "Pacific",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 31612.85928,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "WNC",
#                 "stateDescription": "West North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 137223.74255,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "SD",
#                 "stateDescription": "South Dakota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 10295.113,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2022,
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 114786.90255,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "PA",
#                 "stateDescription": "Pennsylvania",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3455.169,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "ND",
#                 "stateDescription": "North Dakota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 14935.203,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "ID",
#                 "stateDescription": "Idaho",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2680.206,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MA",
#                 "stateDescription": "Massachusetts",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 208.62625,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 99474.21553,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": 90,
#                 "stateDescription": "Pacific",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 34640.61541,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "ME",
#                 "stateDescription": "Maine",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2544.197,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "ESC",
#                 "stateDescription": "East South Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 28.186,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MTN",
#                 "stateDescription": "Mountain",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 43072.636,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "PCN",
#                 "stateDescription": "Pacific Noncontiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 790.103,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "IL",
#                 "stateDescription": "Illinois",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 19133.08783,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "WSC",
#                 "stateDescription": "West South Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 132014.52768,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "OH",
#                 "stateDescription": "Ohio",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2586.756,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "WV",
#                 "stateDescription": "West Virginia",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1624.136,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "SAT",
#                 "stateDescription": "South Atlantic",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2710.702,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "WY",
#                 "stateDescription": "Wyoming",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8447.86,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NY",
#                 "stateDescription": "New York",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4156.369,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "WA",
#                 "stateDescription": "Washington",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9297.756,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "WI",
#                 "stateDescription": "Wisconsin",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1593.479,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "IA",
#                 "stateDescription": "Iowa",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 37098.274,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "VA",
#                 "stateDescription": "Virginia",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 49.583,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MI",
#                 "stateDescription": "Michigan",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7696.887,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "VT",
#                 "stateDescription": "Vermont",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 338.188,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MN",
#                 "stateDescription": "Minnesota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12271.314,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "SD",
#                 "stateDescription": "South Dakota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9326.617,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "OK",
#                 "stateDescription": "Oklahoma",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 32540.31215,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NE",
#                 "stateDescription": "Nebraska",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9592.039,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NH",
#                 "stateDescription": "New Hampshire",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 504.23,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "AK",
#                 "stateDescription": "Alaska",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 132.212,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "RI",
#                 "stateDescription": "Rhode Island",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 172.16,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "CA",
#                 "stateDescription": "California",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 15177.00641,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "US",
#                 "stateDescription": "U.S. Total",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 378196.77482,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "CO",
#                 "stateDescription": "Colorado",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 15125.697,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "HI",
#                 "stateDescription": "Hawaii",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 657.891,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NJ",
#                 "stateDescription": "New Jersey",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 19.729,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "PR",
#                 "stateDescription": "Puerto Rico",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 165.727,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MD",
#                 "stateDescription": "Maryland",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 517.431,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NV",
#                 "stateDescription": "Nevada",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 339.944,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "AZ",
#                 "stateDescription": "Arizona",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1600.319,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MAT",
#                 "stateDescription": "Middle Atlantic",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7631.267,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "TN",
#                 "stateDescription": "Tennessee",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 28.186,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NC",
#                 "stateDescription": "North Carolina",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 514.703,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "DE",
#                 "stateDescription": "Delaware",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4.849,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NM",
#                 "stateDescription": "New Mexico",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 10580.735,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "PCC",
#                 "stateDescription": "Pacific Contiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 33850.51241,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "KS",
#                 "stateDescription": "Kansas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 25693.69463,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MT",
#                 "stateDescription": "Montana",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3472.646,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "CT",
#                 "stateDescription": "Connecticut",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12.758,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "OR",
#                 "stateDescription": "Oregon",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 9375.75,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "ENC",
#                 "stateDescription": "East North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 38867.19486,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6534.345,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "UT",
#                 "stateDescription": "Utah",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 825.229,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "IN",
#                 "stateDescription": "Indiana",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 7856.98503,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "NEW",
#                 "stateDescription": "New England",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3780.15925,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2021,
#                 "location": "WNC",
#                 "stateDescription": "West North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 115451.48663,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2020,
#                 "location": "WI",
#                 "stateDescription": "Wisconsin",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1763.375,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2020,
#                 "location": "PR",
#                 "stateDescription": "Puerto Rico",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 142.234,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2020,
#                 "location": "MAT",
#                 "stateDescription": "Middle Atlantic",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 8289.947,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2020,
#                 "location": "WNC",
#                 "stateDescription": "West North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 101615.6472,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2020,
#                 "location": "MT",
#                 "stateDescription": "Montana",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3058.58,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2020,
#                 "location": "ENC",
#                 "stateDescription": "East North Central",
#                 "sectorid": 99,
# ...
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 57.768,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2002,
#                 "location": "TN",
#                 "stateDescription": "Tennessee",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4.068,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2002,
#                 "location": "SD",
#                 "stateDescription": "South Dakota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6.043,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2002,
#                 "location": "WA",
#                 "stateDescription": "Washington",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 416.581,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2002,
#                 "location": "PCC",
#                 "stateDescription": "Pacific Contiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 4595.385,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2002,
#                 "location": "MAT",
#                 "stateDescription": "Middle Atlantic",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 139.394,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2002,
#                 "location": "IA",
#                 "stateDescription": "Iowa",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 918.835,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "TX",
#                 "stateDescription": "Texas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1187.51,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "MN",
#                 "stateDescription": "Minnesota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 897.018,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "SD",
#                 "stateDescription": "South Dakota",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 0.871,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "US",
#                 "stateDescription": "U.S. Total",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6737.332,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "TN",
#                 "stateDescription": "Tennessee",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": null,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "MTN",
#                 "stateDescription": "Mountain",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 413.799,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "ENC",
#                 "stateDescription": "East North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 72.564,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "AK",
#                 "stateDescription": "Alaska",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 0.95,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "MI",
#                 "stateDescription": "Michigan",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 0.28,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "HI",
#                 "stateDescription": "Hawaii",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2.122,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "NEW",
#                 "stateDescription": "New England",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12.133,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "NY",
#                 "stateDescription": "New York",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 20.539,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "WI",
#                 "stateDescription": "Wisconsin",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 72.284,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "MA",
#                 "stateDescription": "Massachusetts",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": null,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "PA",
#                 "stateDescription": "Pennsylvania",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 11.175,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "WY",
#                 "stateDescription": "Wyoming",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 365.159,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "KS",
#                 "stateDescription": "Kansas",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 39.832,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "VT",
#                 "stateDescription": "Vermont",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12.133,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "CA",
#                 "stateDescription": "California",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3499.738,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "MAT",
#                 "stateDescription": "Middle Atlantic",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 31.714,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "WNC",
#                 "stateDescription": "West North Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1428.215,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "PCC",
#                 "stateDescription": "Pacific Contiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3588.325,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "ESC",
#                 "stateDescription": "East South Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": null,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "PCN",
#                 "stateDescription": "Pacific Noncontiguous",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 3.072,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "NE",
#                 "stateDescription": "Nebraska",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 2.63,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "CO",
#                 "stateDescription": "Colorado",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 48.64,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "OR",
#                 "stateDescription": "Oregon",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 88.587,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "WSC",
#                 "stateDescription": "West South Central",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 1187.51,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "IA",
#                 "stateDescription": "Iowa",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 487.864,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": 2001,
#                 "location": "WA",
#                 "stateDescription": "Washington",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": null,
#                 "generation-units": "thousand megawatthours"
#             }
#         ],
#         "description": "Monthly and annual electric power operations by state, sector, and energy source.\n    Source: Form EIA-923"
#     },
#     "request": {
#         "command": "/v2/electricity/electric-power-operational-data/data/",
#         "params": {
#             "api_key": "VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9",
#             "data": [
#                 "generation"
#             ],
#             "facets": {
#                 "fueltypeid": [
#                     "WND"
#                 ],
#                 "sectorid": [
#                     99
#                 ]
#             },
#             "frequency": "annual",
#             "sort": [
#                 {
#                     "column": "period",
#                     "direction": "desc"
#                 }
#             ]
#         }
#     },
#     "apiVersion": "2.1.5",
#     "ExcelAddInVersion": "2.1.0"
# }
