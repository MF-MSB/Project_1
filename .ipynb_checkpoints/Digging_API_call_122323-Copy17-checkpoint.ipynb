# %%
import requests
import json
import pandas as pd

# %%
#Detailed view of electricity/electric-power-operational-data entry for EIA API. 
# eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/data?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&data[]=generation&facets[fueltypeid][]=WND&facets[location][]=TX&frequency=monthly&sort[0][column]=period&sort[0][direction]=desc&facets[sectorid][]=99"

eia_url = 'https://api.eia.gov/v2/total-energy/facet/msn?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9'

# %%
# Execute "GET" request with url
response_data = requests.get(eia_url)

# %%
# Print "response_data" variable
print(response_data)
# Out:
# <Response [200]>

# %%
# Store response using "content" attribute
response_content = response_data.content
print(response_content)
# Out:
# b'{"response":{"totalFacets":980,"facets":[{"id":"ARICBUS","name":"Asphalt and Road Oil Consumed by the Industrial Sector in Trillion Btu"},{"id":"ARTCBUS","name":"Asphalt and Road Oil Product Supplied in Trillion Btu"},{"id":"AVTCPUS","name":"Aviation Gasoline Product Supplied in Thousand Barrels per Day"},{"id":"B1IMPUS","name":"Renewable Diesel Fuel Imports in Thousand Barrels"},{"id":"B1LCBUS","name":"Renewable Diesel Fuel Losses and Co-products in Trillion Btu"},{"id":"BDACBUS","name":"Biodiesel Consumed by the Transportation Sector in Trillion Btu"},{"id":"BDNIPUS","name":"Biodiesel Net Imports in Thousand Barrels"},{"id":"BDTCMUS","name":"Biodiesel Consumption in Million Gallons"},{"id":"BFTCBUS","name":"Biofuels Consumption in Trillion Btu"},{"id":"BMACEUS","name":"Biomass Transportation Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"},{"id":"BOPRBUS","name":"Other Biofuels Production in Trillion Btu"},{"id":"BTL9SUS","name":"Battery Storage Electric Power Sector Generating Units, Usage Factor in Percent"},{"id":"CLACBUS","name":"Coal Consumed by the Transportation Sector in Trillion Btu"},{"id":"CLCCBUS","name":"Coal Consumed by the Commercial Sector in Trillion Btu"},{"id":"CLEIBUS","name":"Coal Consumed by the Electric Power Sector in Trillion Btu"},{"id":"CLERDUS","name":"Average Cost of Coal Receipts at Electric Generating Plants in Dollars per Million Btu, Including Taxes"},{"id":"CLICBUS","name":"Coal Consumed by the Industrial Sector in Trillion Btu"},{"id":"CLIMBUS","name":"Coal Imports in Quadrillion Btu"},{"id":"CLOCPUS","name":"Coal Consumed by the Other Industrial Sector, Total in Thousand Short Tons"},{"id":"CLPRBUS","name":"Coal Production in Trillion Btu"},{"id":"COFMUCL","name":"Average Free on Board Cost of Crude Oil Imports From Colombia in Dollars per Barrel"},{"id":"COFMUNT","name":"Average Free on Board Cost of Crude Oil Imports From All Non-OPEC Countries in Dollars per Barrel"},{"id":"COIMUOP","name":"Average Landed Cost of Crude Oil Imports From All OPEC Countries in Dollars per Barrel"},{"id":"COIMUSA","name":"Average Landed Cost of Crude Oil Imports From Saudi Arabia in Dollars per Barrel"},{"id":"COIMUUS","name":"Average Landed Cost of Crude Oil Imports in Dollars per Barrel"},{"id":"CONIBUS","name":"Crude Oil Net Imports in Quadrillion Btu"},{"id":"CPUCIUS","name":"Consumer Price Index (Urban) in Index 1982-1984 = 100"},{"id":"CYCASUS","name":"Natural Gas Combined Cycle Plants Generating Units, Capacity Factor in Percent"},{"id":"CYI9SUS","name":"Natural Gas Combined Cycle Plants Industrial Sector Generating Units, Capacity Factor in Percent"},{"id":"DFCCEUS","name":"Distillate Fuel Oil Commercial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"},{"id":"DFICBUS","name":"Distillate Fuel Oil Consumed by the Industrial Sector in Trillion Btu"},{"id":"DFIMPUS","name":"Distillate Fuel Oil Imports in Thousand Barrels per Day"},{"id":"DFROPUS","name":"Distillate Fuel Oil Refinery and Blender Net Production in Thousand Barrels per Day"},{"id":"ELC5PUS","name":"Electricity Net Generation Total (including from sources not shown), Commercial Sector in Million Kilowatthours"},{"id":"ELGBPUS","name":"Total Electric, Net Summer Capacity in Million Kilowatts"},{"id":"ELI9PUS","name":"Total Industrial Sector, Net Summer Capacity in Million Kilowatts"},{"id":"ELNIBUS","name":"Electric Power Sector Electricity Net Imports in Trillion Btu"},{"id":"ENPRPUS","name":"Fuel Ethanol Production in Thousand Barrels"},{"id":"ESACUUS","name":"Average Price of Electricity to Ultimate Customers, Transportation in Cents per Kilowatthour,  Including Taxes"},{"id":"ESCCEUS","name":"Commercial Share of Electric Power Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"},{"id":"ESRCBUS","name":"Electricity Sales to Ultimate Customers in the Residential Sector in Trillion Btu"},{"id":"ESRCPUS","name":"Electricity Sales to Ultimate Customers, Residential in Million Kilowatthours"},{"id":"E ...

# %%
# Format data as JSON
data = response_data.json()

# %%
# Use json.dumps with argument indent=4 to format data
print(json.dumps(data, indent=4))
# Out:
# {
#     "response": {
#         "totalFacets": 980,
#         "facets": [
#             {
#                 "id": "ARICBUS",
#                 "name": "Asphalt and Road Oil Consumed by the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "ARTCBUS",
#                 "name": "Asphalt and Road Oil Product Supplied in Trillion Btu"
#             },
#             {
#                 "id": "AVTCPUS",
#                 "name": "Aviation Gasoline Product Supplied in Thousand Barrels per Day"
#             },
#             {
#                 "id": "B1IMPUS",
#                 "name": "Renewable Diesel Fuel Imports in Thousand Barrels"
#             },
#             {
#                 "id": "B1LCBUS",
#                 "name": "Renewable Diesel Fuel Losses and Co-products in Trillion Btu"
#             },
#             {
#                 "id": "BDACBUS",
#                 "name": "Biodiesel Consumed by the Transportation Sector in Trillion Btu"
#             },
#             {
#                 "id": "BDNIPUS",
#                 "name": "Biodiesel Net Imports in Thousand Barrels"
#             },
#             {
#                 "id": "BDTCMUS",
#                 "name": "Biodiesel Consumption in Million Gallons"
#             },
#             {
#                 "id": "BFTCBUS",
#                 "name": "Biofuels Consumption in Trillion Btu"
#             },
#             {
#                 "id": "BMACEUS",
#                 "name": "Biomass Transportation Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "BOPRBUS",
#                 "name": "Other Biofuels Production in Trillion Btu"
#             },
#             {
#                 "id": "BTL9SUS",
#                 "name": "Battery Storage Electric Power Sector Generating Units, Usage Factor in Percent"
#             },
#             {
#                 "id": "CLACBUS",
#                 "name": "Coal Consumed by the Transportation Sector in Trillion Btu"
#             },
#             {
#                 "id": "CLCCBUS",
#                 "name": "Coal Consumed by the Commercial Sector in Trillion Btu"
#             },
#             {
#                 "id": "CLEIBUS",
#                 "name": "Coal Consumed by the Electric Power Sector in Trillion Btu"
#             },
#             {
#                 "id": "CLERDUS",
#                 "name": "Average Cost of Coal Receipts at Electric Generating Plants in Dollars per Million Btu, Including Taxes"
#             },
#             {
#                 "id": "CLICBUS",
#                 "name": "Coal Consumed by the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "CLIMBUS",
#                 "name": "Coal Imports in Quadrillion Btu"
#             },
#             {
#                 "id": "CLOCPUS",
#                 "name": "Coal Consumed by the Other Industrial Sector, Total in Thousand Short Tons"
#             },
#             {
#                 "id": "CLPRBUS",
#                 "name": "Coal Production in Trillion Btu"
#             },
#             {
#                 "id": "COFMUCL",
#                 "name": "Average Free on Board Cost of Crude Oil Imports From Colombia in Dollars per Barrel"
#             },
#             {
#                 "id": "COFMUNT",
#                 "name": "Average Free on Board Cost of Crude Oil Imports From All Non-OPEC Countries in Dollars per Barrel"
#             },
#             {
#                 "id": "COIMUOP",
#                 "name": "Average Landed Cost of Crude Oil Imports From All OPEC Countries in Dollars per Barrel"
#             },
#             {
#                 "id": "COIMUSA",
#                 "name": "Average Landed Cost of Crude Oil Imports From Saudi Arabia in Dollars per Barrel"
#             },
#             {
#                 "id": "COIMUUS",
#                 "name": "Average Landed Cost of Crude Oil Imports in Dollars per Barrel"
#             },
#             {
#                 "id": "CONIBUS",
#                 "name": "Crude Oil Net Imports in Quadrillion Btu"
#             },
#             {
#                 "id": "CPUCIUS",
#                 "name": "Consumer Price Index (Urban) in Index 1982-1984 = 100"
#             },
#             {
#                 "id": "CYCASUS",
#                 "name": "Natural Gas Combined Cycle Plants Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "CYI9SUS",
#                 "name": "Natural Gas Combined Cycle Plants Industrial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "DFCCEUS",
#                 "name": "Distillate Fuel Oil Commercial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "DFICBUS",
#                 "name": "Distillate Fuel Oil Consumed by the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "DFIMPUS",
#                 "name": "Distillate Fuel Oil Imports in Thousand Barrels per Day"
#             },
#             {
#                 "id": "DFROPUS",
#                 "name": "Distillate Fuel Oil Refinery and Blender Net Production in Thousand Barrels per Day"
#             },
#             {
#                 "id": "ELC5PUS",
#                 "name": "Electricity Net Generation Total (including from sources not shown), Commercial Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "ELGBPUS",
#                 "name": "Total Electric, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "ELI9PUS",
#                 "name": "Total Industrial Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "ELNIBUS",
#                 "name": "Electric Power Sector Electricity Net Imports in Trillion Btu"
#             },
#             {
#                 "id": "ENPRPUS",
#                 "name": "Fuel Ethanol Production in Thousand Barrels"
#             },
#             {
#                 "id": "ESACUUS",
#                 "name": "Average Price of Electricity to Ultimate Customers, Transportation in Cents per Kilowatthour,  Including Taxes"
#             },
#             {
#                 "id": "ESCCEUS",
#                 "name": "Commercial Share of Electric Power Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "ESRCBUS",
#                 "name": "Electricity Sales to Ultimate Customers in the Residential Sector in Trillion Btu"
#             },
#             {
#                 "id": "ESRCPUS",
#                 "name": "Electricity Sales to Ultimate Customers, Residential in Million Kilowatthours"
#             },
#             {
#                 "id": "ESTCPUS",
#                 "name": "Electricity Sales to Ultimate Customers, Total in Million Kilowatthours"
#             },
#             {
#                 "id": "EV2CNUS",
#                 "name": "Number of level 2 charging ports in Number"
#             },
#             {
#                 "id": "EVCHPUS",
#                 "name": "Total number of locations in Number"
#             },
#             {
#                 "id": "EVPPPUS",
#                 "name": "Number of locations with public and private ports in Number"
#             },
#             {
#                 "id": "FFL9PUS",
#                 "name": "Fossil Fuels Electric Power Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "HLACEUS",
#                 "name": "HGL Transportation Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "HLEXPUS",
#                 "name": "Total Hydrocarbon Gas Liquids Exports in Thousand Barrels per Day"
#             },
#             {
#                 "id": "HLRCBUS",
#                 "name": "Propane Consumed by the Residential Sector in Trillion Btu"
#             },
#             {
#                 "id": "HLRCEUS",
#                 "name": "HGL Residential Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "JFACEUS",
#                 "name": "Jet Fuel Transportation Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "JFPSPUS",
#                 "name": "Jet Fuel Stocks, End of Period in Million Barrels"
#             },
#             {
#                 "id": "JKTCUUS",
#                 "name": "Average Refiner Price of Kerosene-Type Jet Fuel to End Users in Dollars per Gallon Excluding Taxes"
#             },
#             {
#                 "id": "KSICEUS",
#                 "name": "Kerosene Industrial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "KSTCPUS",
#                 "name": "Kerosene Product Supplied in Thousand Barrels per Day"
#             },
#             {
#                 "id": "LNEXPCH",
#                 "name": "Natural Gas Exports to China in Billion Cubic Feet"
#             },
#             {
#                 "id": "LNEXPIH",
#                 "name": "Natural Gas Exports to India in Billion Cubic Feet"
#             },
#             {
#                 "id": "LNEXPSP",
#                 "name": "Natural Gas Exports to Spain in Billion Cubic Feet"
#             },
#             {
#                 "id": "LNIMPOM",
#                 "name": "Natural Gas Imports from Oman in Billion Cubic Feet"
#             },
#             {
#                 "id": "LUACEUS",
#                 "name": "Lubricants Transportation Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "MGICPUS",
#                 "name": "Motor Gasoline Consumed by the Industrial Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "MGWHUUS",
#                 "name": "Average Refiner Price of Finished Motor Gasoline for Resale in Dollars per Gallon Excluding Taxes"
#             },
#             {
#                 "id": "NGAJPUS",
#                 "name": "Natural Gas Balancing Item in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGCCSUS",
#                 "name": "Percentage of Commercial Sector Consumption for Which Price Data Are Available in Percent"
#             },
#             {
#                 "id": "NGEGPUS",
#                 "name": "Electricity Net Generation From Natural Gas, Electric Power Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "NGETPUS",
#                 "name": "Electricity Net Generation From Natural Gas, All Sectors in Million Kilowatthours"
#             },
#             {
#                 "id": "NGI5PUS",
#                 "name": "Electricity Net Generation From Natural Gas, Industrial Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "NGL1PUS",
#                 "name": "Natural Gas Consumption for Electricity Generation, Electric Power Sector in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGL9PUS",
#                 "name": "Natural Gas Electric Power Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "NGNFPUS",
#                 "name": "Natural Gas Non-Combustion Consumption in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGUSPUS",
#                 "name": "Natural Gas in Underground Storage, End of Period, Total in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGWCPUS",
#                 "name": "Change in Working Gas From Same Period Previous Year, Volume in Billion Cubic Feet"
#             },
#             {
#                 "id": "NNTCEUS",
#                 "name": "Natural Gas, Excluding Supplemental Gaseous Fuels, CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "NUL9SUS",
#                 "name": "Nuclear Electric Power Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "OGNRPON",
#                 "name": "Crude Oil and Natural Gas Rotary Rigs in Operation, Onshore in Number of Rigs"
#             },
#             {
#                 "id": "OGWSPUS",
#                 "name": "Active Well Service Rig Count in Number of Rigs"
#             },
#             {
#                 "id": "OLECPUS",
#                 "name": "Other Petroleum Liquids Consumption for Electricity Generation and Useful Thermal Output, All Sectors in Thousand Barrels"
#             },
#             {
#                 "id": "OMNIVUS",
#                 "name": "Non-Energy Balance in Million Dollars"
#             },
#             {
#                 "id": "OPACBUS",
#                 "name": "Other Products Consumed by the Transportation Sector in Trillion Btu"
#             },
#             {
#                 "id": "OTECBUS",
#                 "name": "Other Consumption for Electricity Generation and Useful Thermal Output, All Sectors in Trillion Btu"
#             },
#             {
#                 "id": "OTI3BUS",
#                 "name": "Other Consumption for Electricity Generation and Useful Thermal Output, Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "OTNFPUS",
#                 "name": "Other Petroleum Non-Combusiton Consumption in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAC5PUS",
#                 "name": "Electricity Net Generation From Petroleum, Commercial Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "PACCPUS",
#                 "name": "Total Petroleum Consumed by the Commercial Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAEGPUS",
#                 "name": "Electricity Net Generation From Petroleum, Electric Power Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "PAEIEUS",
#                 "name": "Petroleum Electric Power Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "PAEKPUS",
#                 "name": "Total Petroleum Stocks, Electric Power Sector, End of Period in Thousand Barrels"
#             },
#             {
#                 "id": "PAEXVUS",
#                 "name": "Petroleum Exports in Million Dollars"
#             },
#             {
#                 "id": "PAI5PUS",
#                 "name": "Electricity Net Generation From Petroleum, Industrial Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "PAIMPCN",
#                 "name": "Petroleum Imports From Canada in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAIMPNT",
#                 "name": "Petroleum Imports From Total Non-OPEC Countries in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAIMPUA",
#                 "name": "Petroleum Imports from United Arab Emirates in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAL9SUS",
#                 "name": "Petroleum Electric Power Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "PASCPUS",
#                 "name": "Petroleum Stock Change in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PCEIEUS",
#                 "name": "Petroleum Coke Electric Power Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "PCERDUS",
#                 "name": "Average Cost of Petroleum Coke Receipts at Electric Generating Plants in Dollars per Million Btu, Including Taxes"
#             },
#             {
#                 "id": "PMICEUS",
#                 "name": "Petroleum, Excluding Biofuels, Industrial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "PMTCEUS",
#                 "name": "Petroleum, Excluding Biofuels, CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "PQTCPUS",
#                 "name": "Propane Product Supplied in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PRTCUUS",
#                 "name": "Average Refiner Price of Propane (Consumer Grade) to End Users in Dollars per Gallon Excluding Taxes"
#             },
#             {
#                 "id": "PZPSPUS",
#                 "name": "Propane/Propylene Stocks in Million Barrels"
#             },
#             {
#                 "id": "PZTCBUS",
#                 "name": "Propane/Propylene Product Supplied in Trillion Btu"
#             },
#             {
#                 "id": "RAIMUUS",
#                 "name": "Average Refiner Acquisition Cost of Crude Oil, Imported in Dollars per Barrel"
#             },
#             {
#                 "id": "REC9PUS",
#                 "name": "Renewable Energy Commercial Sector, Net Summer Capacity  in Million Kilowatts"
#             },
#             {
#                 "id": "RERCBUS",
#                 "name": "Total Renewable Energy Consumed by the Residential Sector in Trillion Btu"
#             },
#             {
#                 "id": "RFACBUS",
#                 "name": "Residual Fuel Oil Consumed by the Transportation Sector in Trillion Btu"
#             },
#             {
#                 "id": "RFCCBUS",
#                 "name": "Residual Fuel Oil Consumed by the Commercial Sector in Trillion Btu"
#             },
#             {
#                 "id": "RFCCEUS",
#                 "name": "Residual Fuel Oil Commercial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "RFCCPUS",
#                 "name": "Residual Fuel Oil Consumed by the Commercial Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "RFL1PUS",
#                 "name": "Residual Fuel Oil Consumption for Electricity Generation, Electric Power Sector in Thousand Barrels"
#             },
#             {
#                 "id": "SOC7PUS",
#                 "name": "Small-Scale Solar Photovoltaic Generation: Commercial Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "SOETPUS",
#                 "name": "Electricity Net Generation From Solar, All Sectors in Million Kilowatthours"
#             },
#             {
#                 "id": "TEAJBUS",
#                 "name": "Primary Energy Stock Change and Other in Trillion Btu"
#             },
#             {
#                 "id": "TECCEUS",
#                 "name": "Total Energy Commercial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "TEICEUS",
#                 "name": "Total Industrial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "TNCCBUS",
#                 "name": "End-Use Energy Consumed by the Commercial Sector in Trillion Btu"
#             },
#             {
#                 "id": "WDC9PUS",
#                 "name": "Wood Commercial Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "WDEPBUS",
#                 "name": "Wood Consumption for Electricity Generation, All Sectors in Trillion Btu"
#             },
#             {
#                 "id": "WDETPUS",
#                 "name": "Electricity Net Generation From Wood, All Sectors in Million Kilowatthours"
#             },
#             {
#                 "id": "WSGBPUS",
#                 "name": "Waste, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "WYEGBUS",
#                 "name": "Wind Energy Consumed by the Electric Power Sector in Trillion Btu"
#             },
#             {
#                 "id": "WYEGPUS",
#                 "name": "Electricity Net Generation From Wind, Electric Power Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "WYICBUS",
#                 "name": "Wind Energy Consumed by the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "ZWHDPUS",
#                 "name": "Heating Degree-Days, United States in Number"
#             },
#             {
#                 "id": "AVACBUS",
#                 "name": "Aviation Gasoline Consumed by the Transportation Sector in Trillion Btu"
#             },
#             {
#                 "id": "AVTCEUS",
#                 "name": "Aviation Gasoline CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "B1PRMUS",
#                 "name": "Renewable Diesel Fuel Production in Million Gallons"
#             },
#             {
#                 "id": "B1TCBUS",
#                 "name": "Renewable Diesel Fuel Consumption in Trillion Btu"
#             },
#             {
#                 "id": "BDEXPUS",
#                 "name": "Biodiesel Exports in Thousand Barrels"
#             },
#             {
#                 "id": "BDFDBUS",
#                 "name": "Biodiesel Feedstock in Trillion Btu"
#             },
#             {
#                 "id": "BFPRBUS",
#                 "name": "Biofuels Production in Trillion Btu"
#             },
#             {
#                 "id": "BMEXBUS",
#                 "name": "Biomass Exports in Quadrillion Btu"
#             },
#             {
#                 "id": "BMICEUS",
#                 "name": "Biomass Industrial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "BMNIBUS",
#                 "name": "Biomass Net Imports in Quadrillion Btu"
#             },
#             {
#                 "id": "BMRCBUS",
#                 "name": "Biomass Energy Consumed by the Residential Sector in Trillion Btu"
#             },
#             {
#                 "id": "BOIMPUS",
#                 "name": "Other Biofuels Imports in Thousand Barrels"
#             },
#             {
#                 "id": "BTL9PUS",
#                 "name": "Battery Storage Electric Power Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "CCEXBUS",
#                 "name": "Coal Coke Exports in Quadrillion Btu"
#             },
#             {
#                 "id": "CKTCEUS",
#                 "name": "Coal, Including Coal Coke Net Imports, CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "CLACPUS",
#                 "name": "Coal Consumed by the Transportation Sector in Thousand Short Tons"
#             },
#             {
#                 "id": "CLC9PUS",
#                 "name": "Coal Commercial Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "CLEPPUS",
#                 "name": "Coal Consumption for Electricity Generation, All Sectors in Thousand Short Tons"
#             },
#             {
#                 "id": "CLGBPUS",
#                 "name": "Coal, Net Summer Capacity  in Million Kilowatts"
#             },
#             {
#                 "id": "CLI9SUS",
#                 "name": "Coal Industrial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "CLICEUS",
#                 "name": "Coal Industrial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "CLIMPUS",
#                 "name": "Coal Imports in Thousand Short Tons"
#             },
#             {
#                 "id": "CLLUPUS",
#                 "name": "Coal Losses and Unaccounted for in Thousand Short Tons"
#             },
#             {
#                 "id": "CLNFBUS",
#                 "name": "Coal Non-Combustion Consumption in Quadrillion Btu"
#             },
#             {
#                 "id": "CLNIPUS",
#                 "name": "Coal Net Imports in Thousand Short Tons"
#             },
#             {
#                 "id": "CLPSPUS",
#                 "name": "Coal Stocks, Total, End of Period in Thousand Short Tons"
#             },
#             {
#                 "id": "CLRCPUS",
#                 "name": "Coal Consumed by the Residential Sector in Thousand Short Tons"
#             },
#             {
#                 "id": "CLSCPUS",
#                 "name": "Coal Stock Change in Thousand Short Tons"
#             },
#             {
#                 "id": "CLSJPUS",
#                 "name": "Coal Stocks, End-Use Sectors Total, End of Period in Thousand Short Tons"
#             },
#             {
#                 "id": "CLSOPUS",
#                 "name": "Coal Stocks, Industrial Sector, Other, End of Period in Thousand Short Tons"
#             },
#             {
#                 "id": "COFMUUS",
#                 "name": "Average Free on Board Cost of Crude Oil Imports in Dollars per Barrel"
#             },
#             {
#                 "id": "COIMPUS",
#                 "name": "Crude Oil Imports, Total in Thousand Barrels per Day"
#             },
#             {
#                 "id": "COIMUAQ",
#                 "name": "Average Landed Cost of Crude Oil Imports From Angola in Dollars per Barrel"
#             },
#             {
#                 "id": "COSQPUS",
#                 "name": "Crude Oil Stocks, Strategic Petroleum Reserve, End of Period in Million Barrels"
#             },
#             {
#                 "id": "DFPSPUS",
#                 "name": "Distillate Fuel Oil Stocks, End of Period in Million Barrels"
#             },
#             {
#                 "id": "DFRCEUS",
#                 "name": "Distillate Fuel Oil Residential Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "DFRCPUS",
#                 "name": "Distillate Fuel Oil Consumed by the Residential Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "DKEPPUS",
#                 "name": "Distillate Fuel Oil Consumption for Electricity Generation, All Sectors in Thousand Barrels"
#             },
#             {
#                 "id": "ELL9PUS",
#                 "name": "Total Electric Power Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "ELTCPUS",
#                 "name": "Electricity End Use, Total in Million Kilowatthours"
#             },
#             {
#                 "id": "ESTCBUS",
#                 "name": "Electricity Sales to Ultimate Customers in the End-Use Sectors in Trillion Btu"
#             },
#             {
#                 "id": "EV0CNUS",
#                 "name": "Number of legacy charging ports in Number"
#             },
#             {
#                 "id": "EV1CNUS",
#                 "name": "Number of level 1 charging ports in Number"
#             },
#             {
#                 "id": "EVCHNUS",
#                 "name": "Total number of ports in Number"
#             },
#             {
#                 "id": "EVNOPUS",
#                 "name": "Number of locations with non-networked ports only in Number"
#             },
#             {
#                 "id": "EVPVPUS",
#                 "name": "Number of locations with private ports only in Number"
#             },
#             {
#                 "id": "GEFFBUS",
#                 "name": "Geothermal Energy Consumption, Fossil Fuel Equivalent in Trillion Btu"
#             },
#             {
#                 "id": "GEGBPUS",
#                 "name": "Geothermal, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "GEI9PUS",
#                 "name": "Geothermal Industrial Sector, Net Summer Capacity  in Million Kilowatts"
#             },
#             {
#                 "id": "HLACBUS",
#                 "name": "Propane Consumed by the Transportation Sector in Trillion Btu"
#             },
#             {
#                 "id": "HLICEUS",
#                 "name": "HGL Industrial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "HPC9SUS",
#                 "name": "Hydroelectric Pumped Storage Commercial Sector Generating Units, Usage Factor in Percent"
#             },
#             {
#                 "id": "HPETPUS",
#                 "name": "Electricity Net Generation From Hydroelectric Pumped Storage, All Sectors in Million Kilowatthours"
#             },
#             {
#                 "id": "HPL9PUS",
#                 "name": "Hydroelectric Pumped Storage Electric Power Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "HVCASUS",
#                 "name": "Hydroelectric Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "JFACPUS",
#                 "name": "Jet Fuel Consumed by the Transportation Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "JFROPUS",
#                 "name": "Jet Fuel Refinery and Blender Net Production in Thousand Barrels per Day"
#             },
#             {
#                 "id": "KSCCBUS",
#                 "name": "Kerosene Consumed by the Commercial Sector in Trillion Btu"
#             },
#             {
#                 "id": "KSTCEUS",
#                 "name": "Kerosene CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "LNIMPAG",
#                 "name": "Natural Gas Imports from Algeria in Billion Cubic Feet"
#             },
#             {
#                 "id": "LNIMPOT",
#                 "name": "Natural Gas Imports from Other Countries in Billion Cubic Feet"
#             },
#             {
#                 "id": "LNIMPYE",
#                 "name": "Natural Gas Imports from Yemen in Billion Cubic Feet"
#             },
#             {
#                 "id": "LUTCPUS",
#                 "name": "Lubricants Product Supplied in Thousand Barrels per Day"
#             },
#             {
#                 "id": "MGUCUUS",
#                 "name": "All Grades of Gasoline, U.S. City Average Retail Price in Dollars per Gallon Including Taxes"
#             },
#             {
#                 "id": "MMCCEUS",
#                 "name": "Motor Gasoline, Excluding Ethanol, Commercial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "MMICEUS",
#                 "name": "Motor Gasoline, Excluding Ethanol, Industrial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "NGEISUS",
#                 "name": "Percentage of Electric Power Sector Consumption for Which Price Data Are Available in Percent"
#             },
#             {
#                 "id": "NGEXPUS",
#                 "name": "Total Natural Gas Exports in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGIMPCN",
#                 "name": "Natural Gas Imports from Canada in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGNFBUS",
#                 "name": "Natural Gas Non-Combustion Consumption in Quadrillion Btu"
#             },
#             {
#                 "id": "NGPRBUS",
#                 "name": "Natural Gas (Dry) Production in Trillion Btu"
#             },
#             {
#                 "id": "NGRCAUS",
#                 "name": "Average Cost of Residential Natural Gas in Dollars per Million Btu"
#             },
#             {
#                 "id": "NGRCPUS",
#                 "name": "Natural Gas Consumed by the Residential Sector in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGSFPUS",
#                 "name": "Supplemental Gaseous Fuels in Billion Cubic Feet"
#             },
#             {
#                 "id": "NLPRBUS",
#                 "name": "Natural Gas Plant Liquids Production in Trillion Btu"
#             },
#             {
#                 "id": "NNRCEUS",
#                 "name": "Natural Gas, Excluding Supplemental Gaseous Fuels, Residential Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "NUI9SUS",
#                 "name": "Nuclear Industrial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "NYCASUS",
#                 "name": "Natural Gas Conventional Steam Plants Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "OGPFPUS",
#                 "name": "Crude Oil Wells, Total Footage Drilled  in Thousand Feet"
#             },
#             {
#                 "id": "OJECBUS",
#                 "name": "Other Gases Consumption for Electricity Generation and Useful Thermal Output, All Sectors in Trillion Btu"
#             },
#             {
#                 "id": "OLRIPUS",
#                 "name": "Other Liquids Refinery and Blender Net Inputs in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAC9SUS",
#                 "name": "Petroleum Commercial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "PACASUS",
#                 "name": "Petroleum Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "PAEXPMX",
#                 "name": "Petroleum Exports to Mexico in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAI1PUS",
#                 "name": "Petroleum Consumption for Electricity Generation, Industrial Sector in Thousand Barrels"
#             },
#             {
#                 "id": "PAIMPBZ",
#                 "name": "Petroleum Imports From Brazil in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAIMPEN",
#                 "name": "Petroleum Imports from Ecuador in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PANIPUS",
#                 "name": "Petroleum Net Imports in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PATCBUS",
#                 "name": "Total Petroleum Products Supplied in Trillion Btu"
#             },
#             {
#                 "id": "PATWPUS",
#                 "name": "Wells Drilled, Crude Oil in Number"
#             },
#             {
#                 "id": "PCEIMUS",
#                 "name": "Petroleum Coke Consumption for Electricity Generation and Useful Thermal Output, Electric Power Sector in Thousand Short Tons"
#             },
#             {
#                 "id": "PCICBUS",
#                 "name": "Petroleum Coke Consumed by the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "PCNFBUS",
#                 "name": "Petroleum Coke Non-Combustion Consumption in Quadrillion Btu"
#             },
#             {
#                 "id": "PCTCBUS",
#                 "name": "Petroleum Coke Product Supplied in Trillion Btu"
#             },
#             {
#                 "id": "PCTCEUS",
#                 "name": "Petroleum Coke CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "PFNFPUS",
#                 "name": "Petrochemical Feedstocks Non-Combustion Consumption in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PTEIPUS",
#                 "name": "Total Petroleum Consumption for Electricity Generation and Useful Thermal Output, Electric Power Sector in Thousand Barrels"
#             },
#             {
#                 "id": "PZICPUS",
#                 "name": "Propane/Propylene Consumed by the Industrial Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "RADMUUS",
#                 "name": "Average Refiner Acquisition Cost of Crude Oil, Domestic in Dollars per Barrel"
#             },
#             {
#                 "id": "RBTCUUS",
#                 "name": "Average Refiner Price of Residual Fuel Oil, Sulfur Content Less Than or Equal to 1 Percent, Sales to End Users in Dollars per Gallon Excluding Taxes"
#             },
#             {
#                 "id": "RECCBUS",
#                 "name": "Total Renewable Energy Consumed by the Commercial Sector in Trillion Btu"
#             },
#             {
#                 "id": "RRRTUUS",
#                 "name": "Regular Motor Gasoline, Reformulated Gasoline Areas, Average Retail Price in Dollars per Gallon Including Taxes"
#             },
#             {
#                 "id": "SHI9SUS",
#                 "name": "Solar Thermal Industrial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "SOCCBUS",
#                 "name": "Solar Energy Consumed by the Commercial Sector in Trillion Btu"
#             },
#             {
#                 "id": "SOEGBUS",
#                 "name": "Utility-Scale Solar Energy Consumption for Electricity:  Electric Power Sector  in Trillion Btu"
#             },
#             {
#                 "id": "TEIMBUS",
#                 "name": "Total Primary Energy Imports in Trillion Btu"
#             },
#             {
#                 "id": "TEIMVUS",
#                 "name": "Energy Imports in Million Dollars"
#             },
#             {
#                 "id": "TESSBUS",
#                 "name": "Total Energy Consumed by the End-Use-Sectors in Trillion Btu"
#             },
#             {
#                 "id": "WDEGPUS",
#                 "name": "Electricity Net Generation From Wood, Electric Power Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "WDL9PUS",
#                 "name": "Wood Electric Power Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "WDRCBUS",
#                 "name": "Wood Energy Consumed by the Residential Sector in Trillion Btu"
#             },
#             {
#                 "id": "WSC5PUS",
#                 "name": "Electricity Net Generation From Waste, Commercial Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "WSEIBUS",
#                 "name": "Waste Consumption for Electricity Generation and Useful Thermal Output, Electric Power Sector in Trillion Btu"
#             },
#             {
#                 "id": "WSTCEUS",
#                 "name": "Biomass Waste CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "WYCASUS",
#                 "name": "Wind Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "WYETPUS",
#                 "name": "Electricity Net Generation From Wind, All Sectors in Million Kilowatthours"
#             },
#             {
#                 "id": "WYFFBUS",
#                 "name": "Wind Energy Consumption, Fossil Fuel Equivalent in Trillion Btu"
#             },
#             {
#                 "id": "WYI9SUS",
#                 "name": "Wind Industrial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "ZWCDPC2",
#                 "name": "Cooling Degree-Days, Middle Atlantic in Number"
#             },
#             {
#                 "id": "ZWCDPC4",
#                 "name": "Cooling Degree-Days, West North Central in Number"
#             },
#             {
#                 "id": "ZWHDPC8",
#                 "name": "Heating Degree-Days, Mountain in Number"
#             },
#             {
#                 "id": "ARICPUS",
#                 "name": "Asphalt and Road Oil Consumed by the Industrial Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "ARNFPUS",
#                 "name": "Asphalt & Road Oil Non-Combustion Consumption in Thousand Barrels per Day"
#             },
#             {
#                 "id": "ARTCPUS",
#                 "name": "Asphalt and Road Oil Product Supplied in Thousand Barrels per Day"
#             },
#             {
#                 "id": "BDSCPUS",
#                 "name": "Biodiesel Stock Change in Thousand Barrels"
#             },
#             {
#                 "id": "BDTCPUS",
#                 "name": "Biodiesel Consumption in Thousand Barrels"
#             },
#             {
#                 "id": "BFLCBUS",
#                 "name": "Biomass Losses and Co-products in the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "BMC9SUS",
#                 "name": "Biomass Commercial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "BML9SUS",
#                 "name": "Biomass Electric Power Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "BMTCEUS",
#                 "name": "Biomass CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "BOLCBUS",
#                 "name": "Other Biofuels Losses and Co-products in Trillion Btu"
#             },
#             {
#                 "id": "BOTCBUS",
#                 "name": "Other Biofuels Consumption in Trillion Btu"
#             },
#             {
#                 "id": "CLC9SUS",
#                 "name": "Coal Commercial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "CLCASUS",
#                 "name": "Coal Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "CLEIEUS",
#                 "name": "Coal Electric Power Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "CLL1PUS",
#                 "name": "Coal Consumption for Electricity Generation, Electric Power Sector in Thousand Short Tons"
#             },
#             {
#                 "id": "CLL9PUS",
#                 "name": "Coal Electric Power Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "CLSDPUS",
#                 "name": "Coal Stocks, Producers and Distributors, End of Period in Thousand Short Tons"
#             },
#             {
#                 "id": "COEXBUS",
#                 "name": "Crude Oil Exports in Quadrillion Btu"
#             },
#             {
#                 "id": "COIMUUK",
#                 "name": "Average Landed Cost of Crude Oil Imports From United Kingdom in Dollars per Barrel"
#             },
#             {
#                 "id": "CYC9SUS",
#                 "name": "Natural Gas Combined Cycle Plants Commercial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "DFACPUS",
#                 "name": "Distillate Fuel Oil Consumed by the Transportation Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "DFEXPUS",
#                 "name": "Distillate Fuel Oil Exports in Thousand Barrels per Day"
#             },
#             {
#                 "id": "DFONUUS",
#                 "name": "On-Highway Diesel Fuel Average Price in Dollars per Gallon Including Taxes"
#             },
#             {
#                 "id": "DFTCBUS",
#                 "name": "Distillate Fuel Oil Product Supplied in Trillion Btu"
#             },
#             {
#                 "id": "DSWHUUS",
#                 "name": "Average Refiner Price of No. 2 Diesel Fuel for Resale in Dollars per Gallon Excluding Taxes"
#             },
#             {
#                 "id": "ELEGPUS",
#                 "name": "Electricity Net Generation Total (including from sources not shown), Electric Power Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "EMFDBUS",
#                 "name": "Fuel Ethanol, Excluding Denaturant, Feedstock in Trillion Btu"
#             },
#             {
#                 "id": "ENTCBUS",
#                 "name": "Fuel Ethanol Consumption in Trillion Btu"
#             },
#             {
#                 "id": "ESACBUS",
#                 "name": "Electricity Sales to Ultimate Customers in the Transportation Sector in Trillion Btu"
#             },
#             {
#                 "id": "ESCMUUS",
#                 "name": "Average Price of Electricity to Ultimate Customers, Commercial in Cents per Kilowatthour,  Including Taxes"
#             },
#             {
#                 "id": "EVDCNUS",
#                 "name": "Number of DC fast charging ports in Number"
#             },
#             {
#                 "id": "FFGBPUS",
#                 "name": "Fossil Fuels, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "GEI9SUS",
#                 "name": "Geothermal Industrial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "HLICBUS",
#                 "name": "Total Hydrocarbon Gas Liquids Consumed by the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "HLROPUS",
#                 "name": "Total Hydrocarbon Gas Liquids Refinery and Blender Net Production in Thousand Barrels per Day"
#             },
#             {
#                 "id": "HPI9SUS",
#                 "name": "Hydroelectric Pumped Storage Industrial Sector Generating Units, Usage Factor in Percent"
#             },
#             {
#                 "id": "HVCCBUS",
#                 "name": "Conventional Hydroelectric Power Consumed by the Commercial Sector in Trillion Btu"
#             },
#             {
#                 "id": "HVI9PUS",
#                 "name": "Conventional Hydroelectric Power Industrial Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "KSICBUS",
#                 "name": "Kerosene Consumed by the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "KSRCBUS",
#                 "name": "Kerosene Consumed by the Residential Sector in Trillion Btu"
#             },
#             {
#                 "id": "KSRCPUS",
#                 "name": "Kerosene Consumed by the Residential Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "LNIMPQA",
#                 "name": "Natural Gas Imports from Qatar in Billion Cubic Feet"
#             },
#             {
#                 "id": "LNIMPUA",
#                 "name": "Natural Gas Imports from United Arab Emirates in Billion Cubic Feet"
#             },
#             {
#                 "id": "LUICEUS",
#                 "name": "Lubricants Industrial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "LUTCEUS",
#                 "name": "Lubricants CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "MGICBUS",
#                 "name": "Motor Gasoline Consumed by the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "MGIMPUS",
#                 "name": "Finished Motor Gasoline Imports in Thousand Barrels per Day"
#             },
#             {
#                 "id": "MMTCEUS",
#                 "name": "Motor Gasoline, Excluding Ethanol, CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "NGC5PUS",
#                 "name": "Electricity Net Generation From Natural Gas, Commercial Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "NGC9PUS",
#                 "name": "Natural Gas Commercial Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "NGEIUUS",
#                 "name": "Average Natural Gas Price, Electric Power Sector in Dollars per Thousand Cubic Feet"
#             },
#             {
#                 "id": "NGEPPUS",
#                 "name": "Natural Gas Consumption for Electricity Generation, All Sectors in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGEXBUS",
#                 "name": "Natural Gas Exports in Quadrillion Btu"
#             },
#             {
#                 "id": "NGINSUS",
#                 "name": "Percentage of Industrial Sector Consumption for Which Price Data Are Available in Percent"
#             },
#             {
#                 "id": "NGMPPUS",
#                 "name": "Natural Gas Marketed Production (Wet) in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGPRPUS",
#                 "name": "Natural Gas Production (Dry) in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGRCSUS",
#                 "name": "Percentage of Residential Sector Consumption for Which Price Data Are Available in Percent"
#             },
#             {
#                 "id": "NGRCUUS",
# ...
#                 "id": "FFI9PUS",
#                 "name": "Fossil Fuels Industrial Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "GEC9PUS",
#                 "name": "Geothermal Commercial Sector, Net Summer Capacity  in Million Kilowatts"
#             },
#             {
#                 "id": "GEEGBUS",
#                 "name": "Geothermal Energy Consumed by the Electric Power Sector in Trillion Btu"
#             },
#             {
#                 "id": "GEEIEUS",
#                 "name": "Geothermal Energy Electric Power Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "GEETPUS",
#                 "name": "Electricity Net Generation From Geothermal, All Sectors in Million Kilowatthours"
#             },
#             {
#                 "id": "GEL9PUS",
#                 "name": "Geothermal Electric Power Sector, Net Summer Capacity  in Million Kilowatts"
#             },
#             {
#                 "id": "GETCBUS",
#                 "name": "Geothermal Energy Consumption/Production in Trillion Btu"
#             },
#             {
#                 "id": "HLACPUS",
#                 "name": "Propane Consumed by the Transportation Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "HLICPUS",
#                 "name": "Total Hydrocarbon Gas Liquids Consumed by the Industrial Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "HLPSPUS",
#                 "name": "Total Hydrocarbon Gas Liquids Stocks in Million Barrels"
#             },
#             {
#                 "id": "HPCASUS",
#                 "name": "Hydroelectric Pumped Storage Generating Units, Usage Factor in Percent"
#             },
#             {
#                 "id": "HVETPUS",
#                 "name": "Electricity Net Generation From Conventional Hydroelectric Power, All Sectors in Million Kilowatthours"
#             },
#             {
#                 "id": "HVI5PUS",
#                 "name": "Electricity Net Generation From Hydroelectric Power, Industrial Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "KSCCPUS",
#                 "name": "Kerosene Consumed by the Commercial Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "LNEXPJA",
#                 "name": "Natural Gas Exports to Japan in Billion Cubic Feet"
#             },
#             {
#                 "id": "LNEXPSK",
#                 "name": "Natural Gas Exports to South Korea in Billion Cubic Feet"
#             },
#             {
#                 "id": "LNIMPNI",
#                 "name": "Natural Gas Imports from Nigeria in Billion Cubic Feet"
#             },
#             {
#                 "id": "LOCCBUS",
#                 "name": "Electrical System Energy Losses Proportioned to the Commercial Sector in Trillion Btu"
#             },
#             {
#                 "id": "LORCBUS",
#                 "name": "Electricity System Energy Losses Proportioned to the Residential Sector in Trillion Btu"
#             },
#             {
#                 "id": "LOTCBUS",
#                 "name": "Total Electrical Energy System Losses Proportioned to the End-Use Sectors in Trillion Btu"
#             },
#             {
#                 "id": "LUACBUS",
#                 "name": "Lubricants Consumed by the Transportation Sector in Trillion Btu"
#             },
#             {
#                 "id": "LUICBUS",
#                 "name": "Lubricants Consumed by the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "LUICPUS",
#                 "name": "Lubricants Consumed by the Industrial Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "MGTCAUS",
#                 "name": "Average Cost of Motor Gasoline in Dollars per Million Btu"
#             },
#             {
#                 "id": "MGTCOUS",
#                 "name": "Average Cost of Motor Gasoline in Dollars per Gallon"
#             },
#             {
#                 "id": "MGTCPUS",
#                 "name": "Motor Gasoline Product Supplied in Thousand Barrels per Day"
#             },
#             {
#                 "id": "MMACEUS",
#                 "name": "Motor Gasoline, Excluding Ethanol, Transportation Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "NGBGPUS",
#                 "name": "Natural Gas in Underground Storage, End of Period, Base Gas in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGECPUS",
#                 "name": "Natural Gas Consumption for Electricity Generation and Useful Thermal Output, All Sectors in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGEIPUS",
#                 "name": "Natural Gas Consumption for Electricity Generation and Useful Thermal Output, Electric Power Sector in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGERDUS",
#                 "name": "Average Cost of Natural Gas Receipts at Electric Generating Plants in Dollars per Million Btu, Including Taxes"
#             },
#             {
#                 "id": "NGEXPCN",
#                 "name": "Natural Gas Exports to Canada in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGI1PUS",
#                 "name": "Natural Gas Consumption for Electricity Generation, Industrial Sector in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGIMPMX",
#                 "name": "Natural Gas Imports from Mexico in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGNRPUS",
#                 "name": "Natural Gas Rotary Rigs in Operation, Total in Number of Rigs"
#             },
#             {
#                 "id": "NGTCPUS",
#                 "name": "Natural Gas Consumption, Total in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGVHPUS",
#                 "name": "Natural Gas Consumed by the Transportation Sector, Vehicle Fuel in Billion Cubic Feet"
#             },
#             {
#                 "id": "NGWGPUS",
#                 "name": "Natural Gas in Underground Storage, End of Period, Working Gas in Billion Cubic Feet"
#             },
#             {
#                 "id": "NNICEUS",
#                 "name": "Natural Gas Industrial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "NNTCBUS",
#                 "name": "Natural Gas Consumption (Excluding Supplemental Gaseous Fuels) in Trillion Btu"
#             },
#             {
#                 "id": "NTC9SUS",
#                 "name": "Natural Gas Gas Turbine Plants Commercial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "NTL9SUS",
#                 "name": "Natural Gas Gas Turbine Plants Electric Power Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "NUOUPUS",
#                 "name": "Nuclear Generating Units, Total Operable Units, End of Period in Number"
#             },
#             {
#                 "id": "NWEIEUS",
#                 "name": "Non-Biomass Waste Electric Power Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "NXSIPUS",
#                 "name": "Natural Gas Storage Activity, Injections in Billion Cubic Feet"
#             },
#             {
#                 "id": "NYC9SUS",
#                 "name": "Natural Gas Conventional Steam Plants Commercial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "OGDFPUS",
#                 "name": "Dry Wells, Total Footage Drilled  in Thousand Feet"
#             },
#             {
#                 "id": "OGHFPUS",
#                 "name": "Crude Oil, Natural Gas, and Dry Wells, Horizontal and Directional Trajectory, Total Footage Drilled in Thousand Feet"
#             },
#             {
#                 "id": "OGVTPUS",
#                 "name": "Crude Oil and Natural Gas Rotary Rigs in Operation, Vertical Trajectory in Number of Rigs"
#             },
#             {
#                 "id": "OPICBUS",
#                 "name": "Other Petroleum Products Consumed by the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "PAC3PUS",
#                 "name": "Petroleum Consumption for Electricity Generation and Useful Thermal Output, Commercial Sector in Thousand Barrels"
#             },
#             {
#                 "id": "PAEPPUS",
#                 "name": "Total Petroleum Consumption for Electricity Generation, All Sectors in Thousand Barrels"
#             },
#             {
#                 "id": "PAEXPCN",
#                 "name": "Petroleum Exports to Canada in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAEXPNL",
#                 "name": "Petroleum Exports to Netherlands in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAEXPUS",
#                 "name": "Total Petroleum Exports in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAICPUS",
#                 "name": "Total Petroleum Consumed by the Industrial Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAIMPLY",
#                 "name": "Petroleum Imports From Libya in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAIMPNI",
#                 "name": "Petroleum Imports From Nigeria in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAIMPOO",
#                 "name": "Petroleum Imports From Other OPEC in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAIMPUK",
#                 "name": "Petroleum Imports From United Kingdom in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PAIMPVE",
#                 "name": "Petroleum Imports From Venezuela in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PARCPUS",
#                 "name": "Total Petroleum Consumed by the Residential Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PATCPUS",
#                 "name": "Petroleum Products Supplied/Consumption, United States in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PCCCEUS",
#                 "name": "Petroleum Coke Commercial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "PCICEUS",
#                 "name": "Petroleum Coke Industrial Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "PMCCBUS",
#                 "name": "Petroleum Consumed by the Commercial Sector (Excluding Biofuels) in Trillion Btu"
#             },
#             {
#                 "id": "PMIMBUS",
#                 "name": "Total Petroleum, Excluding Biofuels, Imports in Quadrillion Btu"
#             },
#             {
#                 "id": "PQICBUS",
#                 "name": "Propane Consumed by the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "PYPSPUS",
#                 "name": "Propylene Stocks in Million Barrels"
#             },
#             {
#                 "id": "PZEXPUS",
#                 "name": "Propane Exports in Thousand Barrels per Day"
#             },
#             {
#                 "id": "PZICBUS",
#                 "name": "Propane/Propylene Consumed by the Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "RBWHUUS",
#                 "name": "Average Refiner Price of Residual Fuel Oil, Sulfur Content Less Than or Equal to 1 Percent, Sales for Resale in Dollars per Gallon Excluding Taxes"
#             },
#             {
#                 "id": "RCRTUUS",
#                 "name": "Regular Motor Gasoline, Conventional Gasoline Areas, Average Retail Price in Dollars per Gallon Including Taxes"
#             },
#             {
#                 "id": "REACBUS",
#                 "name": "Total Biomass Energy Consumed by the Transportation Sector in Trillion Btu"
#             },
#             {
#                 "id": "RFACPUS",
#                 "name": "Residual Fuel Oil Consumed by the Transportation Sector in Thousand Barrels per Day"
#             },
#             {
#                 "id": "RFEPPUS",
#                 "name": "Residual Fuel Oil Consumption for Electricity Generation, All Sectors in Thousand Barrels"
#             },
#             {
#                 "id": "RFPSPUS",
#                 "name": "Residual Fuel Oil Stocks, End of Period in Million Barrels"
#             },
#             {
#                 "id": "RFTCEUS",
#                 "name": "Residual Fuel Oil CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "RFTCPUS",
#                 "name": "Residual Fuel Oil Product Supplied in Thousand Barrels per Day"
#             },
#             {
#                 "id": "RFWHUUS",
#                 "name": "Average Refiner Price of Residual Fuel Oil, Sales for Resale in Dollars per Gallon Excluding Taxes"
#             },
#             {
#                 "id": "RQIMBUS",
#                 "name": "Petroleum Products, Excluding Biofuels, Imports in Quadrillion Btu"
#             },
#             {
#                 "id": "SOC5BUS",
#                 "name": "Utility-Scale Solar Energy Consumption for Electricity: Commercial Sector in Trillion Btu"
#             },
#             {
#                 "id": "SOC7BUS",
#                 "name": "Small-Scale Solar Energy Consumption for Electricity: Commercial Sector in Trillion Btu"
#             },
#             {
#                 "id": "SOEGPUS",
#                 "name": "Utility-Scale Solar Electricity Net Generation:  Electric Power Sector in Million Kilowatthours"
#             },
#             {
#                 "id": "TEACEUS",
#                 "name": "Total Energy Transportation Sector CO2 Emissions in Million Metric Tons of Carbon Dioxide"
#             },
#             {
#                 "id": "TNRCBUS",
#                 "name": "End-Use Energy Consumed by the Residential Sector in Trillion Btu"
#             },
#             {
#                 "id": "TNTCBUS",
#                 "name": "End-Use Energy Consumed by the End-Use Sectors in Trillion Btu"
#             },
#             {
#                 "id": "TXRCBUS",
#                 "name": "Total Primary Energy Consumed by the Residential Sector in Trillion Btu"
#             },
#             {
#                 "id": "WDGBPUS",
#                 "name": "Wood, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "WDI1BUS",
#                 "name": "Wood Consumption for Electricity Generation, Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "WSCCBUS",
#                 "name": "Waste Energy Consumed by the Commercial Sector in Trillion Btu"
#             },
#             {
#                 "id": "WSI1BUS",
#                 "name": "Waste Consumption for Electricity Generation, Industrial Sector in Trillion Btu"
#             },
#             {
#                 "id": "WSL9PUS",
#                 "name": "Waste Electric Power Sector, Net Summer Capacity in Million Kilowatts"
#             },
#             {
#                 "id": "WYC9SUS",
#                 "name": "Wind Commercial Sector Generating Units, Capacity Factor in Percent"
#             },
#             {
#                 "id": "WYTCBUS",
#                 "name": "Wind Energy Consumption/Production in Trillion Btu"
#             },
#             {
#                 "id": "ZWHDPC5",
#                 "name": "Heating Degree-Days, South Atlantic in Number"
#             }
#         ]
#     },
#     "request": {
#         "command": "/v2/total-energy/facet/msn/",
#         "params": {
#             "api_key": "VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"
#         }
#     },
#     "apiVersion": "2.1.5",
#     "ExcelAddInVersion": "2.1.0"
# }

# %%
data = data['response']['data']
df = pd.json_normalize(data)

# Display the DataFrame
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data = data['response']['data']
#       2 df = pd.json_normalize(data)
#       4 # Display the DataFrame
#
# KeyError: 'data'
