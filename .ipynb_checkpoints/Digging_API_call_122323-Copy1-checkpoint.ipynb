# %%
import requests
import json
import pandas as pd

# %%
#Some API Test URLS
# eia_url = "https://api.eia.gov/v2/electricity/retail-sales/data/?api_key=X"
# eia_url = "https://api.eia.gov/v2/electricity/retail-sales/data/?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&facets[stateid][]=CO&facets[sectorid][]=RES&frequency=monthly"
# https://www.eia.gov/opendata/documentation.php
#https://www.eia.gov/opendata/documentation/APIv2.0.1.pdf
#https://www.energy.gov/indianenergy/articles/eia-electric-power-monthly-data-july-2020

# %%
#Good stuff here: https://www.eia.gov/totalenergy/data/monthly/pdf/mer.pdf
#Good stuff here: https://www.eia.gov/totalenergy/data/monthly/#renewable

#https://eerscmap.usgs.gov/uswtdb/assets/data/uswtdbApiNotebook.html



# Declare "url" variables

#High level overview of EIA API
# eia_url = "https://api.eia.gov/v2?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&"

#Detailed view of Electricity entry for EIA API
# eia_url = "https://api.eia.gov/v2/electricity?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&"

#Detailed view of Electricity entry for EIA API
#eia_url = "https://api.eia.gov/v2/electricity/rto/?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&"


#Detailed view of electricity/electric-power-operational-data entry for EIA API
#eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&"
# Declare "url" variables
# eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/facet/fueltypeid?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"

# %%
#These are the URLs we are using


#Detailed view of electricity/electric-power-operational-data entry for EIA API. This one shows everything available
# eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&"

#Detailed view of electricity/electric-power-operational-data entry for EIA API. This one enables us to detemrine the fueltypeid for wind is WND
eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/facet/fueltypeid?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"

#Detailed view of electricity/electric-power-operational-data entry for EIA API. 
# eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/data?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9&data[]=generation&facets[fueltypeid][]=WND&facets[location][]=MO&frequency=monthly&sort[0][column]=period&sort[0][direction]=desc&facets[sectorid][]=99"

#Gives definiton of "sectorid"
#eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/facet/sectorid/?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"


# weather_url = "http://history.openweathermap.org/data/3.0/history/locations/create?lat={lat}&lon={lon}&appid={API key}""


# weather_url = "https://api.openweathermap.org/data/3.0/onecall/timemachine?lat={lat}&lon={lon}&dt={time}&appid={API key}""

#weather_url = 'http://history.openweathermap.org/data/3.0/history/locations/create?lat=38.573936&lon=-92.603760&appid=2e60fe54c1425ba8456a1a10124fdef8'

# %%
# Execute "GET" request with url
response_data = requests.get(eia_url)

# response_data = requests.get(weather_url)

# response_data

# %%
# Print "response_data" variable
print(response_data)
# Out:
# <Response [200]>

# %%
# Store response using "content" attribute
response_content = response_data.content
print(response_content)
# Out:
# b'{"response":{"totalFacets":45,"facets":[{"id":"ALL","name":"all fuels"},{"id":"SPV","name":"solar photovoltaic"},{"id":"LIG","name":"lignite coal"},{"id":"RC","name":"refined coal"},{"id":"BIT","name":"bituminous coal"},{"id":"WAS","name":"renewable waste products"},{"id":"STH","name":"solar thermal"},{"id":"COW","name":"all coal products"},{"id":"PET","name":"petroleum"},{"id":"REN","name":"renewable"},{"id":"OB2","name":"biomass"},{"id":"OTH","name":"other"},{"id":"TPV","name":"estimated total solar photovoltaic"},{"id":"TSN","name":"estimated total solar"},{"id":"HPS","name":"hydro-electric pumped storage"},{"id":"DPV","name":"estimated small scale solar photovoltaic"},{"id":"LFG","name":"landfill gas"},{"id":"MLG","name":"municiapl landfill gas"},{"id":"WNT","name":"onshore wind turbine"},{"id":"ORW","name":"other renewables"},{"id":"NUC","name":"nuclear"},{"id":"WND","name":"wind"},{"id":"WNS","name":"offshore wind turbine"},{"id":"ANT","name":"anthracite coal"},{"id":"BIO","name":"biomass"},{"id":"SUB","name":"subbituminous coal"},{"id":"PC","name":"petroleum coke"},{"id":"WOC","

#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2009-10",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 69.75725,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2009-09",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 29.03061,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2009-08",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 36.97001,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2009-07",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 22.86197,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2009-06",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 23.41349,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2009-05",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 40.8551,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2009-04",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 59.25294,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2009-03",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 34.47442,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2009-02",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 26.08239,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2009-01",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 25.59102,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2008-12",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 30.26293,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2008-11",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 11.68714,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2008-10",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 30.44964,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2008-09",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 18.7625,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2008-08",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 12.13525,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2008-07",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 16.61531,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2008-06",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 15.98671,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2008-05",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 17.0686,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2008-04",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 18.98344,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2008-03",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 13.49929,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2008-02",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 6.7372,
#                 "generation-units": "thousand megawatthours"
#             },
#             {
#                 "period": "2008-01",
#                 "location": "MO",
#                 "stateDescription": "Missouri",
#                 "sectorid": 99,
#                 "sectorDescription": "All Sectors",
#                 "fueltypeid": "WND",
#                 "fuelTypeDescription": "wind",
#                 "generation": 11.125,
#                 "generation-units": "thousand megawatthours"
#             }
#         ],
#         "description": "Monthly and annual electric power operations by state, sector, and energy source.\n    Source: Form EIA-923"
#     },
#     "request": {
#         "command": "/v2/electricity/electric-power-operational-data/data/",
#         "params": {
#             "api_key": "VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9",
#             "data": [
#                 "generation"
#             ],
#             "facets": {
#                 "fueltypeid": [
#                     "WND"
#                 ],
#                 "location": [
#                     "MO"
#                 ],
#                 "sectorid": [
#                     99
#                 ]
#             },
#             "frequency": "monthly",
#             "sort": [
#                 {
#                     "column": "period",
#                     "direction": "desc"
#                 }
#             ]
#         }
#     },
#     "apiVersion": "2.1.5",
#     "ExcelAddInVersion": "2.1.0"
# }

# %%
# # Used with eia_url = "https://api.eia.gov/v2/electricity/electric-power-operational-data/facet/fueltypeid?api_key=VncsPCILhy2WlSElUxu9SmixaOdqw9gZMobZ5uz9"
# #Reports identified for all fuel types

# # mo_wnd_generation_df = pd.json_normalize(data["period"]["generation"][generation-units])
# # fueltypeid_df

# # Extract the relevant values
# relevant_data = []

# for item in data['response']['data']:
#     relevant_item = {
#         "period": item["period"],
#         "location": item["location"],
#         "stateDescription": item["stateDescription"],
#         "sectorid": item["sectorid"],
#         "sectorDescription": item["sectorDescription"],
#         "fueltypeid": item["fueltypeid"],
#         "fuelTypeDescription": item["fuelTypeDescription"],
#         "generation": item["generation"],
#         "generation-units": item["generation-units"]
#     }
#     relevant_data.append(relevant_item)

# # Create a DataFrame from the relevant data
# df = pd.DataFrame(relevant_data)

# # Display the DataFrame
# df

# %%
data = data['response']['data']
df = pd.json_normalize(data)

# Display the DataFrame
df
# Out:
#       period location stateDescription  sectorid sectorDescription fueltypeid  \
# 0    2023-09       MO         Missouri        99       All Sectors        WND
# 1    2023-08       MO         Missouri        99       All Sectors        WND
# 2    2023-07       MO         Missouri        99       All Sectors        WND
# 3    2023-06       MO         Missouri        99       All Sectors        WND
# 4    2023-05       MO         Missouri        99       All Sectors        WND
# ..       ...      ...              ...       ...               ...        ...
# 184  2008-05       MO         Missouri        99       All Sectors        WND
# 185  2008-04       MO         Missouri        99       All Sectors        WND
# 186  2008-03       MO         Missouri        99       All Sectors        WND
# 187  2008-02       MO         Missouri        99       All Sectors        WND
# 188  2008-01       MO         Missouri        99       All Sectors        WND
#
#     fuelTypeDescription  generation        generation-units
# 0                  wind   438.89128  thousand megawatthours
# 1                  wind   377.16664  thousand megawatthours
# 2                  wind   305.72244  thousand megawatthours
# 3                  wind   304.22761  thousand megawatthours
# 4                  wind   423.71527  thousand megawatthours
# ..                  ...         ...                     ...
# 184                wind    17.06860  thousand megawatthours
# 185                wind    18.98344  thousand megawatthours
# 186                wind    13.49929  thousand megawatthours
# 187                wind     6.73720  thousand megawatthours
# 188                wind    11.12500  thousand megawatthours
#
# [189 rows x 9 columns]
